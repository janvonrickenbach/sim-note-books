# %%
import os
import glob as gl
import simulation_brutus as sim_brutus
import job_configurations as jc
import matplotlib.pyplot as pl
import pickle as pic
import numpy as np


import subprocess as sp
import initial_condition_writer as ini
import shutil as sh

import Cantera as ca

import para_reader as pa
from IPython.display import Image,display
import operator as op
# %matplotlib inline

# %%
def filter_simulations(sim_list,**kwargs):
  filtered_list = []
  for sim in sim_list:
      match_all = True
      for key, item in kwargs.iteritems():
            if not int(sim.sim_info[key]) == int(item):  
              match_all = False
      if match_all:
        filtered_list.append(sim)
  return filtered_list
    
def sort_sims(sim_list,prop): 
    return sorted(sim_list,key=lambda it: it.sim_info[prop])    

def get_array(sim_list,func=None):
    prop_list = []
    if func:
        for sim in sim_list:
           prop_list.append(func(sim))
    return np.array(prop_list)

# %%
# %%file write_pictures.py

from paraview.simple import *
from para_reader import *
import os

try:
    os.mkdir("processed")
except:
    print("directory exists already")

outputname=  os.path.join("processed","unstructured.vtu")

rewrite_as_unstructured(get_last_modified(),outputname)

print(outputname)
# Out:
# Overwriting write_pictures.py

# %%
# %%file line_avg.py

from paraview.simple import *
from para_reader import *
import pickle as pic
import os
import glob as gl
import numpy as np

name = get_last_modified()
print(name)
    
data_file = OpenDataFile(name)

print("Reading file ", data_file)

avg_var =[]

filelist=gl.glob("grid*")
wc_data = []
for file_h in filelist:
    f = open(file_h)
    x_coord = f.readline()
    f.close()
    wc_data.append([x_coord,np.genfromtxt(file_h)])
    

point_data = CellDatatoPointData(MergeBlocks(data_file))
prob = ProbeLocation(point_data,ProbeType="Fixed Radius Point Source"     )
prob1 = ProbeLocation(point_data,ProbeType="Fixed Radius Point Source"     )

UpdatePipeline()
bounds = get_bounds(data_file)

print(bounds)

prob.ProbeType.Center = [0.01025,-0.00400001525878906,0.000999992370605469]
prob1.ProbeType.Center = [0.0001,-0.00400001525878906,0.000999992370605469]

UpdatePipeline()

data_dict = save_data_to_dict(prob,cell=False)
data_dict1 = save_data_to_dict(prob1,cell=False)

UpdatePipeline()


try:
    os.mkdir("processed")
except:
    print("directory exists already")
pickle_file = "processed/slice_averages.dat"
pickle_file_wc = "processed/wc_data.dat"
f = open(pickle_file,'w')
f_wc = open(pickle_file_wc,'w')
pic.dump([data_dict,data_dict1],f)
pic.dump(wc_data,f_wc)
f.close()
f_wc.close()
# Out:
# Overwriting line_avg.py

# %%
# %%file plot_line.py

from paraview.simple import *
from para_reader import *
import pickle as pic
import os

name = get_last_modified()
print(name)
    
data_file = OpenDataFile(name)

print("Reading file ", data_file)

avg_var =[]

point_data = CellDatatoPointData(MergeBlocks(data_file))

prob = PlotOverLine(point_data)

UpdatePipeline()
bounds = get_bounds(data_file)

print(bounds)

prob.Source.Point1 = [0.0000001,-0.00400001525878906,0.000999992370605469]
prob.Source.Point2 = [0.0399999999,-0.00400001525878906,0.000999992370605469]
prob.Source.Resolution = 10

UpdatePipeline()

data_dict = save_data_to_dict(prob,cell=False)

UpdatePipeline()


try:
    os.mkdir("processed")
except:
    print("directory exists already")
pickle_file = "processed/plot_over_line.dat"
f = open(pickle_file,'w')
pic.dump(data_dict,f)
f.close()
# Out:
# Overwriting plot_line.py

# %%
ref_folder = "/home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/ref_sim/finite_vol_avg_wc_only_CO/"

# %%
def create_simulation(input_dict,folder,root_folder="."):

    try:
        sh.copytree(ref_folder,os.path.join(root_folder,folder))
    except:
        print("directory exists")
 
    massfraction = {}
    massfraction["O2"]   = [0.1,   [0,0]] 
    massfraction["CO2"]  = [0.064, [0,1]]
    massfraction["H2O"]  = [0.072, [0,2]]
    massfraction["N2"]   = [0.76,  [0,3]]
    massfraction["CO"]   = [input_dict["mf"]*1E-6, [0,4]]
    velocity     = input_dict["velocity"]
    temperature  = input_dict["temperature"]
    wc_thickness = input_dict["wc_thickness"]*1E-6
    wc_geo_area  = input_dict["wc_geo_area"]
    sh_n         = input_dict["sh_number"]
    a_v          = input_dict["a_v"]
    n_wc         = input_dict["wc_ncells"]
    res          = input_dict["resolution"]
    dp           = input_dict["dp"]*1E-9
    cov_CO       = input_dict["cov_CO"]
    config_sim = jc.configuration_brutus
    config_sim["jobname"] = folder
    config_sim["root_folder"] = root_folder
    config_sim["cluster_scratch"]='/cluster/scratch_xp/public/vjan/wc_1d_tests'
    simulation = sim_brutus.job(**config_sim)
    

    sh.copy(os.path.join(os.path.join(root_folder,ref_folder),"transat_mb.inp"),os.path.join(root_folder,folder))
    sh.copy(os.path.join(os.path.join(root_folder,ref_folder),"finite_vol_avg.stt"),os.path.join(root_folder,folder))

    sh.copy(os.path.join(os.path.join(root_folder,ref_folder),"cantera_input.cti"),os.path.join(root_folder,folder))
    sh.copy(os.path.join(os.path.join(root_folder,ref_folder),"mt_coefficients.dat"),os.path.join(root_folder,folder))
    sh.copy(os.path.join(os.path.join(root_folder,ref_folder),"res_coefficients.dat"),os.path.join(root_folder,folder))

    simulation.application.change_input("cornerpoint_number  21",res,newline="cornerpoint_number "+str(res) +"\n",filename="finite_vol_avg.stt") 
    
    transatui_command = []
    transatui_command.append("transatui.py")
    transatui_command.append("--Project=finite_vol_avg.stt")
    transatui_command.append("--Graphics=bash")
#    ui=sp.Popen(transatui_command,cwd=os.path.join(root_folder,folder),stdout=open("ui_output.out","a"))
    ui=sp.Popen(transatui_command,cwd=os.path.join(root_folder,folder))

    ui.communicate() 
    
    Dp = 0.002
    ds = 0.0003
    porosity = 0.903
    #a_v = 10.33/(Dp+ds) * np.sqrt(1-porosity) -5.8/(Dp+ds)*(1.0-porosity)
  
    write_inital_conditions(os.path.join(root_folder,folder),massfraction,velocity,temperature)
    
    component_string =  "if (x[ii] < 0.0001){component_molefraction_0_4[ii] ="+str(input_dict["mf"]*1E-6)+";}else{component_molefraction_0_4[ii] =0.000;}"
    if cov_CO < 1:
        simulation.application.change_input("component_molefraction_0_4[ii]",res,newline=component_string + os.linesep,filename="initialconditions.cxx")        

    simulation.application.change_input("data_format",'\"paraview_cell\"')
    simulation.application.change_input("wc_thickness",str(wc_thickness))
    simulation.application.change_input("activate_chem_heat_src",'.false.')
    simulation.application.change_input("mf_subiter",'1')
    simulation.application.change_input("L3Dplot",'.true.')
    simulation.application.change_input("L2Dplot",'.false.')
    simulation.application.change_input("write_kplane",'.false.')
    simulation.application.change_input("ode_rtol",'1E-5')
    simulation.application.change_input("ode_atol",'1E-25')
    simulation.application.change_input("wc_geo_area",str(wc_geo_area))
    simulation.application.change_input("sherwood_number",str(sh_n))
    simulation.application.change_input("den(1)",0.028*1E5/(8.314*temperature))
    simulation.application.change_input("wc_ncells",str(n_wc))
    simulation.application.change_input("wc_pore_diameter",str(dp))
    simulation.application.change_input("wc_tortuosity",str(8.0))
    simulation.application.change_input("pseudo_int_time",str(1E4))
    simulation.application.change_input("init_surf_cov(1)",str(1-cov_CO))
    simulation.application.change_input("init_surf_cov(3)",str(cov_CO))

    if wc_thickness < 0.0:
        simulation.application.change_input("wc_ncells",str(1))
        simulation.application.change_input("wc_thickness",str(1E-5))

    simulation.application.change_input("porous_a_v",str(a_v))

    simulation.application.change_input("surface_coverage",'1.0',filename="properties.dat")

    conjugate = False
    if conjugate:
       simulation.application.change_input("temp_model",'\"conjugate\"',filename="properties.dat")
       simulation.application.change_input("density",'3500',filename="properties.dat")
       simulation.application.change_input("conductivity",'25.6',filename="properties.dat")
       simulation.application.change_input("heatcapacity",'795',filename="properties.dat")
       simulation.application.change_input("surface_coverage",'1.0',filename="properties.dat")


    simulation.sim_info = input_dict.copy()
    simulation.sim_info["converged"] = False


    return simulation

# %%
def write_inital_conditions(folder,massfraction,velocity,temperature):

    writer = ini.initalconditions_writer()
    writer.add_variable("uvelocity",velocity)
    writer.add_variable("temperature",temperature)
    
    for key,item in massfraction.iteritems():
        writer.add_variable(var="component_molefraction",value=item[0],index=item[1])
        
    writer.write_file(folder)

# %%
def get_folder_name(inputs):
  folder = ""
  for item in sorted(inputs.iteritems(), key=op.itemgetter(0)):
      folder += item[0][0:5]+"_"+str(int(item[1]))+"_"
  return folder[:-1]
        

sim_list_full = []
sim_list = []

input_dict = {} 
#temperatures = [360,400,440,450,460,470,480,490,500,510,520,530,540,550,560,570,600,700,800,900,1000,1100]
temperatures = [400,440,470,500,540,600,700,900,1100]
#temperatures = [560]

wc_ncells = [32]
res = [21]

par_inputs = {}


par_inputs["wc_thickness"] = [10,40,-1E6]
par_inputs["wc_geo_area"] = [100,1,10,500]
par_inputs["sh_number"] = [4000,2000]
par_inputs["velocity"] = [2.5,5]
par_inputs["a_v"] = [1000]
par_inputs["dp"] = [10,100]
par_inputs["mf"] = [3000,10000]
cov_co = [1,0]


root_folder = "/home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/"

default_inputs = {}
for key,item in par_inputs.iteritems():
    default_inputs[key] = item[0] 

sim_count = 0
for temperature in temperatures:
    for resolution in res:
        for n_cells in wc_ncells:
          for co in cov_co:
            current_inputs = {}
            current_inputs = default_inputs.copy()
            current_inputs["resolution"] = resolution
            current_inputs["wc_ncells"] = n_cells
            current_inputs["temperature"] = temperature
            current_inputs["cov_CO"]      = co
            global_inputs = current_inputs.copy()
            sim_list_full.append(create_simulation(current_inputs,get_folder_name(current_inputs),root_folder=root_folder))
            sim_count += 1
            for par_input,par_values in par_inputs.iteritems():
                current_inputs = global_inputs.copy()
                for par_value in par_values[1:]:
                    current_inputs[par_input] = par_value
                    sim_count += 1
                    sim_list_full.append(create_simulation(current_inputs,get_folder_name(current_inputs),root_folder=root_folder))
    
sim_list = sim_list_full
# Out:
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_1_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_10_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_500_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_5_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_40': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# jobname         a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# jobname         a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_1_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_10_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_500_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_5_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_40': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_1_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_10_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_500_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_5_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_40': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# jobname         a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# jobname         a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_1_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_10_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_500_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_5_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_40': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ...
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_40': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# jobname         a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# jobname         a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_1_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_10_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_500_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_5_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_40': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# jobname         a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# ===============================================
# directory exists
# mkdir: cannot create directory `/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10': File exists
# ===============================================
# username        vjan
# scratch         /cluster/scratch_xp/public/vjan/wc_1d_tests
# host            brutus.ethz.ch
# ssh             vjan@brutus.ethz.ch:/cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# dir             /cluster/scratch_xp/public/vjan/wc_1d_tests/a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# project_name    finite_vol_avg
# sim_folder      /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# jobname         a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# ===============================================

# %%
sim_count
# Out:
# 180

# %%
filter_simulations(sim_list,temperature=700)
# Out:
# [<simulation_brutus.job instance at 0x1b532fc8>,
#  <simulation_brutus.job instance at 0x1ac90440>,
#  <simulation_brutus.job instance at 0x1b507e18>,
#  <simulation_brutus.job instance at 0x1ac9fef0>,
#  <simulation_brutus.job instance at 0x1aca3a70>,
#  <simulation_brutus.job instance at 0x1ac8c6c8>,
#  <simulation_brutus.job instance at 0x1bb57200>,
#  <simulation_brutus.job instance at 0x1aca3950>,
#  <simulation_brutus.job instance at 0x1ac98ea8>,
#  <simulation_brutus.job instance at 0x1befcef0>,
#  <simulation_brutus.job instance at 0x1ac8a758>,
#  <simulation_brutus.job instance at 0x1c0dd7a0>,
#  <simulation_brutus.job instance at 0x1c0e4fc8>,
#  <simulation_brutus.job instance at 0x1acaad88>,
#  <simulation_brutus.job instance at 0x1c0dde60>,
#  <simulation_brutus.job instance at 0x1ac85cf8>,
#  <simulation_brutus.job instance at 0x1ac9d2d8>,
#  <simulation_brutus.job instance at 0x1ac9ec20>,
#  <simulation_brutus.job instance at 0x1c0dff80>,
#  <simulation_brutus.job instance at 0x1c0eef38>]

# %%
for sim in filter_simulations(sim_list,cov_CO=0):
       sim.kill()
# Out:
# Job <57367480> is being terminated
# Job <a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_1_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_10_wc_nc_32_wc_th_10> is not found
# Job <57367508> is being terminated
# Job <57367512> is being terminated
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_5_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_40> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000> is not found
# Job <a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_1_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_10_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_500_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_5_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_40> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000> is not found
# Job <a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_1_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_10_wc_nc_32_wc_th_10> is not found
# Job <57367622> is being terminated
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_5_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_40> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000> is not found
# Job <a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_1_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_10_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_500_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_5_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_40> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000> is not found
# Job <a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <57367776> is being terminated
# Job <57367782> is being terminated
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_500_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_5_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <57367802> is being terminated
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000> is not found
# Job <a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_600_veloc_2_wc_ge_100_wc_nc_32_wc_th_10> is not found
# Job <57367818> is being terminated
# Job <57367824> is being terminated
# Job <57367827> is being terminated
# Job <57367835> is being terminated
# Job <57367888> is being terminated
# Job <57367892> is being terminated
# Job <57367898> is being terminated
# Job <57367904> is being terminated
# Job <57367909> is being terminated
# Job <57367914> is being terminated
# Job <57367922> is being terminated
# Job <57367926> is being terminated
# Job <57367929> is being terminated
# Job <57367940> is being terminated
# Job <57367945> is being terminated
# Job <57367949> is being terminated
# Job <57367953> is being terminated
# Job <57367961> is being terminated
# Job <57367964> is being terminated
# Job <57367972> is being terminated
# Job <57367977> is being terminated
# Job <57367980> is being terminated
# Job <57367983> is being terminated
# Job <57367986> is being terminated
# Job <57368006> is being terminated
# Job <57368010> is being terminated
# Job <57368014> is being terminated
# Job <57368018> is being terminated
# Job <57368024> is being terminated
# Job <57368044> is being terminated
# Job <57368050> is being terminated
# Job <57368053> is being terminated
# Job <57368056> is being terminated
# Job <57368060> is being terminated
# Job <57368063> is being terminated
# Job <57368066> is being terminated
# Job <57368069> is being terminated
# Job <57368074> is being terminated
# Job <57368080> is being terminated

# %%
for sim in filter_simulations(sim_list,cov_CO=0):
   sim.application.load      = "source ~/.bashrc_gfort_wc_model"
   sim.init_application.load = "source ~/.bashrc_gfort_wc_model"  
   sim.compile_init_application.load = "source ~/.bashrc_gfort_wc_model"  

   init = True
   depend = False
   sim.sync_input()
   if init:
       sim.compile_init(nproc="1",memory="1024",time='60') 

       sim.run_init(nproc="1",memory="1024",time='60',depend=True) 
       depend = True
   sim.run_sim(nproc="10",memory="1024",time='1200',njobs=1,restart=False,depend=depend)
# Out:
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370455> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57370456> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370457> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370458> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57370460> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370462> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370463> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_1_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57370464> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_1_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370465> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370467> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_10_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57370468> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_10_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370470> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_500_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370471> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_500_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_500_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57370472> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_500_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_500_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370474> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370475> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57370476> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370477> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370478> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_5_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57370479> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_5_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370483> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370485> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_40)" mpirun ./transatmbinitialDP
# Job <57370486> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_40)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370487> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370489> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000)" mpirun ./transatmbinitialDP
# Job <57370490> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370492> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370493> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57370494> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370495> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370497> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57370498> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370499> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370500> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57370501> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370502> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370503> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_1_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57370504> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_1_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370506> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370508> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_10_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57370509> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_10_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370510> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_500_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370511> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_500_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_500_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57370514> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_500_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_500_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370517> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370521> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57370523> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370525> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370527> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_5_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57370528> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_5_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370529> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370530> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_40)" mpirun ./transatmbinitialDP
# Job <57370533> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_40)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370536> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370538> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000)" mpirun ./transatmbinitialDP
# Job <57370539> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370540> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370542> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57370543> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370546> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370548> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57370550> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370552> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370554> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57370555> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370556> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370557> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_1_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57370558> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_1_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57370573> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57370585> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_10_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57370587> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
# ...
# Job <57373221> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_1_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57373229> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_1_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57373235> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57373236> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_10_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57373237> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_10_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57373240> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_500_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57373241> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_500_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_500_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57373242> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_500_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_500_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57373243> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57373244> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57373245> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57373247> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57373248> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_5_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57373249> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_5_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57373250> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57373251> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_40)" mpirun ./transatmbinitialDP
# Job <57373253> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_40)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57373254> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57373255> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000)" mpirun ./transatmbinitialDP
# Job <57373256> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57373258> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <57373260> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbinitialDP
# Job <57373263> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <57373264> is submitted to queue <vip.36h>.
# MPI job.

# %%
filenames = []
#filenames.append("write_pictures.py")
filenames.append("line_avg.py")
#filenames.append("plot_line.py")

for filename in filenames:
    for sim in sim_list:
      sh.copy(filename,os.path.join(sim.info.local["sim_folder"]))
      sim.run_postprocess(filename,nproc="1",memory="1024")
# Out:
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_500_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_500_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_500_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_500_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_500_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_500_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_500_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_500_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_500_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_500_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_600_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_600_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_600_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
# ...
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_500_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_900_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_500_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_1_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_10_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_500_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_5_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py

# %%
def filter_file(sim):
    sim.cp()
    filename = os.path.join(sim.info.local["sim_folder"],"std_out.log_cluster")
    file_obj = open(filename)
    last_job = []
    for line in file_obj:
        last_job.append(line)
        if "Your job looked like" in line:
            last_job = []
            
    for line in last_job:       
        if "---> iteration stops here" in line:
            sim.sim_info["converged"] = True
            return "converged"

    sim.sim_info["converged"] = False
    return None

# %%
try:
    sh.rmtree("logfiles")
except:
   pass
os.mkdir("logfiles")

for sim in sim_list:
    if not filter_file(sim):
        #sim.run_sim(nproc="4",memory="1024",time='480',njobs=1,restart=False) 
        sh.copy(os.path.join(sim.info.local["sim_folder"],"std_out.log_cluster"),os.path.join("logfiles",sim.info.local["jobname"]))

# %%
def get_conv(sim):
    try:
        avg_Y= np.interp(0.005,sim.wc_data["coords"],sim.wc_data["CO"])
        mf   = (0.00299-avg_Y)/0.00299
    except:
        mf = np.nan
    if mf <0.0:
        mf = np.nan
    return mf

# %%
def get_var(sim):
   return max(0,sim.sim_info["temperature"])

# %%
for sim in sim_list_full:
      sim.data = pic.load(open(os.path.join(sim.info.local["sim_folder"],"processed/slice_averages.dat")))  

gas = ca.importPhase(os.path.join(ref_folder,"cantera_input.cti"),"gas")

ext = ".eps"
ext = ".png"

for par,vals in par_inputs.iteritems():
   if len(vals) > 1:
    # if par == "wc_geo_area":
    #        continue

     fig = pl.figure(figsize=[9,6])
     ax  = fig.add_subplot(1,1,1)
     name = par+ext
 
     for resolution in res[:]:
        if par != "wc_thickness":
           ncells = wc_ncells[:]          
        else:
           ncells = [32]
        for cel in ncells:
            for co in cov_co[:]:
               inputs = default_inputs.copy()
               for val in vals: 

                inputs[par] = val
                inputs["resolution"] = resolution
                inputs["wc_ncells"] = cel
                inputs["cov_CO"] = co


                sim_to_plot = sort_sims(filter_simulations(sim_list_full,converged=True,**inputs),"temperature")
                label = par + "_"+str(val) +"_"+ str(co)
                ax.plot(get_array(sim_to_plot,get_var),get_array(sim_to_plot,get_conv),label=label,marker='o')


     diff_coeffs = []
     for temp in temperatures:
        gas.setState_TPY(temp,1.00E5,[0.1,0.064,0.072,0.76,0.003])
        diff_coeffs.append(gas.mixDiffCoeffs()[-1])
     if par!="sh_number":
            sh_n = [par_inputs["sh_number"][0]]
     else:
        sh_n = vals
     if par!="velocity":
        uvel_n = [par_inputs["velocity"][0]]
     else:
        uvel_n = vals   
     for sh_l in sh_n:
         for uvel in uvel_n:
             ax.plot(temperatures,1-np.exp(-np.array(diff_coeffs)*sh_l/uvel*1000*0.005/0.5)*np.ones(len(temperatures)),label="fast chemistry limit Sh="+str(sh_l*0.0023),color="g")

     ax.legend(loc=0)

     ax = pl.gca()

     ax.set_ylabel("$CO$ conversion")
#     ax.set_ylim([0.1,0.2])
     ax.set_xlabel("Temperature (K)")
     fig.tight_layout()
     fig.savefig(name,dpi=300)

# %%
for item in filter_simulations(sim_list_full):
    if not filter_file(item):
        print(item.info.local["jobname"])
len(filter_simulations(sim_list,resolution=41,converged=False))
# Out:
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_600_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_600_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_600_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_600_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_600_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_600_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_600_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_600_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_600_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_600_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_600_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_600_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_600_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_600_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_600_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_600_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_600_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_700_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_700_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_700_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_700_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_700_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_700_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_700_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_700_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_700_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_700_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_700_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_700_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_700_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_700_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_700_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_700_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_700_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_700_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_900_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_900_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_900_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# 0

# %%
gas = ca.importPhase(os.path.join(ref_folder,"cantera_input.cti"),"gas")
gas.setState_TPY(700,1.015E5,[0.1,0.064,0.072,0.76,0.003])
gas.mixDiffCoeffs()
gas.moleFractions()
# Out:
# array([ 0.08726247,  0.04060614,  0.11159703,  0.75754372,  0.00299063])

# %%
res_list = filter_simulations(sim_list)

for sim in res_list:
    sim.cp("RESULT/Linf_resnorm.dat")

# %%
# Plot residuals

legendlist = []
filename = "RESULT/Linf_resnorm.dat"
varname = ".*Species05.*Linf.*end"
for sim in res_list:
  print(sim.get_log(filename))
  res_file     = pa.file_reader(sim.get_log(filename,n=0),comment="#")
#  pressure_res = res_file.get_column(".*Species01.*Linf.*end")[:]/np.amax(res_file.get_column(".*Species01.*Linf.*end")[:])
  pressure_res = res_file.get_column(varname)[:]/np.amax(res_file.get_column(varname)[:])

  pl.semilogy(abs(pressure_res))
  legendlist.append(sim.info.local["jobname"])
ax = pl.gca()
#ax.set_xlim([0,1000])
ax.set_xlabel("Iteration")
ax.set_ylabel("Residual")
ax.legend(legendlist,bbox_to_anchor=(3,1))
# Out:
# /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_dp_10_resolution_21_sh_number_4000_temperature_400_velocity_5_wc_geo_area_1_wc_ncells_32_wc_thickness_40/RESULT/Linf_resnorm.dat_cluster
# #  1: Iteration                                                  #
# #  2: Pres-Divmax. residue (begin), global block number          #
#
# #  3: Pres-Divmax. residue (begin), i-index                      #
#
# #  4: Pres-Divmax. residue (begin), j-index                      #
#
# #  5: Pres-Divmax. residue (begin), k-index                      #
#
# #  6: Pres-Divmax. residue (  end), global block number          #
#
# #  7: Pres-Divmax. residue (  end), i-index                      #
#
# #  8: Pres-Divmax. residue (  end), j-index                      #
#
# #  9: Pres-Divmax. residue (  end), k-index                      #
#
# # 10: Pres-DivLinf(   begin)                                     #
#
# # 11: Pres-DivLinf(     end)                                     #
#
# # 12: Pres-DivLinf(relative)                                     #
#
# # 13: U-Velocitymax. residue (begin), global block number        #
#
# # 14: U-Velocitymax. residue (begin), i-index                    #
#
# # 15: U-Velocitymax. residue (begin), j-index                    #
#
# # 16: U-Velocitymax. residue (begin), k-index                    #
#
# # 17: U-Velocitymax. residue (  end), global block number        #
#
# # 18: U-Velocitymax. residue (  end), i-index                    #
#
# # 19: U-Velocitymax. residue (  end), j-index                    #
#
# # 20: U-Velocitymax. residue (  end), k-index                    #
#
# # 21: U-VelocityLinf(   begin)                                   #
#
# # 22: U-VelocityLinf(     end)                                   #
#
# # 23: U-VelocityLinf(relative)                                   #
#
# # 24: Temperaturemax. residue (begin), global block number       #
#
# # 25: Temperaturemax. residue (begin), i-index                   #
#
# # 26: Temperaturemax. residue (begin), j-index                   #
#
# # 27: Temperaturemax. residue (begin), k-index                   #
#
# # 28: Temperaturemax. residue (  end), global block number       #
#
# # 29: Temperaturemax. residue (  end), i-index                   #
#
# # 30: Temperaturemax. residue (  end), j-index                   #
#
# # 31: Temperaturemax. residue (  end), k-index                   #
#
# # 32: TemperatureLinf(   begin)                                  #
#
# # 33: TemperatureLinf(     end)                                  #
#
# # 34: TemperatureLinf(relative)                                  #
#
# # 35: Phase01_Species01max. residue (begin), global block number #
#
# # 36: Phase01_Species01max. residue (begin), i-index             #
#
# # 37: Phase01_Species01max. residue (begin), j-index             #
#
# # 38: Phase01_Species01max. residue (begin), k-index             #
#
# # 39: Phase01_Species01max. residue (  end), global block number #
#
# # 40: Phase01_Species01max. residue (  end), i-index             #
#
# # 41: Phase01_Species01max. residue (  end), j-index             #
#
# # 42: Phase01_Species01max. residue (  end), k-index             #
#
# # 43: Phase01_Species01Linf(   begin)                            #
#
# # 44: Phase01_Species01Linf(     end)                            #
#
# # 45: Phase01_Species01Linf(relative)                            #
#
# # 46: Phase01_Species02max. residue (begin), global block number #
#
# # 47: Phase01_Species02max. residue (begin), i-index             #
#
# # 48: Phase01_Species02max. residue (begin), j-index             #
#
# # 49: Phase01_Species02max. residue (begin), k-index             #
#
# # 50: Phase01_Species02max. residue (  end), global block number #
#
# # 51: Phase01_Species02max. residue (  end), i-index             #
#
# # 52: Phase01_Species02max. residue (  end), j-index             #
#
# # 53: Phase01_Species02max. residue (  end), k-index             #
#
# # 54: Phase01_Species02Linf(   begin)                            #
#
# # 55: Phase01_Species02Linf(     end)                            #
#
# # 56: Phase01_Species02Linf(relative)                            #
#
# # 57: Phase01_Species03max. residue (begin), global block number #
#
# # 58: Phase01_Species03max. residue (begin), i-index             #
#
# # 59: Phase01_Species03max. residue (begin), j-index             #
#
# # 60: Phase01_Species03max. residue (begin), k-index             #
#
# # 61: Phase01_Species03max. residue (  end), global block number #
#
# # 62: Phase01_Species03max. residue (  end), i-index             #
#
# # 63: Phase01_Species03max. residue (  end), j-index             #
#
# # 64: Phase01_Species03max. residue (  end), k-index             #
#
# # 65: Phase01_Species03Linf(   begin)                            #
#
# # 66: Phase01_Species03Linf(     end)                            #
#
# # 67: Phase01_Species03Linf(relative)                            #
#
# # 68: Phase01_Species04max. residue (begin), global block number #
#
# # 69: Phase01_Species04max. residue (begin), i-index             #
#
# # 70: Phase01_Species04max. residue (begin), j-index             #
#
# # 71: Phase01_Species04max. residue (begin), k-index             #
#
# # 72: Phase01_Species04max. residue (  end), global block number #
#
# # 73: Phase01_Species04max. residue (  end), i-index             #
#
# # 74: Phase01_Species04max. residue (  end), j-index             #
#
# # 75: Phase01_Species04max. residue (  end), k-index             #
#
# # 76: Phase01_Species04Linf(   begin)                            #
#
# # 77: Phase01_Species04Linf(     end)                            #
#
# # 78: Phase01_Species04Linf(relative)                            #
#
# # 79: Phase01_Species05max. residue (begin), global block number #
#
# # 80: Phase01_Species05max. residue (begin), i-index             #
#
# # 81: Phase01_Species05max. residue (begin), j-index             #
#
# # 82: Phase01_Species05max. residue (begin), k-index             #
#
# # 83: Phase01_Species05max. residue (  end), global block number #
#
# # 84: Phase01_Species05max. residue (  end), i-index             #
#
# # 85: Phase01_Species05max. residue (  end), j-index             #
#
# # 86: Phase01_Species05max. residue (  end), k-index             #
#
# # 87: Phase01_Species05Linf(   begin)                            #
#
# # 88: Phase01_Species05Linf(     end)                            #
#
# # 89: Phase01_Species05Linf(relative)                            #
#
# /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_dp_10_resolution_21_sh_number_4000_temperature_400_velocity_5_wc_geo_area_100_wc_ncells_32_wc_thickness_40/RESULT/Linf_resnorm.dat_cluster
# #  1: Iteration                                                  #
# #  2: Pres-Divmax. residue (begin), global block number          #
#
# #  3: Pres-Divmax. residue (begin), i-index                      #
#
# #  4: Pres-Divmax. residue (begin), j-index                      #
#
# #  5: Pres-Divmax. residue (begin), k-index                      #
#
# #  6: Pres-Divmax. residue (  end), global block number          #
#
# #  7: Pres-Divmax. residue (  end), i-index                      #
#
# #  8: Pres-Divmax. residue (  end), j-index                      #
#
# #  9: Pres-Divmax. residue (  end), k-index                      #
#
# # 10: Pres-DivLinf(   begin)                                     #
#
# # 11: Pres-DivLinf(     end)                                     #
#
# # 12: Pres-DivLinf(relative)                                     #
#
# # 13: U-Velocitymax. residue (begin), global block number        #
#
# # 14: U-Velocitymax. residue (begin), i-index                    #
#
# # 15: U-Velocitymax. residue (begin), j-index                    #
#
# # 16: U-Velocitymax. residue (begin), k-index                    #
#
# # 17: U-Velocitymax. residue (  end), global block number        #
#
# # 18: U-Velocitymax. residue (  end), i-index                    #
#
# # 19: U-Velocitymax. residue (  end), j-index                    #
#
# # 20: U-Velocitymax. residue (  end), k-index                    #
#
# # 21: U-VelocityLinf(   begin)                                   #
#
# # 22: U-VelocityLinf(     end)                                   #
#
# # 23: U-VelocityLinf(relative)                                   #
#
# # 24: Temperaturemax. residue (begin), global block number       #
#
# # 25: Temperaturemax. residue (begin), i-index                   #
#
# # 26: Temperaturemax. residue (begin), j-index                   #
#
# # 27: Temperaturemax. residue (begin), k-index                   #
#
# # 28: Temperaturemax. residue (  end), global block number       #
#
# # 29: Temperaturemax. residue (  end), i-index                   #
#
# # 30: Temperaturemax. residue (  end), j-index                   #
#
# # 31: Temperaturemax. residue (  end), k-index                   #
#
# # 32: TemperatureLinf(   begin)                                  #
#
# # 33: TemperatureLinf(     end)                                  #
#
# # 34: TemperatureLinf(relative)                                  #
#
# # 35: Phase01_Species01max. residue (begin), global block number #
#
# # 36: Phase01_Species01max. residue (begin), i-index             #
#
# # 37: Phase01_Species01max. residue (begin), j-index             #
#
# # 38: Phase01_Species01max. residue (begin), k-index             #
#
# # 39: Phase01_Species01max. residue (  end), global block number #
#
# # 40: Phase01_Species01max. residue (  end), i-index             #
#
# # 41: Phase01_Species01max. residue (  end), j-index             #
#
# # 42: Phase01_Species01max. residue (  end), k-index             #
#
# # 43: Phase01_Species01Linf(   begin)                            #
#
# # 44: Phase01_Species01Linf(     end)                            #
#
# # 45: Phase01_Species01Linf(relative)                            #
#
# # 46: Phase01_Species02max. residue (begin), global block number #
#
# # 47: Phase01_Species02max. residue (begin), i-index             #
#
# # 48: Phase01_Species02max. residue (begin), j-index             #
#
# # 49: Phase01_Species02max. residue (begin), k-index             #
#
# # 50: Phase01_Species02max. residue (  end), global block number #
#
# # 51: Phase01_Species02max. residue (  end), i-index             #
#
# # 52: Phase01_Species02max. residue (  end), j-index             #
#
# # 53: Phase01_Species02max. residue (  end), k-index             #
#
# # 54: Phase01_Species02Linf(   begin)                            #
#
# # 55: Phase01_Species02Linf(     end)                            #
#
# # 56: Phase01_Species02Linf(relative)                            #
#
# # 57: Phase01_Species03max. residue (begin), global block number #
#
# # 58: Phase01_Species03max. residue (begin), i-index             #
#
# # 59: Phase01_Species03max. residue (begin), j-index             #
#
# # 60: Phase01_Species03max. residue (begin), k-index             #
#
# # 61: Phase01_Species03max. residue (  end), global block number #
#
# # 62: Phase01_Species03max. residue (  end), i-index             #
#
# # 63: Phase01_Species03max. residue (  end), j-index             #
#
# # 64: Phase01_Species03max. residue (  end), k-index             #
#
# # 65: Phase01_Species03Linf(   begin)                            #
#
# # 66: Phase01_Species03Linf(     end)                            #
#
# # 67: Phase01_Species03Linf(relative)                            #
#
# # 68: Phase01_Species04max. residue (begin), global block number #
#
# # 69: Phase01_Species04max. residue (begin), i-index             #
#
# # 70: Phase01_Species04max. residue (begin), j-index             #
#
# # 71: Phase01_Species04max. residue (begin), k-index             #
#
# # 72: Phase01_Species04max. residue (  end), global block number #
#
# # 73: Phase01_Species04max. residue (  end), i-index             #
#
# # 74: Phase01_Species04max. residue (  end), j-index             #
#
# # 75: Phase01_Species04max. residue (  end), k-index             #
#
# # 76: Phase01_Species04Linf(   begin)                            #
#
# # 77: Phase01_Species04Linf(     end)                            #
#
# # 78: Phase01_Species04Linf(relative)                            #
#
# # 79: Phase01_Species05max. residue (begin), global block number #
#
# # 80: Phase01_Species05max. residue (begin), i-index             #
#
# # 81: Phase01_Species05max. residue (begin), j-index             #
#
# # 82: Phase01_Species05max. residue (begin), k-index             #
#
# # 83: Phase01_Species05max. residue (  end), global block number #
#
# # 84: Phase01_Species05max. residue (  end), i-index             #
#
# # 85: Phase01_Species05max. residue (  end), j-index             #
#
# # 86: Phase01_Species05max. residue (  end), k-index             #
#
# # 87: Phase01_Species05Linf(   begin)                            #
#
# # 88: Phase01_Species05Linf(     end)                            #
#
# # 89: Phase01_Species05Linf(relative)                            #
#
# /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_dp_10_resolution_21_sh_number_4000_temperature_400_velocity_5_wc_geo_area_1_wc_ncells_64_wc_thickness_40/RESULT/Linf_resnorm.dat_cluster
# #  1: Iteration                                                  #
# #  2: Pres-Divmax. residue (begin), global block number          #
#
# #  3: Pres-Divmax. residue (begin), i-index                      #
#
# #  4: Pres-Divmax. residue (begin), j-index                      #
#
# #  5: Pres-Divmax. residue (begin), k-index                      #
#
# #  6: Pres-Divmax. residue (  end), global block number          #
#
# #  7: Pres-Divmax. residue (  end), i-index                      #
#
# #  8: Pres-Divmax. residue (  end), j-index                      #
#
# #  9: Pres-Divmax. residue (  end), k-index                      #
#
# # 10: Pres-DivLinf(   begin)                                     #
#
# # 11: Pres-DivLinf(     end)                                     #
#
# # 12: Pres-DivLinf(relative)                                     #
#
# # 13: U-Velocitymax. residue (begin), global block number        #
#
# # 14: U-Velocitymax. residue (begin), i-index                    #
#
# # 15: U-Velocitymax. residue (begin), j-index                    #
#
# # 16: U-Velocitymax. residue (begin), k-index                    #
#
# # 17: U-Velocitymax. residue (  end), global block number        #
#
# # 18: U-Velocitymax. residue (  end), i-index                    #
#
# # 19: U-Velocitymax. residue (  end), j-index                    #
#
# # 20: U-Velocitymax. residue (  end), k-index                    #
#
# # 21: U-VelocityLinf(   begin)                                   #
#
# # 22: U-VelocityLinf(     end)                                   #
#
# # 23: U-VelocityLinf(relative)                                   #
#
# # 24: Temperaturemax. residue (begin), global block number       #
#
# # 25: Temperaturemax. residue (begin), i-index                   #
#
# # 26: Temperaturemax. residue (begin), j-index                   #
#
# # 27: Temperaturemax. residue (begin), k-index                   #
#
# # 28: Temperaturemax. residue (  end), global block number       #
#
# # 29: Temperaturemax. residue (  end), i-index                   #
#
# # 30: Temperaturemax. residue (  end), j-index                   #
#
# # 31: Temperaturemax. residue (  end), k-index                   #
#
# # 32: TemperatureLinf(   begin)                                  #
#
# # 33: TemperatureLinf(     end)                                  #
#
# # 34: TemperatureLinf(relative)                                  #
#
# # 35: Phase01_Species01max. residue (begin), global block number #
#
# # 36: Phase01_Species01max. residue (begin), i-index             #
#
# # 37: Phase01_Species01max. residue (begin), j-index             #
#
# # 38: Phase01_Species01max. residue (begin), k-index             #
#
# # 39: Phase01_Species01max. residue (  end), global block number #
#
# # 40: Phase01_Species01max. residue (  end), i-index             #
#
# # 41: Phase01_Species01max. residue (  end), j-index             #
#
# # 42: Phase01_Species01max. residue (  end), k-index             #
#
# # 43: Phase01_Species01Linf(   begin)                            #
#
# # 44: Phase01_Species01Linf(     end)                            #
#
# # 45: Phase01_Species01Linf(relative)                            #
#
# # 46: Phase01_Species02max. residue (begin), global block number #
#
# # 47: Phase01_Species02max. residue (begin), i-index             #
#
# # 48: Phase01_Species02max. residue (begin), j-index             #
#
# # 49: Phase01_Species02max. residue (begin), k-index             #
#
# # 50: Phase01_Species02max. residue (  end), global block number #
#
# # 51: Phase01_Species02max. residue (  end), i-index             #
#
# # 52: Phase01_Species02max. residue (  end), j-index             #
#
# # 53: Phase01_Species02max. residue (  end), k-index             #
#
# # 54: Phase01_Species02Linf(   begin)                            #
#
# # 55: Phase01_Species02Linf(     end)                            #
#
# # 56: Phase01_Species02Linf(relative)                            #
#
# # 57: Phase01_Species03max. residue (begin), global block number #
#
# # 58: Phase01_Species03max. residue (begin), i-index             #
#
# # 59: Phase01_Species03max. residue (begin), j-index             #
#
# # 60: Phase01_Species03max. residue (begin), k-index             #
#
# # 61: Phase01_Species03max. residue (  end), global block number #
#
# # 62: Phase01_Species03max. residue (  end), i-index             #
#
# # 63: Phase01_Species03max. residue (  end), j-index             #
#
# # 64: Phase01_Species03max. residue (  end), k-index             #
#
# # 65: Phase01_Species03Linf(   begin)                            #
#
# # 66: Phase01_Species03Linf(     end)                            #
#
# # 67: Phase01_Species03Linf(relative)                            #
#
# # 68: Phase01_Species04max. residue (begin), global block number #
#
# # 69: Phase01_Species04max. residue (begin), i-index             #
#
# # 70: Phase01_Species04max. residue (begin), j-index             #
#
# # 71: Phase01_Species04max. residue (begin), k-index             #
#
# # 72: Phase01_Species04max. residue (  end), global block number #
#
# # 73: Phase01_Species04max. residue (  end), i-index             #
#
# # 74: Phase01_Species04max. residue (  end), j-index             #
#
# # 75: Phase01_Species04max. residue (  end), k-index             #
#
# # 76: Phase01_Species04Linf(   begin)                            #
#
# # 77: Phase01_Species04Linf(     end)                            #
#
# # 78: Phase01_Species04Linf(relative)                            #
#
# # 79: Phase01_Species05max. residue (begin), global block number #
#
# # 80: Phase01_Species05max. residue (begin), i-index             #
#
# # 81: Phase01_Species05max. residue (begin), j-index             #
#
# # 82: Phase01_Species05max. residue (begin), k-index             #
#
# # 83: Phase01_Species05max. residue (  end), global block number #
#
# # 84: Phase01_Species05max. residue (  end), i-index             #
#
# # 85: Phase01_Species05max. residue (  end), j-index             #
#
# # 86: Phase01_Species05max. residue (  end), k-index             #
#
# # 87: Phase01_Species05Linf(   begin)                            #
#
# # 88: Phase01_Species05Linf(     end)                            #
#
# # 89: Phase01_Species05Linf(relative)                            #
#
# /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_dp_10_resolution_21_sh_number_4000_temperature_400_velocity_5_wc_geo_area_100_wc_ncells_64_wc_thickness_40/RESULT/Linf_resnorm.dat_cluster
# #  1: Iteration                                                  #
# #  2: Pres-Divmax. residue (begin), global block number          #
#
# #  3: Pres-Divmax. residue (begin), i-index                      #
#
# #  4: Pres-Divmax. residue (begin), j-index                      #
#
# #  5: Pres-Divmax. residue (begin), k-index                      #
#
# #  6: Pres-Divmax. residue (  end), global block number          #
#
# #  7: Pres-Divmax. residue (  end), i-index                      #
#
# #  8: Pres-Divmax. residue (  end), j-index                      #
#
# #  9: Pres-Divmax. residue (  end), k-index                      #
#
# # 10: Pres-DivLinf(   begin)                                     #
#
# # 11: Pres-DivLinf(     end)                                     #
#
# # 12: Pres-DivLinf(relative)                                     #
#
# # 13: U-Velocitymax. residue (begin), global block number        #
#
# # 14: U-Velocitymax. residue (begin), i-index                    #
#
# # 15: U-Velocitymax. residue (begin), j-index                    #
#
# # 16: U-Velocitymax. residue (begin), k-index                    #
#
# # 17: U-Velocitymax. residue (  end), global block number        #
#
# # 18: U-Velocitymax. residue (  end), i-index                    #
#
# # 19: U-Velocitymax. residue (  end), j-index                    #
#
# # 20: U-Velocitymax. residue (  end), k-index                    #
#
# # 21: U-VelocityLinf(   begin)                                   #
#
# # 22: U-VelocityLinf(     end)                                   #
#
# # 23: U-VelocityLinf(relative)                                   #
#
# # 24: Temperaturemax. residue (begin), global block number       #
#
# # 25: Temperaturemax. residue (begin), i-index                   #
#
# # 26: Temperaturemax. residue (begin), j-index                   #
#
# # 27: Temperaturemax. residue (begin), k-index                   #
#
# # 28: Temperaturemax. residue (  end), global block number       #
#
# # 29: Temperaturemax. residue (  end), i-index                   #
#
# # 30: Temperaturemax. residue (  end), j-index                   #
#
# # 31: Temperaturemax. residue (  end), k-index                   #
#
# # 32: TemperatureLinf(   begin)                                  #
#
# # 33: TemperatureLinf(     end)                                  #
#
# # 34: TemperatureLinf(relative)                                  #
#
# # 35: Phase01_Species01max. residue (begin), global block number #
#
# # 36: Phase01_Species01max. residue (begin), i-index             #
#
# # 37: Phase01_Species01max. residue (begin), j-index             #
#
# # 38: Phase01_Species01max. residue (begin), k-index             #
#
# # 39: Phase01_Species01max. residue (  end), global block number #
#
# # 40: Phase01_Species01max. residue (  end), i-index             #
#
# # 41: Phase01_Species01max. residue (  end), j-index             #
#
# # 42: Phase01_Species01max. residue (  end), k-index             #
#
# # 43: Phase01_Species01Linf(   begin)                            #
#
# # 44: Phase01_Species01Linf(     end)                            #
#
# # 45: Phase01_Species01Linf(relative)                            #
#
# # 46: Phase01_Species02max. residue (begin), global block number #
#
# # 47: Phase01_Species02max. residue (begin), i-index             #
#
# # 48: Phase01_Species02max. residue (begin), j-index             #
#
# # 49: Phase01_Species02max. residue (begin), k-index             #
#
# # 50: Phase01_Species02max. residue (  end), global block number #
#
# # 51: Phase01_Species02max. residue (  end), i-index             #
#
# # 52: Phase01_Species02max. residue (  end), j-index             #
#
# # 53: Phase01_Species02max. residue (  end), k-index             #
#
# # 54: Phase01_Species02Linf(   begin)                            #
#
# # 55: Phase01_Species02Linf(     end)                            #
#
# # 56: Phase01_Species02Linf(relative)                            #
#
# # 57: Phase01_Species03max. residue (begin), global block number #
#
# # 58: Phase01_Species03max. residue (begin), i-index             #
#
# # 59: Phase01_Species03max. residue (begin), j-index             #
#
# # 60: Phase01_Species03max. residue (begin), k-index             #
#
# # 61: Phase01_Species03max. residue (  end), global block number #
#
# # 62: Phase01_Species03max. residue (  end), i-index             #
#
# # 63: Phase01_Species03max. residue (  end), j-index             #
#
# # 64: Phase01_Species03max. residue (  end), k-index             #
#
# # 65: Phase01_Species03Linf(   begin)                            #
#
# # 66: Phase01_Species03Linf(     end)                            #
#
# # 67: Phase01_Species03Linf(relative)                            #
#
# # 68: Phase01_Species04max. residue (begin), global block number #
#
# # 69: Phase01_Species04max. residue (begin), i-index             #
#
# # 70: Phase01_Species04max. residue (begin), j-index             #
#
# # 71: Phase01_Species04max. residue (begin), k-index             #
#
# # 72: Phase01_Species04max. residue (  end), global block number #
#
# # 73: Phase01_Species04max. residue (  end), i-index             #
#
# # 74: Phase01_Species04max. residue (  end), j-index             #
#
# # 75: Phase01_Species04max. residue (  end), k-index             #
#
# # 76: Phase01_Species04Linf(   begin)                            #
#
# # 77: Phase01_Species04Linf(     end)                            #
#
# # 78: Phase01_Species04Linf(relative)                            #
#
# # 79: Phase01_Species05max. residue (begin), global block number #
#
# # 80: Phase01_Species05max. residue (begin), i-index             #
#
# # 81: Phase01_Species05max. residue (begin), j-index             #
#
# # 82: Phase01_Species05max. residue (begin), k-index             #
#
# # 83: Phase01_Species05max. residue (  end), global block number #
#
# # 84: Phase01_Species05max. residue (  end), i-index             #
#
# # 85: Phase01_Species05max. residue (  end), j-index             #
#
# # 86: Phase01_Species05max. residue (  end), k-index             #
#
# # 87: Phase01_Species05Linf(   begin)                            #
#
# # 88: Phase01_Species05Linf(     end)                            #
#
# # 89: Phase01_Species05Linf(relative)                            #
#
# /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_dp_10_resolution_41_sh_number_4000_temperature_400_velocity_5_wc_geo_area_1_wc_ncells_32_wc_thickness_40/RESULT/Linf_resnorm.dat_cluster
# #  1: Iteration                                                  #
# #  2: Pres-Divmax. residue (begin), global block number          #
#
# #  3: Pres-Divmax. residue (begin), i-index                      #
#
# #  4: Pres-Divmax. residue (begin), j-index                      #
#
# #  5: Pres-Divmax. residue (begin), k-index                      #
#
# #  6: Pres-Divmax. residue (  end), global block number          #
#
# #  7: Pres-Divmax. residue (  end), i-index                      #
#
# #  8: Pres-Divmax. residue (  end), j-index                      #
#
# #  9: Pres-Divmax. residue (  end), k-index                      #
#
# # 10: Pres-DivLinf(   begin)                                     #
#
# # 11: Pres-DivLinf(     end)                                     #
#
# # 12: Pres-DivLinf(relative)                                     #
#
# # 13: U-Velocitymax. residue (begin), global block number        #
#
# # 14: U-Velocitymax. residue (begin), i-index                    #
#
# # 15: U-Velocitymax. residue (begin), j-index                    #
#
# # 16: U-Velocitymax. residue (begin), k-index                    #
#
# # 17: U-Velocitymax. residue (  end), global block number        #
#
# # 18: U-Velocitymax. residue (  end), i-index                    #
#
# # 19: U-Velocitymax. residue (  end), j-index                    #
#
# # 20: U-Velocitymax. residue (  end), k-index                    #
#
# # 21: U-VelocityLinf(   begin)                                   #
#
# # 22: U-VelocityLinf(     end)                                   #
#
# # 23: U-VelocityLinf(relative)                                   #
#
# # 24: Temperaturemax. residue (begin), global block number       #
#
# # 25: Temperaturemax. residue (begin), i-index                   #
#
# # 26: Temperaturemax. residue (begin), j-index                   #
#
# # 27: Temperaturemax. residue (begin), k-index                   #
#
# # 28: Temperaturemax. residue (  end), global block number       #
#
# # 29: Temperaturemax. residue (  end), i-index                   #
#
# # 30: Temperaturemax. residue (  end), j-index                   #
#
# # 31: Temperaturemax. residue (  end), k-index                   #
#
# # 32: TemperatureLinf(   begin)                                  #
#
# # 33: TemperatureLinf(     end)                                  #
#
# # 34: TemperatureLinf(relative)                                  #
#
# # 35: Phase01_Species01max. residue (begin), global block number #
#
# # 36: Phase01_Species01max. residue (begin), i-index             #
#
# # 37: Phase01_Species01max. residue (begin), j-index             #
#
# # 38: Phase01_Species01max. residue (begin), k-index             #
#
# # 39: Phase01_Species01max. residue (  end), global block number #
#
# # 40: Phase01_Species01max. residue (  end), i-index             #
#
# # 41: Phase01_Species01max. residue (  end), j-index             #
#
# # 42: Phase01_Species01max. residue (  end), k-index             #
#
# # 43: Phase01_Species01Linf(   begin)                            #
#
# # 44: Phase01_Species01Linf(     end)                            #
#
# # 45: Phase01_Species01Linf(relative)                            #
#
# # 46: Phase01_Species02max. residue (begin), global block number #
#
# # 47: Phase01_Species02max. residue (begin), i-index             #
#
# # 48: Phase01_Species02max. residue (begin), j-index             #
#
# # 49: Phase01_Species02max. residue (begin), k-index             #
#
# # 50: Phase01_Species02max. residue (  end), global block number #
#
# # 51: Phase01_Species02max. residue (  end), i-index             #
#
# # 52: Phase01_Species02max. residue (  end), j-index             #
#
# # 53: Phase01_Species02max. residue (  end), k-index             #
#
# # 54: Phase01_Species02Linf(   begin)                            #
#
# # 55: Phase01_Species02Linf(     end)                            #
#
# # 56: Phase01_Species02Linf(relative)                            #
#
# # 57: Phase01_Species03max. residue (begin), global block number #
#
# # 58: Phase01_Species03max. residue (begin), i-index             #
#
# # 59: Phase01_Species03max. residue (begin), j-index             #
#
# # 60: Phase01_Species03max. residue (begin), k-index             #
#
# # 61: Phase01_Species03max. residue (  end), global block number #
#
# # 62: Phase01_Species03max. residue (  end), i-index             #
#
# # 63: Phase01_Species03max. residue (  end), j-index             #
#
# # 64: Phase01_Species03max. residue (  end), k-index             #
#
# # 65: Phase01_Species03Linf(   begin)                            #
#
# # 66: Phase01_Species03Linf(     end)                            #
#
# # 67: Phase01_Species03Linf(relative)                            #
#
# # 68: Phase01_Species04max. residue (begin), global block number #
#
# # 69: Phase01_Species04max. residue (begin), i-index             #
#
# # 70: Phase01_Species04max. residue (begin), j-index             #
#
# # 71: Phase01_Species04max. residue (begin), k-index             #
#
# # 72: Phase01_Species04max. residue (  end), global block number #
#
# # 73: Phase01_Species04max. residue (  end), i-index             #
#
# # 74: Phase01_Species04max. residue (  end), j-index             #
#
# # 75: Phase01_Species04max. residue (  end), k-index             #
#
# # 76: Phase01_Species04Linf(   begin)                            #
#
# # 77: Phase01_Species04Linf(     end)                            #
#
# # 78: Phase01_Species04Linf(relative)                            #
#
# # 79: Phase01_Species05max. residue (begin), global block number #
#
# # 80: Phase01_Species05max. residue (begin), i-index             #
#
# # 81: Phase01_Species05max. residue (begin), j-index             #
#
# # 82: Phase01_Species05max. residue (begin), k-index             #
#
# # 83: Phase01_Species05max. residue (  end), global block number #
#
# # 84: Phase01_Species05max. residue (  end), i-index             #
#
# # 85: Phase01_Species05max. residue (  end), j-index             #
#
# # 86: Phase01_Species05max. residue (  end), k-index             #
#
# # 87: Phase01_Species05Linf(   begin)                            #
#
# # 88: Phase01_Species05Linf(     end)                            #
#
# # 89: Phase01_Species05Linf(relative)                            #
#
# /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_dp_10_resolution_41_sh_number_4000_temperature_400_velocity_5_wc_geo_area_100_wc_ncells_32_wc_thickness_40/RESULT/Linf_resnorm.dat_cluster
# #  1: Iteration                                                  #
# #  2: Pres-Divmax. residue (begin), global block number          #
#
# #  3: Pres-Divmax. residue (begin), i-index                      #
#
# #  4: Pres-Divmax. residue (begin), j-index                      #
#
# #  5: Pres-Divmax. residue (begin), k-index                      #
#
# #  6: Pres-Divmax. residue (  end), global block number          #
#
# #  7: Pres-Divmax. residue (  end), i-index                      #
#
# #  8: Pres-Divmax. residue (  end), j-index                      #
#
# #  9: Pres-Divmax. residue (  end), k-index                      #
#
# # 10: Pres-DivLinf(   begin)                                     #
#
# # 11: Pres-DivLinf(     end)                                     #
#
# # 12: Pres-DivLinf(relative)                                     #
#
# # 13: U-Velocitymax. residue (begin), global block number        #
#
# # 14: U-Velocitymax. residue (begin), i-index                    #
#
# # 15: U-Velocitymax. residue (begin), j-index                    #
#
# # 16: U-Velocitymax. residue (begin), k-index                    #
#
# # 17: U-Velocitymax. residue (  end), global block number        #
#
# # 18: U-Velocitymax. residue (  end), i-index                    #
#
# # 19: U-Velocitymax. residue (  end), j-index                    #
#
# # 20: U-Velocitymax. residue (  end), k-index                    #
#
# # 21: U-VelocityLinf(   begin)                                   #
#
# # 22: U-VelocityLinf(     end)                                   #
#
# # 23: U-VelocityLinf(relative)                                   #
#
# # 24: Temperaturemax. residue (begin), global block number       #
#
# # 25: Temperaturemax. residue (begin), i-index                   #
#
# # 26: Temperaturemax. residue (begin), j-index                   #
#
# # 27: Temperaturemax. residue (begin), k-index                   #
#
# # 28: Temperaturemax. residue (  end), global block number       #
#
# # 29: Temperaturemax. residue (  end), i-index                   #
#
# # 30: Temperaturemax. residue (  end), j-index                   #
#
# # 31: Temperaturemax. residue (  end), k-index                   #
#
# # 32: TemperatureLinf(   begin)                                  #
#
# # 33: TemperatureLinf(     end)                                  #
#
# # 34: TemperatureLinf(relative)                                  #
#
# # 35: Phase01_Species01max. residue (begin), global block number #
#
# # 36: Phase01_Species01max. residue (begin), i-index             #
#
# # 37: Phase01_Species01max. residue (begin), j-index             #
#
# # 38: Phase01_Species01max. residue (begin), k-index             #
#
# # 39: Phase01_Species01max. residue (  end), global block number #
#
# # 40: Phase01_Species01max. residue (  end), i-index             #
#
# # 41: Phase01_Species01max. residue (  end), j-index             #
#
# # 42: Phase01_Species01max. residue (  end), k-index             #
#
# # 43: Phase01_Species01Linf(   begin)                            #
#
# # 44: Phase01_Species01Linf(     end)                            #
#
# # 45: Phase01_Species01Linf(relative)                            #
#
# # 46: Phase01_Species02max. residue (begin), global block number #
#
# # 47: Phase01_Species02max. residue (begin), i-index             #
#
# # 48: Phase01_Species02max. residue (begin), j-index             #
#
# # 49: Phase01_Species02max. residue (begin), k-index             #
#
# # 50: Phase01_Species02max. residue (  end), global block number #
#
# # 51: Phase01_Species02max. residue (  end), i-index             #
#
# # 52: Phase01_Species02max. residue (  end), j-index             #
#
# # 53: Phase01_Species02max. residue (  end), k-index             #
#
# # 54: Phase01_Species02Linf(   begin)                            #
#
# # 55: Phase01_Species02Linf(     end)                            #
#
# # 56: Phase01_Species02Linf(relative)                            #
#
# # 57: Phase01_Species03max. residue (begin), global block number #
#
# # 58: Phase01_Species03max. residue (begin), i-index             #
#
# # 59: Phase01_Species03max. residue (begin), j-index             #
#
# # 60: Phase01_Species03max. residue (begin), k-index             #
#
# # 61: Phase01_Species03max. residue (  end), global block number #
#
# # 62: Phase01_Species03max. residue (  end), i-index             #
#
# # 63: Phase01_Species03max. residue (  end), j-index             #
#
# # 64: Phase01_Species03max. residue (  end), k-index             #
#
# # 65: Phase01_Species03Linf(   begin)                            #
#
# # 66: Phase01_Species03Linf(     end)                            #
#
# # 67: Phase01_Species03Linf(relative)                            #
#
# # 68: Phase01_Species04max. residue (begin), global block number #
#
# # 69: Phase01_Species04max. residue (begin), i-index             #
#
# # 70: Phase01_Species04max. residue (begin), j-index             #
#
# # 71: Phase01_Species04max. residue (begin), k-index             #
#
# # 72: Phase01_Species04max. residue (  end), global block number #
#
# # 73: Phase01_Species04max. residue (  end), i-index             #
#
# # 74: Phase01_Species04max. residue (  end), j-index             #
#
# # 75: Phase01_Species04max. residue (  end), k-index             #
#
# # 76: Phase01_Species04Linf(   begin)                            #
#
# # 77: Phase01_Species04Linf(     end)                            #
#
# # 78: Phase01_Species04Linf(relative)                            #
#
# # 79: Phase01_Species05max. residue (begin), global block number #
#
# # 80: Phase01_Species05max. residue (begin), i-index             #
#
# # 81: Phase01_Species05max. residue (begin), j-index             #
#
# # 82: Phase01_Species05max. residue (begin), k-index             #
#
# # 83: Phase01_Species05max. residue (  end), global block number #
#
# # 84: Phase01_Species05max. residue (  end), i-index             #
#
# # 85: Phase01_Species05max. residue (  end), j-index             #
#
# # 86: Phase01_Species05max. residue (  end), k-index             #
#
# # 87: Phase01_Species05Linf(   begin)                            #
#
# # 88: Phase01_Species05Linf(     end)                            #
#
# # 89: Phase01_Species05Linf(relative)                            #
#
# /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_dp_10_resolution_41_sh_number_4000_temperature_400_velocity_5_wc_geo_area_1_wc_ncells_64_wc_thickness_40/RESULT/Linf_resnorm.dat_cluster
# #  1: Iteration                                                  #
# #  2: Pres-Divmax. residue (begin), global block number          #
#
# #  3: Pres-Divmax. residue (begin), i-index                      #
#
# #  4: Pres-Divmax. residue (begin), j-index                      #
#
# #  5: Pres-Divmax. residue (begin), k-index                      #
#
# #  6: Pres-Divmax. residue (  end), global block number          #
#
# #  7: Pres-Divmax. residue (  end), i-index                      #
#
# #  8: Pres-Divmax. residue (  end), j-index                      #
#
# #  9: Pres-Divmax. residue (  end), k-index                      #
#
# # 10: Pres-DivLinf(   begin)                                     #
#
# # 11: Pres-DivLinf(     end)                                     #
#
# # 12: Pres-DivLinf(relative)                                     #
#
# # 13: U-Velocitymax. residue (begin), global block number        #
#
# # 14: U-Velocitymax. residue (begin), i-index                    #
#
# # 15: U-Velocitymax. residue (begin), j-index                    #
#
# # 16: U-Velocitymax. residue (begin), k-index                    #
#
# # 17: U-Velocitymax. residue (  end), global block number        #
#
# # 18: U-Velocitymax. residue (  end), i-index                    #
#
# # 19: U-Velocitymax. residue (  end), j-index                    #
#
# # 20: U-Velocitymax. residue (  end), k-index                    #
#
# # 21: U-VelocityLinf(   begin)                                   #
#
# # 22: U-VelocityLinf(     end)                                   #
#
# # 23: U-VelocityLinf(relative)                                   #
#
# # 24: Temperaturemax. residue (begin), global block number       #
#
# # 25: Temperaturemax. residue (begin), i-index                   #
#
# # 26: Temperaturemax. residue (begin), j-index                   #
#
# # 27: Temperaturemax. residue (begin), k-index                   #
#
# # 28: Temperaturemax. residue (  end), global block number       #
#
# # 29: Temperaturemax. residue (  end), i-index                   #
#
# # 30: Temperaturemax. residue (  end), j-index                   #
#
# # 31: Temperaturemax. residue (  end), k-index                   #
#
# # 32: TemperatureLinf(   begin)                                  #
#
# # 33: TemperatureLinf(     end)                                  #
#
# # 34: TemperatureLinf(relative)                                  #
#
# # 35: Phase01_Species01max. residue (begin), global block number #
#
# # 36: Phase01_Species01max. residue (begin), i-index             #
#
# # 37: Phase01_Species01max. residue (begin), j-index             #
#
# # 38: Phase01_Species01max. residue (begin), k-index             #
#
# # 39: Phase01_Species01max. residue (  end), global block number #
#
# # 40: Phase01_Species01max. residue (  end), i-index             #
#
# # 41: Phase01_Species01max. residue (  end), j-index             #
#
# # 42: Phase01_Species01max. residue (  end), k-index             #
#
# # 43: Phase01_Species01Linf(   begin)                            #
#
# # 44: Phase01_Species01Linf(     end)                            #
#
# # 45: Phase01_Species01Linf(relative)                            #
#
# # 46: Phase01_Species02max. residue (begin), global block number #
#
# # 47: Phase01_Species02max. residue (begin), i-index             #
#
# # 48: Phase01_Species02max. residue (begin), j-index             #
#
# # 49: Phase01_Species02max. residue (begin), k-index             #
#
# # 50: Phase01_Species02max. residue (  end), global block number #
#
# # 51: Phase01_Species02max. residue (  end), i-index             #
#
# # 52: Phase01_Species02max. residue (  end), j-index             #
#
# # 53: Phase01_Species02max. residue (  end), k-index             #
#
# # 54: Phase01_Species02Linf(   begin)                            #
#
# # 55: Phase01_Species02Linf(     end)                            #
#
# # 56: Phase01_Species02Linf(relative)                            #
#
# # 57: Phase01_Species03max. residue (begin), global block number #
#
# # 58: Phase01_Species03max. residue (begin), i-index             #
#
# # 59: Phase01_Species03max. residue (begin), j-index             #
#
# # 60: Phase01_Species03max. residue (begin), k-index             #
#
# # 61: Phase01_Species03max. residue (  end), global block number #
#
# # 62: Phase01_Species03max. residue (  end), i-index             #
#
# # 63: Phase01_Species03max. residue (  end), j-index             #
#
# # 64: Phase01_Species03max. residue (  end), k-index             #
#
# # 65: Phase01_Species03Linf(   begin)                            #
#
# # 66: Phase01_Species03Linf(     end)                            #
#
# # 67: Phase01_Species03Linf(relative)                            #
#
# # 68: Phase01_Species04max. residue (begin), global block number #
#
# # 69: Phase01_Species04max. residue (begin), i-index             #
#
# # 70: Phase01_Species04max. residue (begin), j-index             #
#
# # 71: Phase01_Species04max. residue (begin), k-index             #
#
# # 72: Phase01_Species04max. residue (  end), global block number #
#
# # 73: Phase01_Species04max. residue (  end), i-index             #
#
# # 74: Phase01_Species04max. residue (  end), j-index             #
#
# # 75: Phase01_Species04max. residue (  end), k-index             #
#
# # 76: Phase01_Species04Linf(   begin)                            #
#
# # 77: Phase01_Species04Linf(     end)                            #
#
# # 78: Phase01_Species04Linf(relative)                            #
#
# # 79: Phase01_Species05max. residue (begin), global block number #
#
# # 80: Phase01_Species05max. residue (begin), i-index             #
#
# # 81: Phase01_Species05max. residue (begin), j-index             #
#
# # 82: Phase01_Species05max. residue (begin), k-index             #
#
# # 83: Phase01_Species05max. residue (  end), global block number #
#
# # 84: Phase01_Species05max. residue (  end), i-index             #
#
# # 85: Phase01_Species05max. residue (  end), j-index             #
#
# # 86: Phase01_Species05max. residue (  end), k-index             #
#
# # 87: Phase01_Species05Linf(   begin)                            #
#
# # 88: Phase01_Species05Linf(     end)                            #
#
# # 89: Phase01_Species05Linf(relative)                            #
#
# /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_dp_10_resolution_41_sh_number_4000_temperature_400_velocity_5_wc_geo_area_100_wc_ncells_64_wc_thickness_40/RESULT/Linf_resnorm.dat_cluster
# #  1: Iteration                                                  #
# #  2: Pres-Divmax. residue (begin), global block number          #
#
# #  3: Pres-Divmax. residue (begin), i-index                      #
#
# #  4: Pres-Divmax. residue (begin), j-index                      #
#
# #  5: Pres-Divmax. residue (begin), k-index                      #
#
# #  6: Pres-Divmax. residue (  end), global block number          #
#
# #  7: Pres-Divmax. residue (  end), i-index                      #
#
# #  8: Pres-Divmax. residue (  end), j-index                      #
#
# #  9: Pres-Divmax. residue (  end), k-index                      #
#
# # 10: Pres-DivLinf(   begin)                                     #
#
# # 11: Pres-DivLinf(     end)                                     #
#
# # 12: Pres-DivLinf(relative)                                     #
#
# # 13: U-Velocitymax. residue (begin), global block number        #
#
# # 14: U-Velocitymax. residue (begin), i-index                    #
#
# # 15: U-Velocitymax. residue (begin), j-index                    #
#
# # 16: U-Velocitymax. residue (begin), k-index                    #
#
# # 17: U-Velocitymax. residue (  end), global block number        #
#
# # 18: U-Velocitymax. residue (  end), i-index                    #
#
# # 19: U-Velocitymax. residue (  end), j-index                    #
#
# # 20: U-Velocitymax. residue (  end), k-index                    #
#
# # 21: U-VelocityLinf(   begin)                                   #
#
# # 22: U-VelocityLinf(     end)                                   #
#
# # 23: U-VelocityLinf(relative)                                   #
#
# # 24: Temperaturemax. residue (begin), global block number       #
#
# # 25: Temperaturemax. residue (begin), i-index                   #
#
# # 26: Temperaturemax. residue (begin), j-index                   #
#
# # 27: Temperaturemax. residue (begin), k-index                   #
#
# # 28: Temperaturemax. residue (  end), global block number       #
#
# # 29: Temperaturemax. residue (  end), i-index                   #
#
# # 30: Temperaturemax. residue (  end), j-index                   #
#
# # 31: Temperaturemax. residue (  end), k-index                   #
#
# # 32: TemperatureLinf(   begin)                                  #
#
# # 33: TemperatureLinf(     end)                                  #
#
# # 34: TemperatureLinf(relative)                                  #
#
# # 35: Phase01_Species01max. residue (begin), global block number #
#
# # 36: Phase01_Species01max. residue (begin), i-index             #
#
# # 37: Phase01_Species01max. residue (begin), j-index             #
#
# # 38: Phase01_Species01max. residue (begin), k-index             #
#
# # 39: Phase01_Species01max. residue (  end), global block number #
#
# # 40: Phase01_Species01max. residue (  end), i-index             #
#
# # 41: Phase01_Species01max. residue (  end), j-index             #
#
# # 42: Phase01_Species01max. residue (  end), k-index             #
#
# # 43: Phase01_Species01Linf(   begin)                            #
#
# # 44: Phase01_Species01Linf(     end)                            #
#
# # 45: Phase01_Species01Linf(relative)                            #
#
# # 46: Phase01_Species02max. residue (begin), global block number #
#
# # 47: Phase01_Species02max. residue (begin), i-index             #
#
# # 48: Phase01_Species02max. residue (begin), j-index             #
#
# # 49: Phase01_Species02max. residue (begin), k-index             #
#
# # 50: Phase01_Species02max. residue (  end), global block number #
#
# # 51: Phase01_Species02max. residue (  end), i-index             #
#
# # 52: Phase01_Species02max. residue (  end), j-index             #
#
# # 53: Phase01_Species02max. residue (  end), k-index             #
#
# # 54: Phase01_Species02Linf(   begin)                            #
#
# # 55: Phase01_Species02Linf(     end)                            #
#
# # 56: Phase01_Species02Linf(relative)                            #
#
# # 57: Phase01_Species03max. residue (begin), global block number #
#
# # 58: Phase01_Species03max. residue (begin), i-index             #
#
# ...
#
# # 42: Phase01_Species01max. residue (  end), k-index             #
#
# # 43: Phase01_Species01Linf(   begin)                            #
#
# # 44: Phase01_Species01Linf(     end)                            #
#
# # 45: Phase01_Species01Linf(relative)                            #
#
# # 46: Phase01_Species02max. residue (begin), global block number #
#
# # 47: Phase01_Species02max. residue (begin), i-index             #
#
# # 48: Phase01_Species02max. residue (begin), j-index             #
#
# # 49: Phase01_Species02max. residue (begin), k-index             #
#
# # 50: Phase01_Species02max. residue (  end), global block number #
#
# # 51: Phase01_Species02max. residue (  end), i-index             #
#
# # 52: Phase01_Species02max. residue (  end), j-index             #
#
# # 53: Phase01_Species02max. residue (  end), k-index             #
#
# # 54: Phase01_Species02Linf(   begin)                            #
#
# # 55: Phase01_Species02Linf(     end)                            #
#
# # 56: Phase01_Species02Linf(relative)                            #
#
# # 57: Phase01_Species03max. residue (begin), global block number #
#
# # 58: Phase01_Species03max. residue (begin), i-index             #
#
# # 59: Phase01_Species03max. residue (begin), j-index             #
#
# # 60: Phase01_Species03max. residue (begin), k-index             #
#
# # 61: Phase01_Species03max. residue (  end), global block number #
#
# # 62: Phase01_Species03max. residue (  end), i-index             #
#
# # 63: Phase01_Species03max. residue (  end), j-index             #
#
# # 64: Phase01_Species03max. residue (  end), k-index             #
#
# # 65: Phase01_Species03Linf(   begin)                            #
#
# # 66: Phase01_Species03Linf(     end)                            #
#
# # 67: Phase01_Species03Linf(relative)                            #
#
# # 68: Phase01_Species04max. residue (begin), global block number #
#
# # 69: Phase01_Species04max. residue (begin), i-index             #
#
# # 70: Phase01_Species04max. residue (begin), j-index             #
#
# # 71: Phase01_Species04max. residue (begin), k-index             #
#
# # 72: Phase01_Species04max. residue (  end), global block number #
#
# # 73: Phase01_Species04max. residue (  end), i-index             #
#
# # 74: Phase01_Species04max. residue (  end), j-index             #
#
# # 75: Phase01_Species04max. residue (  end), k-index             #
#
# # 76: Phase01_Species04Linf(   begin)                            #
#
# # 77: Phase01_Species04Linf(     end)                            #
#
# # 78: Phase01_Species04Linf(relative)                            #
#
# # 79: Phase01_Species05max. residue (begin), global block number #
#
# # 80: Phase01_Species05max. residue (begin), i-index             #
#
# # 81: Phase01_Species05max. residue (begin), j-index             #
#
# # 82: Phase01_Species05max. residue (begin), k-index             #
#
# # 83: Phase01_Species05max. residue (  end), global block number #
#
# # 84: Phase01_Species05max. residue (  end), i-index             #
#
# # 85: Phase01_Species05max. residue (  end), j-index             #
#
# # 86: Phase01_Species05max. residue (  end), k-index             #
#
# # 87: Phase01_Species05Linf(   begin)                            #
#
# # 88: Phase01_Species05Linf(     end)                            #
#
# # 89: Phase01_Species05Linf(relative)                            #
#
# /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_dp_10_resolution_41_sh_number_4000_temperature_1100_velocity_5_wc_geo_area_1_wc_ncells_64_wc_thickness_40/RESULT/Linf_resnorm.dat_cluster
# #  1: Iteration                                                  #
# #  2: Pres-Divmax. residue (begin), global block number          #
#
# #  3: Pres-Divmax. residue (begin), i-index                      #
#
# #  4: Pres-Divmax. residue (begin), j-index                      #
#
# #  5: Pres-Divmax. residue (begin), k-index                      #
#
# #  6: Pres-Divmax. residue (  end), global block number          #
#
# #  7: Pres-Divmax. residue (  end), i-index                      #
#
# #  8: Pres-Divmax. residue (  end), j-index                      #
#
# #  9: Pres-Divmax. residue (  end), k-index                      #
#
# # 10: Pres-DivLinf(   begin)                                     #
#
# # 11: Pres-DivLinf(     end)                                     #
#
# # 12: Pres-DivLinf(relative)                                     #
#
# # 13: U-Velocitymax. residue (begin), global block number        #
#
# # 14: U-Velocitymax. residue (begin), i-index                    #
#
# # 15: U-Velocitymax. residue (begin), j-index                    #
#
# # 16: U-Velocitymax. residue (begin), k-index                    #
#
# # 17: U-Velocitymax. residue (  end), global block number        #
#
# # 18: U-Velocitymax. residue (  end), i-index                    #
#
# # 19: U-Velocitymax. residue (  end), j-index                    #
#
# # 20: U-Velocitymax. residue (  end), k-index                    #
#
# # 21: U-VelocityLinf(   begin)                                   #
#
# # 22: U-VelocityLinf(     end)                                   #
#
# # 23: U-VelocityLinf(relative)                                   #
#
# # 24: Temperaturemax. residue (begin), global block number       #
#
# # 25: Temperaturemax. residue (begin), i-index                   #
#
# # 26: Temperaturemax. residue (begin), j-index                   #
#
# # 27: Temperaturemax. residue (begin), k-index                   #
#
# # 28: Temperaturemax. residue (  end), global block number       #
#
# # 29: Temperaturemax. residue (  end), i-index                   #
#
# # 30: Temperaturemax. residue (  end), j-index                   #
#
# # 31: Temperaturemax. residue (  end), k-index                   #
#
# # 32: TemperatureLinf(   begin)                                  #
#
# # 33: TemperatureLinf(     end)                                  #
#
# # 34: TemperatureLinf(relative)                                  #
#
# # 35: Phase01_Species01max. residue (begin), global block number #
#
# # 36: Phase01_Species01max. residue (begin), i-index             #
#
# # 37: Phase01_Species01max. residue (begin), j-index             #
#
# # 38: Phase01_Species01max. residue (begin), k-index             #
#
# # 39: Phase01_Species01max. residue (  end), global block number #
#
# # 40: Phase01_Species01max. residue (  end), i-index             #
#
# # 41: Phase01_Species01max. residue (  end), j-index             #
#
# # 42: Phase01_Species01max. residue (  end), k-index             #
#
# # 43: Phase01_Species01Linf(   begin)                            #
#
# # 44: Phase01_Species01Linf(     end)                            #
#
# # 45: Phase01_Species01Linf(relative)                            #
#
# # 46: Phase01_Species02max. residue (begin), global block number #
#
# # 47: Phase01_Species02max. residue (begin), i-index             #
#
# # 48: Phase01_Species02max. residue (begin), j-index             #
#
# # 49: Phase01_Species02max. residue (begin), k-index             #
#
# # 50: Phase01_Species02max. residue (  end), global block number #
#
# # 51: Phase01_Species02max. residue (  end), i-index             #
#
# # 52: Phase01_Species02max. residue (  end), j-index             #
#
# # 53: Phase01_Species02max. residue (  end), k-index             #
#
# # 54: Phase01_Species02Linf(   begin)                            #
#
# # 55: Phase01_Species02Linf(     end)                            #
#
# # 56: Phase01_Species02Linf(relative)                            #
#
# # 57: Phase01_Species03max. residue (begin), global block number #
#
# # 58: Phase01_Species03max. residue (begin), i-index             #
#
# # 59: Phase01_Species03max. residue (begin), j-index             #
#
# # 60: Phase01_Species03max. residue (begin), k-index             #
#
# # 61: Phase01_Species03max. residue (  end), global block number #
#
# # 62: Phase01_Species03max. residue (  end), i-index             #
#
# # 63: Phase01_Species03max. residue (  end), j-index             #
#
# # 64: Phase01_Species03max. residue (  end), k-index             #
#
# # 65: Phase01_Species03Linf(   begin)                            #
#
# # 66: Phase01_Species03Linf(     end)                            #
#
# # 67: Phase01_Species03Linf(relative)                            #
#
# # 68: Phase01_Species04max. residue (begin), global block number #
#
# # 69: Phase01_Species04max. residue (begin), i-index             #
#
# # 70: Phase01_Species04max. residue (begin), j-index             #
#
# # 71: Phase01_Species04max. residue (begin), k-index             #
#
# # 72: Phase01_Species04max. residue (  end), global block number #
#
# # 73: Phase01_Species04max. residue (  end), i-index             #
#
# # 74: Phase01_Species04max. residue (  end), j-index             #
#
# # 75: Phase01_Species04max. residue (  end), k-index             #
#
# # 76: Phase01_Species04Linf(   begin)                            #
#
# # 77: Phase01_Species04Linf(     end)                            #
#
# # 78: Phase01_Species04Linf(relative)                            #
#
# # 79: Phase01_Species05max. residue (begin), global block number #
#
# # 80: Phase01_Species05max. residue (begin), i-index             #
#
# # 81: Phase01_Species05max. residue (begin), j-index             #
#
# # 82: Phase01_Species05max. residue (begin), k-index             #
#
# # 83: Phase01_Species05max. residue (  end), global block number #
#
# # 84: Phase01_Species05max. residue (  end), i-index             #
#
# # 85: Phase01_Species05max. residue (  end), j-index             #
#
# # 86: Phase01_Species05max. residue (  end), k-index             #
#
# # 87: Phase01_Species05Linf(   begin)                            #
#
# # 88: Phase01_Species05Linf(     end)                            #
#
# # 89: Phase01_Species05Linf(relative)                            #
#
# /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_dp_10_resolution_41_sh_number_4000_temperature_1100_velocity_5_wc_geo_area_100_wc_ncells_64_wc_thickness_40/RESULT/Linf_resnorm.dat_cluster
# #  1: Iteration                                                  #
# #  2: Pres-Divmax. residue (begin), global block number          #
#
# #  3: Pres-Divmax. residue (begin), i-index                      #
#
# #  4: Pres-Divmax. residue (begin), j-index                      #
#
# #  5: Pres-Divmax. residue (begin), k-index                      #
#
# #  6: Pres-Divmax. residue (  end), global block number          #
#
# #  7: Pres-Divmax. residue (  end), i-index                      #
#
# #  8: Pres-Divmax. residue (  end), j-index                      #
#
# #  9: Pres-Divmax. residue (  end), k-index                      #
#
# # 10: Pres-DivLinf(   begin)                                     #
#
# # 11: Pres-DivLinf(     end)                                     #
#
# # 12: Pres-DivLinf(relative)                                     #
#
# # 13: U-Velocitymax. residue (begin), global block number        #
#
# # 14: U-Velocitymax. residue (begin), i-index                    #
#
# # 15: U-Velocitymax. residue (begin), j-index                    #
#
# # 16: U-Velocitymax. residue (begin), k-index                    #
#
# # 17: U-Velocitymax. residue (  end), global block number        #
#
# # 18: U-Velocitymax. residue (  end), i-index                    #
#
# # 19: U-Velocitymax. residue (  end), j-index                    #
#
# # 20: U-Velocitymax. residue (  end), k-index                    #
#
# # 21: U-VelocityLinf(   begin)                                   #
#
# # 22: U-VelocityLinf(     end)                                   #
#
# # 23: U-VelocityLinf(relative)                                   #
#
# # 24: Temperaturemax. residue (begin), global block number       #
#
# # 25: Temperaturemax. residue (begin), i-index                   #
#
# # 26: Temperaturemax. residue (begin), j-index                   #
#
# # 27: Temperaturemax. residue (begin), k-index                   #
#
# # 28: Temperaturemax. residue (  end), global block number       #
#
# # 29: Temperaturemax. residue (  end), i-index                   #
#
# # 30: Temperaturemax. residue (  end), j-index                   #
#
# # 31: Temperaturemax. residue (  end), k-index                   #
#
# # 32: TemperatureLinf(   begin)                                  #
#
# # 33: TemperatureLinf(     end)                                  #
#
# # 34: TemperatureLinf(relative)                                  #
#
# # 35: Phase01_Species01max. residue (begin), global block number #
#
# # 36: Phase01_Species01max. residue (begin), i-index             #
#
# # 37: Phase01_Species01max. residue (begin), j-index             #
#
# # 38: Phase01_Species01max. residue (begin), k-index             #
#
# # 39: Phase01_Species01max. residue (  end), global block number #
#
# # 40: Phase01_Species01max. residue (  end), i-index             #
#
# # 41: Phase01_Species01max. residue (  end), j-index             #
#
# # 42: Phase01_Species01max. residue (  end), k-index             #
#
# # 43: Phase01_Species01Linf(   begin)                            #
#
# # 44: Phase01_Species01Linf(     end)                            #
#
# # 45: Phase01_Species01Linf(relative)                            #
#
# # 46: Phase01_Species02max. residue (begin), global block number #
#
# # 47: Phase01_Species02max. residue (begin), i-index             #
#
# # 48: Phase01_Species02max. residue (begin), j-index             #
#
# # 49: Phase01_Species02max. residue (begin), k-index             #
#
# # 50: Phase01_Species02max. residue (  end), global block number #
#
# # 51: Phase01_Species02max. residue (  end), i-index             #
#
# # 52: Phase01_Species02max. residue (  end), j-index             #
#
# # 53: Phase01_Species02max. residue (  end), k-index             #
#
# # 54: Phase01_Species02Linf(   begin)                            #
#
# # 55: Phase01_Species02Linf(     end)                            #
#
# # 56: Phase01_Species02Linf(relative)                            #
#
# # 57: Phase01_Species03max. residue (begin), global block number #
#
# # 58: Phase01_Species03max. residue (begin), i-index             #
#
# # 59: Phase01_Species03max. residue (begin), j-index             #
#
# # 60: Phase01_Species03max. residue (begin), k-index             #
#
# # 61: Phase01_Species03max. residue (  end), global block number #
#
# # 62: Phase01_Species03max. residue (  end), i-index             #
#
# # 63: Phase01_Species03max. residue (  end), j-index             #
#
# # 64: Phase01_Species03max. residue (  end), k-index             #
#
# # 65: Phase01_Species03Linf(   begin)                            #
#
# # 66: Phase01_Species03Linf(     end)                            #
#
# # 67: Phase01_Species03Linf(relative)                            #
#
# # 68: Phase01_Species04max. residue (begin), global block number #
#
# # 69: Phase01_Species04max. residue (begin), i-index             #
#
# # 70: Phase01_Species04max. residue (begin), j-index             #
#
# # 71: Phase01_Species04max. residue (begin), k-index             #
#
# # 72: Phase01_Species04max. residue (  end), global block number #
#
# # 73: Phase01_Species04max. residue (  end), i-index             #
#
# # 74: Phase01_Species04max. residue (  end), j-index             #
#
# # 75: Phase01_Species04max. residue (  end), k-index             #
#
# # 76: Phase01_Species04Linf(   begin)                            #
#
# # 77: Phase01_Species04Linf(     end)                            #
#
# # 78: Phase01_Species04Linf(relative)                            #
#
# # 79: Phase01_Species05max. residue (begin), global block number #
#
# # 80: Phase01_Species05max. residue (begin), i-index             #
#
# # 81: Phase01_Species05max. residue (begin), j-index             #
#
# # 82: Phase01_Species05max. residue (begin), k-index             #
#
# # 83: Phase01_Species05max. residue (  end), global block number #
#
# # 84: Phase01_Species05max. residue (  end), i-index             #
#
# # 85: Phase01_Species05max. residue (  end), j-index             #
#
# # 86: Phase01_Species05max. residue (  end), k-index             #
#
# # 87: Phase01_Species05Linf(   begin)                            #
#
# # 88: Phase01_Species05Linf(     end)                            #
#
# # 89: Phase01_Species05Linf(relative)                            #
# /usr/lib64/python2.7/site-packages/numpy/lib/npyio.py:1596: ConversionWarning: Some errors were detected !
#     Line #78 (got 75 columns instead of 89)
#   warnings.warn(errmsg, ConversionWarning)

# %%
#for sim in sim_list:
#      print(sim.info.local["jobname"])
#      sim.sync_result("processed")

wc_sims = filter_simulations(sim_list)
for sim in wc_sims:
  try:
     wc_data_l = pic.load(open(os.path.join(sim.info.local["sim_folder"],"processed/wc_data.dat"))) 
     wc_data = [[float(item[0].split()[2].split("\\")[0]),item[1]] for item in sorted(wc_data_l,key=lambda item:item[0])]
     sim.wc_data = {}
     sim.wc_data["coords"] = np.linspace(0.0,0.04,100)
     sim.wc_data["CO"]     = np.interp(sim.wc_data["coords"],[item[0] for item in wc_data],[np.array(item[1][4][0]) for item in wc_data])
     sim.all_data = wc_data   
  except:
     print sim.info.local["jobname"]
# Out:
# a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_1100_veloc_2_wc_ge_100_wc_nc_32_wc_th_10

# %%
for sim in wc_sims:
    label = str(sim.sim_info["temperature"])+"_"+str(sim.sim_info["resolution"])
    pl.plot(sim.wc_data["coords"],sim.wc_data["CO"],label=label)
    
pl.legend()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-713-d2f88c45e8a7> in <module>()
#       1 for sim in wc_sims:
#       2     label = str(sim.sim_info["temperature"])+"_"+str(sim.sim_info["resolution"])
# ----> 3     pl.plot(sim.wc_data["coords"],sim.wc_data["CO"],label=label)
#       4
#       5 pl.legend()
#
# KeyError: 'CO'

# %%
for sim in filter_simulations(wc_sims,temperature=600,wc_geo_area=100,dp=10,mf=3000):
    label = str(sim.sim_info["temperature"])+"_"+str(sim.sim_info["resolution"])
    pl.plot([np.array(item[1][4][:]) for item in sim.all_data][0],label=label)

# %%
for sim in sim_list:
    sim.sim_info["running"]=False

    if sim.status() == "running":
        sim.sim_info["running"]=True
# Out:
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['running']
# Reason for pending
# []
# =========================
# RUNNING
# job not found
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# Job status
# ['running']
# Reason for pending
# []
# =========================
# RUNNING
# job not found
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['running']
# Reason for pending
# []
# =========================
# RUNNING
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# Job status
# ['running']
# Reason for pending
# []
# =========================
# RUNNING
# job not found
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_400_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# Job status
# ['running']
# Reason for pending
# []
# =========================
# RUNNING
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# Job status
# ['running']
# Reason for pending
# []
# =========================
# RUNNING
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['running']
# Reason for pending
# []
# =========================
# RUNNING
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['running']
# Reason for pending
# []
# =========================
# RUNNING
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# Job status
# ['running']
# Reason for pending
# []
# =========================
# RUNNING
# job not found
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['running']
# Reason for pending
# []
# =========================
# RUNNING
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['running']
# Reason for pending
# []
# =========================
# RUNNING
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['pending']
# Reason for pending
# ['reached job slot limit']
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# Job status
# ['pending']
# Reason for pending
# ['reached job slot limit']
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# Job status
# ['pending']
# Reason for pending
# ['reached job slot limit']
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# Job status
# ['pending']
# Reason for pending
# ['reached job slot limit']
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['pending']
# Reason for pending
# ['reached job slot limit']
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['pending']
# Reason for pending
# ['reached job slot limit']
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# Job status
# ['pending']
# Reason for pending
# ['reached job slot limit']
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# Job status
# ['pending']
# Reason for pending
# ['reached job slot limit']
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_470_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['pending']
# Reason for pending
# ['reached job slot limit']
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['pending']
# Reason for pending
# ['reached job slot limit']
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['pending']
# Reason for pending
# ['reached job slot limit']
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# Job status
# ['pending']
# Reason for pending
# ['reached job slot limit']
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# Job status
# ['pending']
# Reason for pending
# ['reached job slot limit']
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# Job status
# ['pending']
# Reason for pending
# ['reached job slot limit']
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['pending']
# Reason for pending
# ['reached job slot limit']
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['pending']
# Reason for pending
# ['reached job slot limit']
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# Job status
# ['pending']
# Reason for pending
# ['reached job slot limit']
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# Job status
# ['pending']
# Reason for pending
# ['reached job slot limit']
# =========================
# =========================
# Summary of job a_v_1000_cov_C_0_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_500_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['pending']
# Reason for pending
# ['reached job slot limit']
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_1_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_10_wc_nc_32_wc_th_10
# Job status
# ['running']
# Reason for pending
# []
# =========================
# RUNNING
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_500_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_5_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_40
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# job not found
# =========================
# Summary of job a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_540_veloc_2_wc_ge_100_wc_nc_32_wc_th_10
# Job status
# ['job not found']
# Reason for pending
# []
# =========================
# =========================

# %%
sim_list[0].status

# %%
gas = ca.importPhase(os.path.join(ref_folder,"cantera_input.cti"),"gas")
interface = ca.importInterface(os.path.join(ref_folder,"cantera_input.cti"),"pt_surf",[gas])
temp = 500
gas.setState_TPY(temp,1.015E5,[0.1,0.064,0.072,0.76,0.003])
diff = []
dps = np.logspace(-4,-9)
for dp in dps:
    diff.append(1./(1/gas.mixDiffCoeffs()[-1]+1./(dp/3*np.sqrt(8*8*temp/(np.pi*0.028)))))

ax = pl.gca()
ax.set_xlabel("pore diameter")
ax.set_ylabel("D ($m^2/s$)")

ax.loglog(dps,diff)
pl.gcf().tight_layout()
pl.gcf().savefig("knudsen.eps")

# %%
gas = ca.importPhase(os.path.join(ref_folder,"cantera_input.cti"),"gas")
interface = ca.importInterface(os.path.join(ref_folder,"cantera_input.cti"),"pt_surf",[gas])
temp = 800
prod = []
conc_arr = np.logspace(-5,-1,100)
for conc in conc_arr:
    gas.setState_TPY(temp,1.015E5,[0.1,0.064,0.072,0.76,conc])
    interface.setTemperature(temp)
    interface.advanceCoverages(100000)
    prod.append(interface.netProductionRates()[4])

# %%
pl.loglog(conc_arr,-np.array(prod))

# %%
a=[[0,1],[2,3]]

# %%
a[0][1]
# Out:
# 1

# %%
data=[[sim.sim_info,sim.wc_data,sim.all_data] for sim in sim_list]
f = open("output.dat",'w')
pic.dump(data,f)
f.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-606-702a8482bed0> in <module>()
# ----> 1 data=[[sim.sim_info,sim.wc_data,sim.all_data] for sim in sim_list]
#       2 f = open("output.dat",'w')
#       3 pic.dump(data,f)
#       4 f.close()
#
# AttributeError: job instance has no attribute 'all_data'

# %%
data
# Out:
# [[{'a_v': 1000,
#    'converged': True,
#    'dp': 10,
#    'resolution': 21,
#    'sh_number': 4000,
#    'temperature': 400,
#    'velocity': 5,
#    'wc_geo_area': 1,
#    'wc_ncells': 32,
#    'wc_thickness': 40},
#   {'CO': array([ 0.00292915,  0.00292915,  0.00292915,  0.00292915,  0.00292915,
#            0.00292915,  0.00292915,  0.00292915,  0.00292915,  0.00292915,
#            0.00292915,  0.00292915,  0.00292915,  0.00292915,  0.00292915,
#            0.00292915,  0.00292915,  0.00292915,  0.00292915,  0.00292915,
#            0.00292915,  0.00292915,  0.00292915,  0.00292915,  0.00292915,
#            0.00292915,  0.00292915,  0.00292915,  0.00292915,  0.00292915,
#            0.00292915,  0.00292915,  0.00292915,  0.00292915,  0.00292915,
#            0.00292915,  0.00292915,  0.00292915,  0.00292915,  0.00292915,
#            0.00292915,  0.00292915,  0.00292915,  0.00292915,  0.00292915,
#            0.00292915,  0.00292915,  0.00292915,  0.00292915,  0.00292915,
#            0.00
),
#    'coords': array([ 0.        ,  0.00040404,  0.00080808,  0.00121212,  0.00161616,
#            0.0020202 ,  0.00242424,  0.00282828,  0.00323232,  0.00363636,
#            0.0040404 ,  0.00444444,  0.00484848,  0.00525253,  0.00565657,
#            0.00606061,  0.00646465,  0.00686869,  0.00727273,  0.00767677,
#            0.00808081,  0.00848485,  0.00888889,  0.00929293,  0.00969697,
#            0.01010101,  0.01050505,  0.01090909,  0.01131313,  0.01171717,
#            0.01212121,  0.01252525,  0.01292929,  0.01333333,  0.01373737,
#            0.01414141,  0.01454545,  0.01494949,  0.01535354,  0.01575758,
#            0.01616162,  0.01656566,  0.0169697 ,  0.01737374,  0.01777778,
#            0.01818182,  0.01858586,  0.0189899 ,  0.01939394,  0.01979798,
#            0.02020202,  0.02060606,  0.0210101 ,  0.02141414,  0.02181818,
#            0.02222222,  0.02262626,  0.0230303 ,  0.02343434,  0.02383838,
#            0.02424242,  0.02464646,  0.02505051,  0.02545455,  0.02585859,
#            0.02626263,  0.02666667,  0.02707071,  0.02747475,  0.02787879,
#            0.02828283,  0.02868687,  0.02909091,  0.02949495,  0.02989899,
#            0.03030303,  0.03070707,  0.03111111,  0.03151515,  0.03191919,
#            0.03232323,  0.03272727,  0.03313131,  0.03353535,  0.03393939,
#            0.03434343,  0.03474747,  0.03515152,  0.03555556,  0.0359596 ,
#            0.03636364,  0.03676768,  0.03717172,  0.03757576,  0.0379798 ,
#            0.03838384,  0.03878788,  0.03919192,  0.03959596,  0.04      ])}],
#  [{'a_v': 1000,
#    'converged': True,
#    'dp': 10,
#    'resolution': 41,
#    'sh_number': 4000,
#    'temperature': 1100,
#    'velocity': 5,
#    'wc_geo_area': 1,
#    'wc_ncells': 64,
#    'wc_thickness': 40},
#   {'CO': array([  2.76457000e-03,   2.76457000e-03,   2.67242919e-03,
#             2.58437000e-03,   2.51704879e-03,   2.42761848e-03,
#             2.33818818e-03,   2.25375763e-03,   2.17048086e-03,
#             2.08957955e-03,   2.01334116e-03,   1.93710278e-03,
#             1.86668061e-03,   1.79718566e-03,   1.73009556e-03,
#             1.66680667e-03,   1.60351778e-03,   1.54539788e-03,
#             1.48777364e-03,   1.43240495e-03,   1.37993626e-03,
#             1.32746758e-03,   1.27952167e-03,   1.23175197e-03,
#             1.18606424e-03,   1.14256525e-03,   1.09911485e-03,
#             1.05950273e-03,   1.01989061e-03,   9.82182646e-04,
#             9.46113152e-04,   9.10244919e-04,   8.77395626e-04,
#             8.44546333e-04,   8.13420136e-04,   7.83503773e-04,
#             7.53887818e-04,   7.26641758e-04,   6.99395697e-04,
#             6.73699212e-04,   6.48883859e-04,   6.24428303e-04,
#             6.01827091e-04,   5.79225879e-04,   5.58009944e-04,
#             5.37423682e-04,   5.17227561e-04,   4.98477258e-04,
#             4.79726955e-04,   4.62209096e-04,   4.45129904e-04,
#             4.28450348e-04,   4.12893581e-04,   3.97336813e-04,
#             3.82871727e-04,   3.68701222e-04,   3.54925162e-04,
#             3.42016879e-04,   3.29108596e-04,   3.17163354e-04,
#             3.05404970e-04,   2.94026222e-04,   2.83315111e-04,
#             2.72604000e-04,   2.62739510e-04,   2.52982338e-04,
#             2.43583500e-04,   2.34695015e-04,   2.25806530e-04,
#             2.17660091e-04,   2.09563121e-04,   2.01799525e-04,
#             1.94423364e-04,   1.87047202e-04,   1.80319399e-04,
#             1.73599803e-04,   1.67186672e-04,   1.61065056e-04,
#             1.54963879e-04,   1.49387313e-04,   1.43810747e-04,
#             1.38513273e-04,   1.33432869e-04,   1.28392096e-04,
#             1.23764621e-04,   1.19137146e-04,   1.14758631e-04,
#             1.10537621e-04,   1.06371361e-04,   1.02548533e-04,
#             9.87257045e-05,   9.57129465e-05,   9.22853606e-05,
#             8.80448152e-05,   8.51328960e-05,   8.22209768e-05,
#             7.82469864e-05,   7.38444409e-05,   7.04875000e-05,
#             7.04875000e-05]),
#    'coords': array([ 0.        ,  0.00040404,  0.00080808,  0.00121212,  0.00161616,
#            0.0020202 ,  0.00242424,  0.00282828,  0.00323232,  0.00363636,
#            0.0040404 ,  0.00444444,  0.00484848,  0.00525253,  0.00565657,
#            0.00606061,  0.00646465,  0.00686869,  0.00727273,  0.00767677,
#            0.00808081,  0.00848485,  0.00888889,  0.00929293,  0.00969697,
#            0.01010101,  0.01050505,  0.01090909,  0.01131313,  0.01171717,
#            0.01212121,  0.01252525,  0.01292929,  0.01333333,  0.01373737,
#            0.01414141,  0.01454545,  0.01494949,  0.01535354,  0.01575758,
#            0.01616162,  0.01656566,  0.0169697 ,  0.01737374,  0.01777778,
#            0.01818182,  0.01858586,  0.0189899 ,  0.01939394,  0.01979798,
#            0.02020202,  0.02060606,  0.0210101 ,  0.02141414,  0.02181818,
#            0.02222222,  0.02262626,  0.0230303 ,  0.02343434,  0.02383838,
#            0.02424242,  0.02464646,  0.02505051,  0.02545455,  0.02585859,
#            0.02626263,  0.02666667,  0.02707071,  0.02747475,  0.02787879,
#            0.02828283,  0.02868687,  0.02909091,  0.02949495,  0.02989899,
#            0.03030303,  0.03070707,  0.03111111,  0.03151515,  0.03191919,
#            0.03232323,  0.03272727,  0.03313131,  0.03353535,  0.03393939,
#            0.03434343,  0.03474747,  0.03515152,  0.03555556,  0.0359596 ,
#            0.03636364,  0.03676768,  0.03717172,  0.03757576,  0.0379798 ,
#            0.03838384,  0.03878788,  0.03919192,  0.03959596,  0.04      ])}],
#  [{'a_v': 1000,
#    'converged': False,
#    'dp': 10,
#    'resolution': 41,
#    'sh_number': 4000,
#    'temperature': 1100,
#    'velocity': 5,
#    'wc_geo_area': 100,
#    'wc_ncells': 64,
#    'wc_thickness': 40},
#   {'CO': array([  2.52310000e-03,   2.52310000e-03,   2.32785071e-03,
#             2.13052242e-03,   1.97736540e-03,   1.80197551e-03,
#             1.62658561e-03,   1.47893889e-03,   1.33769444e-03,
#             1.20667768e-03,   1.09573748e-03,   9.84797278e-04,
#             9.00041879e-04,   8.11900768e-04,   7.28964015e-04,
#             6.61423409e-04,   5.93882803e-04,   5.40035965e-04,
#             4.87502227e-04,   4.40073187e-04,   3.99207328e-04,
#             3.58341470e-04,   3.26095333e-04,   2.94185030e-04,
