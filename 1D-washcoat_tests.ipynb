# %%
#%load_ext autoreload
#%autoreload 2
from matplotlib import rc_file
rc_file('/home/vonrickenbach/.matplotlib/rc_publication')


import os

import glob as gl
import simulation_brutus as sim_brutus

import job_configurations as jc
import matplotlib.pyplot as pl
import pickle as pic
import numpy as np

import subprocess as sp
import initial_condition_writer as ini
import shutil as sh

import cantera as ca

import para_reader as pa
from IPython.display import Image,display
import operator as op
# %matplotlib inline
import time
pl.rcParams["text.usetex"] = False

# %%
figsize_print = [3.45,2.4]
figsize = list(np.array([3.25,2.4]))
from matplotlib import rc_file
rc_file('/home/vonrickenbach/.matplotlib/rc_publication')

# %%
ref_folder = "/home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/ref_sim/finite_vol_avg_wc_only_CO/"

# %%
def filter_simulations(sim_list,**kwargs):
  filtered_list = []
  for sim in sim_list:
      match_all = True
      for key, item in kwargs.iteritems():
            if not int(sim.sim_info[key]) == int(item):  
              match_all = False
      if match_all:
        filtered_list.append(sim)
  return filtered_list
    
def sort_sims(sim_list,prop): 
    return sorted(sim_list,key=lambda it: it.sim_info[prop])    

def get_array(sim_list,func=None,var=None):
    prop_list = []
    if func:
        for sim in sim_list:
           if var:
               prop_list.append(func(sim,var))
           else:
               prop_list.append(func(sim))
    return np.array(prop_list)

# %%
# %%file write_pictures.py

from paraview.simple import *
from para_reader import *
import os

try:
    os.mkdir("processed")
except:
    print("directory exists already")

outputname=  os.path.join("processed","unstructured.vtu")

rewrite_as_unstructured(get_last_modified(),outputname)

print(outputname)

# %%
# %%file line_avg.py

from paraview.simple import *
from para_reader import *
import pickle as pic
import os
import glob as gl
import numpy as np

name = get_last_modified()
print(name)
    
data_file = OpenDataFile(name)

print("Reading file ", data_file)

avg_var =[]

filelist=gl.glob("grid*")
wc_data = []
for file_h in filelist:
    f = open(file_h)
    x_coord = f.readline()
    f.close()
    wc_data.append([x_coord,np.genfromtxt(file_h)])
    

point_data = CellDatatoPointData(MergeBlocks(data_file))
prob = ProbeLocation(point_data,ProbeType="Fixed Radius Point Source"     )
prob1 = ProbeLocation(point_data,ProbeType="Fixed Radius Point Source"     )

UpdatePipeline()
bounds = get_bounds(data_file)

print(bounds)

prob.ProbeType.Center = [0.01025,-0.00400001525878906,0.000999992370605469]
prob1.ProbeType.Center = [0.0001,-0.00400001525878906,0.000999992370605469]

UpdatePipeline()

data_dict = save_data_to_dict(prob,cell=False)
data_dict1 = save_data_to_dict(prob1,cell=False)

UpdatePipeline()


try:
    os.mkdir("processed")
except:
    print("directory exists already")
pickle_file = "processed/slice_averages.dat"
pickle_file_wc = "processed/wc_data.dat"
f = open(pickle_file,'w')
f_wc = open(pickle_file_wc,'w')
pic.dump([data_dict,data_dict1],f)
pic.dump(wc_data,f_wc)
f.close()
f_wc.close()
# Out:
# Overwriting line_avg.py

# %%
# %%file plot_line.py

from paraview.simple import *
from para_reader import *
import pickle as pic
import os

name = get_last_modified()
print(name)
    
data_file = OpenDataFile(name)

print("Reading file ", data_file)

avg_var =[]

point_data = CellDatatoPointData(MergeBlocks(data_file))

prob = PlotOverLine(point_data)

UpdatePipeline()
bounds = get_bounds(data_file)

print(bounds)

prob.Source.Point1 = [0.0000001,-0.00400001525878906,0.000999992370605469]
prob.Source.Point2 = [0.0399999999,-0.00400001525878906,0.000999992370605469]
prob.Source.Resolution = 10

UpdatePipeline()

data_dict = save_data_to_dict(prob,cell=False)

UpdatePipeline()


try:
    os.mkdir("processed")
except:
    print("directory exists already")
pickle_file = "processed/plot_over_line.dat"
f = open(pickle_file,'w')
pic.dump(data_dict,f)
f.close()
# Out:
# Overwriting plot_line.py

# %%
def create_simulation(input_dict,folder,root_folder=".",ref_folder=None,massfraction=None):

    if not ref_folder:
        ref_folder = "/home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/ref_sim/finite_vol_avg_wc_only_CO/"


    try:
        sh.copytree(ref_folder,os.path.join(root_folder,folder))
    except:
        print("directory exists")
 
    if not massfraction:
        massfraction = {}
        massfraction["O2"]   = [0.1,   [0,0]] 
        massfraction["CO2"]  = [0.064, [0,1]]
        massfraction["H2O"]  = [0.072, [0,2]]
        massfraction["N2"]   = [0.76,  [0,3]]
        massfraction["CO"]   = [input_dict["mf"]*1E-6, [0,4]]
        
    velocity     = input_dict["velocity"]
    temperature  = input_dict["temperature"]
    wc_thickness = input_dict["wc_thickness"]*1E-6
    wc_geo_area  = input_dict["wc_geo_area"]
    sh_n         = input_dict["sh_number"]
    a_v          = input_dict["a_v"]
    n_wc         = input_dict["wc_ncells"]
    res          = input_dict["resolution"]
    dp           = input_dict["dp"]*1E-9
    cov_CO       = input_dict["cov_CO"]
    wc_porosity       = input_dict["wc_porosity"]
    wc_tortuosity       = input_dict["wc_tortuosity"]
    config_sim = jc.configuration_brutus
    config_sim["jobname"] = folder
    config_sim["root_folder"] = root_folder
    config_sim["cluster_scratch"]='/cluster/scratch_xp/public/vjan/wc_1d_tests'

    print(folder)
    #maxtries = 100
    #current_try = 0
    #while current_try < maxtries:
    #    try:
    simulation = sim_brutus.job(**config_sim)
    #    except:
    #        current_try += 1
    #        print("FAILED",current_try)
    #        continue
        

    

    sh.copy(os.path.join(os.path.join(root_folder,ref_folder),"transat_mb.inp"),os.path.join(root_folder,folder))
    sh.copy(os.path.join(os.path.join(root_folder,ref_folder),"finite_vol_avg.stt"),os.path.join(root_folder,folder))

    sh.copy(os.path.join(os.path.join(root_folder,ref_folder),"cantera_input.cti"),os.path.join(root_folder,folder))
    sh.copy(os.path.join(os.path.join(root_folder,ref_folder),"mt_coefficients.dat"),os.path.join(root_folder,folder))
    sh.copy(os.path.join(os.path.join(root_folder,ref_folder),"res_coefficients.dat"),os.path.join(root_folder,folder))

    simulation.application.change_input("cornerpoint_number  21",res,newline="cornerpoint_number "+str(res) +"\n",filename="finite_vol_avg.stt") 
    
    transatui_command = []
    transatui_command.append("transatui.py")
    transatui_command.append("--Project=finite_vol_avg.stt")
    transatui_command.append("--Graphics=bash")
#    ui=sp.Popen(transatui_command,cwd=os.path.join(root_folder,folder),stdout=open("ui_output.out","a"))
    ui=sp.Popen(transatui_command,cwd=os.path.join(root_folder,folder))

    ui.communicate() 
    
    Dp = 0.002
    ds = 0.0003
    porosity = 0.903
    #a_v = 10.33/(Dp+ds) * np.sqrt(1-porosity) -5.8/(Dp+ds)*(1.0-porosity)
  
    write_inital_conditions(os.path.join(root_folder,folder),massfraction,velocity,temperature)
    
    component_string =  "if (x[ii] < 0.0001){component_molefraction_0_4[ii] ="+str(input_dict["mf"]*1E-6)+";}else{component_molefraction_0_4[ii] =0.000;}"
    component_string_2 =  "if (x[ii] < 0.0001){component_molefraction_0_4[ii] ="+str(input_dict["mf"]*1E-6)+";}else{component_molefraction_0_4[ii] ="+str(input_dict["mf"]*2E-6)+";}"

    if cov_CO < 1:
        simulation.application.change_input("component_molefraction_0_4[ii]",res,newline=component_string + os.linesep,filename="initialconditions.cxx")  
    else:
        simulation.application.change_input("component_molefraction_0_4[ii]",res,newline=component_string_2 + os.linesep,filename="initialconditions.cxx")  

    simulation.application.change_input("data_format",'\"paraview_cell\"')
    simulation.application.change_input("wc_thickness",str(wc_thickness))
    simulation.application.change_input("activate_chem_heat_src",'.false.')
    simulation.application.change_input("mf_subiter",'1')
    simulation.application.change_input("L3Dplot",'.true.')
    simulation.application.change_input("L2Dplot",'.false.')
    simulation.application.change_input("write_kplane",'.false.')
    simulation.application.change_input("ode_rtol",'1E-7')
    simulation.application.change_input("ode_atol",'1E-25')
    simulation.application.change_input("ode_maxit","100000")
    simulation.application.change_input("wc_geo_area",str(wc_geo_area))
    simulation.application.change_input("sherwood_number",str(sh_n))
    simulation.application.change_input("den(1)",0.028*1E5/(8.314*temperature))
    simulation.application.change_input("wc_ncells",str(n_wc))
    simulation.application.change_input("wc_pore_diameter",str(dp))
    simulation.application.change_input("wc_tortuosity",str(wc_tortuosity))
    simulation.application.change_input("wc_porosity",str(wc_porosity))
    if temperature < 551:
        simulation.application.change_input("pseudo_int_time",str(10))
        simulation.application.change_input("ode_maxit","1000000")

    else:
        simulation.application.change_input("pseudo_int_time",str(0.01))

    simulation.application.change_input("init_surf_cov(1)",str(1-cov_CO))
    simulation.application.change_input("init_surf_cov(3)",str(cov_CO))
    simulation.application.change_input("applyeiinitial",".false.")
    
    if wc_thickness < 0.0:
        simulation.application.change_input("wc_ncells",str(1))
        simulation.application.change_input("wc_thickness",str(1E-5))

    simulation.application.change_input("porous_a_v",str(a_v))

    simulation.application.change_input("surface_coverage",'1.0',filename="properties.dat")

    conjugate = False
    if conjugate:
       simulation.application.change_input("temp_model",'\"conjugate\"',filename="properties.dat")
       simulation.application.change_input("density",'3500',filename="properties.dat")
       simulation.application.change_input("conductivity",'25.6',filename="properties.dat")
       simulation.application.change_input("heatcapacity",'795',filename="properties.dat")
       simulation.application.change_input("surface_coverage",'1.0',filename="properties.dat")


    simulation.sim_info = input_dict.copy()
    simulation.sim_info["converged"] = False


    return simulation

# %%
def write_inital_conditions(folder,massfraction,velocity,temperature):

    writer = ini.initalconditions_writer()
    writer.add_variable("uvelocity",velocity)
    writer.add_variable("temperature",temperature)
    
    for key,item in massfraction.iteritems():
        writer.add_variable(var="component_molefraction",value=item[0],index=item[1])
        
    writer.write_file(folder)

# %%
def get_folder_name(inputs):
  folder = ""
  for item in sorted(inputs.iteritems(), key=op.itemgetter(0)):
      if item[0] in par_inputs.keys() or item[0] == "temperature" or item[0] == "cov_CO":
          folder += item[0][0:4]+"_"+str(int(item[1]))+"_"
  return folder[:-1]

# %%
sim_list = []

sim_count = 0


temperatures = [300,360,370,380,390,400,410,420,430,440,450,460,470,480,490,500,510,520,530,540,550,560,570,600,700,800,900,1000]
temperatures = [400,500,600,900,1000]
#temperatures = [300,360,370,380,375,380,385,390,395,400,410,420,430,440,450,460,470,480,490,500,510,520,530,540,550,560,570,600,700,800,900,1000]

wc_ncells = [32]
res = [41]

par_inputs = {}
#par_inputs["wc_thickness"] = [40,20,10,80,160,-1E6]
#par_inputs["wc_geo_area"] = [100,1,10,500]
#par_inputs["sh_number"] = [4000,2000]
#par_inputs["velocity"] = [5,2.5]
#par_inputs["a_v"] = [1000,4000]
#par_inputs["dp"] = [10,50,100]
#par_inputs["mf"] = [3000,1000,10000]

par_inputs["sh_number"] = [4000,8000,16000]
par_inputs["velocity"] = [5]
par_inputs["a_v"] = [1000]
par_inputs["dp"] = [10,50,5]
par_inputs["mf"] = [3000,1000,10000]
par_inputs["wc_thickness"] = [100,10,160,-1E6]
par_inputs["wc_geo_area"] = [100,500,10,1,-1]
par_inputs["nx"] = [64,128,32]
par_inputs["t_fac"] = [1,10,0.1]
par_inputs["x_cells"] = [20,40]


cov_co = [1,0]


default_inputs = {}
for key,item in par_inputs.iteritems():
    default_inputs[key] = item[0] 
    
default_inputs["wc_tortuosity"] = 8.0
default_inputs["wc_porosity"]   = 0.35


add_simulations(sim_list,sim_count,temperatures,wc_ncells,res,default_inputs,par_inputs,cov_co,add_ref=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-261-418defb1eb53> in <module>()
#      43
#      44
# ---> 45 add_simulations(sim_list,sim_count,temperatures,wc_ncells,res,default_inputs,par_inputs,cov_co,add_ref=True)
#      46
#
# NameError: name 'add_simulations' is not defined

# %%
default_inputs
# Out:
# {'a_v': 1000,
#  'dp': 10,
#  'mf': 3000,
#  'nx': 64,
#  'sh_number': 4000,
#  't_fac': 1,
#  'velocity': 5,
#  'wc_geo_area': 100,
#  'wc_porosity': 0.35,
#  'wc_thickness': 40,
#  'wc_tortuosity': 8.0,
#  'x_cells': 20}

# %%
def add_simulations(sim_list,sim_count,temperatures,wc_ncells,res,default_inputs,par_inputs,cov_co,add_ref=True):
  root_folder = "/home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/"

  for temperature in temperatures:
    for resolution in res:
        for n_cells in wc_ncells:
          for co in cov_co:
            current_inputs = {}
            current_inputs = default_inputs.copy()
            current_inputs["resolution"] = resolution
            current_inputs["wc_ncells"] = n_cells
            current_inputs["temperature"] = temperature
            current_inputs["cov_CO"]      = co
            global_inputs = current_inputs.copy()
            print add_ref
            if add_ref:
                sim_list.append(create_simulation(current_inputs,get_folder_name(current_inputs),root_folder=root_folder))
                sim_count += 1
            for par_input,par_values in par_inputs.iteritems():
                current_inputs = global_inputs.copy()
                for par_value in par_values[1:]:
                    if par_input == "wc_thickness" and par_value == -1E6:
                        loc_wc_geo_area = par_inputs["wc_geo_area"]
                    else:
                        loc_wc_geo_area = [current_inputs["wc_geo_area"]]
                    for geo_a in loc_wc_geo_area:
                        
                        current_inputs["wc_geo_area"] = geo_a
                        current_inputs[par_input] = par_value
                        sim_count += 1
                        sim_list.append(create_simulation(current_inputs,get_folder_name(current_inputs),root_folder=root_folder))

# %%
for sim in filter_simulations(sim_list):
   if sim.sim_info["temperature"] > 399 and sim.sim_info["cov_CO"] == 1 and sim.sim_info["temperature"] < 551:
       sim.application.load      = "source ~/.bashrc_gfort_wc_model"
       sim.init_application.load = "source ~/.bashrc_gfort_wc_model"  
       sim.compile_init_application.load = "source ~/.bashrc_gfort_wc_model"  

       init = True
       depend = False
       sim.sync_input()
       if init:
           sim.compile_init(nproc="1",memory="1024",time='60') 

           sim.run_init(nproc="1",memory="1024",time='60',depend=True) 
           depend = True
       sim.run_sim(nproc="10",memory="1024",time='1200',njobs=1,restart=False,depend=depend)
# Out:
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098044> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10)" mpirun ./transatmbinitialDP
# Job <59098045> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098046> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098047> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10)" mpirun ./transatmbinitialDP
# Job <59098050> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098053> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098054> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10)" mpirun ./transatmbinitialDP
# Job <59098055> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098056> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_500_wc_t_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098057> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_500_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_500_wc_t_10)" mpirun ./transatmbinitialDP
# Job <59098058> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_500_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_500_wc_t_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098059> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_10_wc_t_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098060> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_10_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_10_wc_t_10)" mpirun ./transatmbinitialDP
# Job <59098061> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_10_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_10_wc_t_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098062> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_1_wc_t_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098063> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_1_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_1_wc_t_10)" mpirun ./transatmbinitialDP
# Job <59098064> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_1_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_1_wc_t_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098065> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_40 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098066> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_40 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_40)" mpirun ./transatmbinitialDP
# Job <59098067> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_40 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_40)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098068> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_160 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098069> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_160 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_160)" mpirun ./transatmbinitialDP
# Job <59098070> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_160 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_160)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098071> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_-1000000 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098072> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_-1000000)" mpirun ./transatmbinitialDP
# Job <59098073> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_-1000000)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098074> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_500_wc_t_-1000000 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098075> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_500_wc_t_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_500_wc_t_-1000000)" mpirun ./transatmbinitialDP
# Job <59098076> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_500_wc_t_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_500_wc_t_-1000000)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098077> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_10_wc_t_-1000000 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098078> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_10_wc_t_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_10_wc_t_-1000000)" mpirun ./transatmbinitialDP
# Job <59098079> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_10_wc_t_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_10_wc_t_-1000000)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098080> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_1_wc_t_-1000000 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098081> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_1_wc_t_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_1_wc_t_-1000000)" mpirun ./transatmbinitialDP
# Job <59098082> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_1_wc_t_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_1_wc_t_-1000000)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098083> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098084> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10)" mpirun ./transatmbinitialDP
# Job <59098085> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098086> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098087> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10)" mpirun ./transatmbinitialDP
# Job <59098088> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098090> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098091> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10)" mpirun ./transatmbinitialDP
# Job <59098092> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098093> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098094> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10)" mpirun ./transatmbinitialDP
# Job <59098095> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098096> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098097> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10)" mpirun ./transatmbinitialDP
# Job <59098098> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098099> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_500_wc_t_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098100> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_500_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_500_wc_t_10)" mpirun ./transatmbinitialDP
# Job <59098101> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_500_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_500_wc_t_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098102> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_10_wc_t_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098105> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_10_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_10_wc_t_10)" mpirun ./transatmbinitialDP
# Job <59098107> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_10_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_10_wc_t_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098108> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_1_wc_t_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098109> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_1_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_1_wc_t_10)" mpirun ./transatmbinitialDP
# Job <59098110> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_1_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_1_wc_t_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098111> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_40 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098112> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_40 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_40)" mpirun ./transatmbinitialDP
# Job <59098113> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_40 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_40)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098114> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_160 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098115> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_160 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_160)" mpirun ./transatmbinitialDP
# Job <59098116> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_160 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_160)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098117> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_-1000000 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098118> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_-1000000)" mpirun ./transatmbinitialDP
# Job <59098119> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_-1000000)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098120> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_500_wc_t_-1000000 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098121> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_500_wc_t_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_500_wc_t_-1000000)" mpirun ./transatmbinitialDP
# Job <59098122> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_500_wc_t_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_500_wc_t_-1000000)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59098142> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_10_wc_t_-1000000 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59098143> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_10_wc_t_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_10_wc_t_-1000000)" mpirun ./transatmbinitialDP
# Job <59098144> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_10_wc_t_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_10_wc_t_-1000000)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# ...
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_1_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_1_wc_t_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59099301> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_40 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59099303> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_40 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_40)" mpirun ./transatmbinitialDP
# Job <59099304> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_40 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_40)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59099308> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_160 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59099309> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_160 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_160)" mpirun ./transatmbinitialDP
# Job <59099313> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_160 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_160)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59099314> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_-1000000 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59099316> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_-1000000)" mpirun ./transatmbinitialDP
# Job <59099317> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_-1000000)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59099318> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_500_wc_t_-1000000 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59099321> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_500_wc_t_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_500_wc_t_-1000000)" mpirun ./transatmbinitialDP
# Job <59099322> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_500_wc_t_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_500_wc_t_-1000000)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59099327> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_10_wc_t_-1000000 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59099329> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_10_wc_t_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_10_wc_t_-1000000)" mpirun ./transatmbinitialDP
# Job <59099330> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_10_wc_t_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_10_wc_t_-1000000)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59099332> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_1_wc_t_-1000000 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59099334> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_1_wc_t_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_1_wc_t_-1000000)" mpirun ./transatmbinitialDP
# Job <59099335> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_1_wc_t_-1000000 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_1_wc_t_-1000000)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59099337> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59099338> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_10)" mpirun ./transatmbinitialDP
# Job <59099339> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59099342> is submitted to queue <vip.36h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log   tmb_init_compile.py
# Job <59099343> is submitted to queue <pub.1h>.
# Generic job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_10)" mpirun ./transatmbinitialDP
# Job <59099345> is submitted to queue <pub.1h>.
# MPI job.
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source ~/.bashrc_gfort_wc_model; bsub -n 10 -W 1200 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_10 -o std_out.log -e std_err.log -w "ended(a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_550_velo_5_wc_g_100_wc_t_10)" mpirun ./transatmbDP -pc_hypre_boomeramg_max_iter -pc_hypre_boomeramg_coarsen_type HMIS -pc_hypre_boomeramg_interp_type ext+i -pc_hypre_boomeramg_P_max 4 -pc_hypre_boomeramg_strong_treshold 0 -pc_hypre_boomeramg_agg_nl 2
# Job <59099347> is submitted to queue <vip.36h>.
# MPI job.

# %%
for sim in filter_simulations(sim_list,converged=False):
#    sh.copy(os.path.join(os.path.join(root_folder,ref_folder),"transat_mb.inp"),os.path.join(root_folder,sim.info.local["jobname"]))

       sim.kill()
# Out:
# Job <58307636> is being terminated
# Job <58309550> is being terminated
# Job <58309553> is being terminated
# Job <58309791> is being terminated
# Job <58309794> is being terminated
# Job <58309969> is being terminated
# Job <58309972> is being terminated
# Job <a_v_4000_cov__1_dp_10_mf_3000_sh_n_4000_temp_450_velo_5_wc_g_100_wc_t_10> is not found
# Job <a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_450_velo_5_wc_g_100_wc_t_10> is not found
# Job <a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_450_velo_5_wc_g_500_wc_t_10> is not found
# Job <58310139> is being terminated
# Job <58310143> is being terminated
# Job <a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_460_velo_5_wc_g_100_wc_t_10> is not found
# Job <a_v_4000_cov__1_dp_10_mf_3000_sh_n_4000_temp_460_velo_5_wc_g_100_wc_t_10> is not found
# Job <a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_460_velo_5_wc_g_500_wc_t_10> is not found
# Job <a_v_1000_cov__1_dp_10_mf_3000_sh_n_2000_temp_460_velo_5_wc_g_100_wc_t_10> is not found
# Job <a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_460_velo_2_wc_g_100_wc_t_10> is not found
# Job <a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_460_velo_5_wc_g_100_wc_t_20> is not found
# Job <a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_460_velo_5_wc_g_100_wc_t_40> is not found
# Job <a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_460_velo_5_wc_g_100_wc_t_10> is not found
# Job <a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_460_velo_5_wc_g_100_wc_t_10> is not found
# Job <a_v_1000_cov__0_dp_50_mf_3000_sh_n_4000_temp_460_velo_5_wc_g_100_wc_t_10> is not found
# Job <a_v_1000_cov__0_dp_100_mf_3000_sh_n_4000_temp_460_velo_5_wc_g_100_wc_t_10> is not found
# Job <a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_470_velo_5_wc_g_100_wc_t_10> is not found
# Job <a_v_4000_cov__1_dp_10_mf_3000_sh_n_4000_temp_470_velo_5_wc_g_100_wc_t_10> is not found
# Job <a_v_1000_cov__1_dp_10_mf_3000_sh_n_2000_temp_470_velo_5_wc_g_100_wc_t_10> is not found
# Job <a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_470_velo_2_wc_g_100_wc_t_10> is not found
# Job <a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_470_velo_5_wc_g_100_wc_t_20> is not found
# Job <a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_470_velo_5_wc_g_100_wc_t_40> is not found
# Job <a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_470_velo_5_wc_g_100_wc_t_10> is not found
# Job <a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_470_velo_5_wc_g_100_wc_t_10> is not found
# Job <a_v_1000_cov__0_dp_50_mf_3000_sh_n_4000_temp_470_velo_5_wc_g_100_wc_t_10> is not found
# Job <a_v_1000_cov__0_dp_100_mf_3000_sh_n_4000_temp_470_velo_5_wc_g_100_wc_t_10> is not found
# Job <a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_480_velo_5_wc_g_100_wc_t_10> is not found
# Job <58303343> is being terminated
# Job <58303346> is being terminated
# Job <58303349> is being terminated
# Job <58303353> is being terminated
# Job <58303356> is being terminated
# Job <58303361> is being terminated
# Job <58303364> is being terminated
# Job <58303372> is being terminated
# Job <58303375> is being terminated
# Job <58303379> is being terminated
# Job <58303382> is being terminated
# Job <58303385> is being terminated
# Job <58303388> is being terminated
# Job <58303393> is being terminated
# Job <58303398> is being terminated
# Job <58303402> is being terminated
# Job <58303405> is being terminated
# Job <58303408> is being terminated
# Job <58303411> is being terminated
# Job <58303425> is being terminated
# Job <58303430> is being terminated
# Job <58303434> is being terminated
# Job <58303437> is being terminated
# Job <58303441> is being terminated
# Job <58303445> is being terminated
# Job <58303448> is being terminated
# Job <58303451> is being terminated
# Job <58303455> is being terminated
# Job <58303458> is being terminated
# Job <58303461> is being terminated
# Job <58303464> is being terminated
# Job <58303467> is being terminated
# Job <58303470> is being terminated
# Job <58303473> is being terminated
# Job <58303477> is being terminated
# Job <58303480> is being terminated
# Job <58303483> is being terminated
# Job <58303486> is being terminated
# Job <58303489> is being terminated
# Job <58303492> is being terminated
# Job <58303501> is being terminated
# Job <58303506> is being terminated
# Job <58303511> is being terminated
# Job <58303514> is being terminated
# Job <58303518> is being terminated
# Job <58303522> is being terminated
# Job <58303525> is being terminated
# Job <58303528> is being terminated
# Job <58303533> is being terminated
# Job <58303537> is being terminated
# Job <58303558> is being terminated
# Job <58303562> is being terminated
# Job <58303565> is being terminated
# Job <58303569> is being terminated
# Job <58303578> is being terminated
# Job <58303581> is being terminated
# Job <58303586> is being terminated
# Job <58303592> is being terminated
# Job <58303595> is being terminated
# Job <58303600> is being terminated
# Job <58303607> is being terminated
# Job <58303612> is being terminated
# Job <58303615> is being terminated
# Job <58303620> is being terminated
# Job <58303624> is being terminated
# Job <58303631> is being terminated
# Job <58303635> is being terminated
# Job <58303641> is being terminated
# Job <58303644> is being terminated
# Job <58303647> is being terminated
# Job <58303654> is being terminated
# Job <58303714> is being terminated
# Job <58303740> is being terminated
# Job <58303744> is being terminated
# Job <58303799> is being terminated
# Job <58303833> is being terminated
# Job <58303838> is being terminated
# Job <58303842> is being terminated
# Job <58303845> is being terminated
# Job <58303849> is being terminated
# Job <58303853> is being terminated
# Job <58303856> is being terminated

# %%
filenames = []
#filenames.append("write_pictures.py")
filenames.append("line_avg.py")
#filenames.append("plot_line.py")

for filename in filenames:
    for sim in sim_list:
#      if sim.sim_info["temperature"] < 400:
          sh.copy(filename,os.path.join(sim.info.local["sim_folder"]))
          sim.run_postprocess(filename,nproc="1",memory="1024")
# Out:
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_500_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_10_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_1_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_160 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_500_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_10_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_1_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_1000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_10000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_500_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_10_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_1_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_160 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_500_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_10_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_1_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_50_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_100_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_500_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_10_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_1_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_160 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_500_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_10_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_1_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_1000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_10000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_500_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_10_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_1_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_160 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_500_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_10_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_1_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_50_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_100_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_500_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_10_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_1_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_160 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_500_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_10_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_1_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_1000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_10000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_500_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_10_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_1_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_160 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_500_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_10_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_1_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_50_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_100_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_500_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_10_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_1_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_160 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_500_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_10_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_1_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_1000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_10000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_500_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_10_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_1_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_160 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_500_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# ...
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_100_wc_t_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_100_wc_t_160 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_100_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_500_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_10_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_1_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_50_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_100_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_500_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_10_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_1_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_160 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_500_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_10_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_1_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_1000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_10000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_500_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_10_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_1_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_40 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_160 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_500_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_10_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_1_wc_t_-1000000 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_50_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py
# ===================================================
#  Syncing Current Working Directory with Cluster
# ===================================================
# source $HOME/.bashrc_paraview; bsub -n 1 -W 60 -R "rusage[mem=1024]" -J a_v_1000_cov__0_dp_100_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_10 -o postprocess.out -e std_err.log  mpirun /cluster/home/mavt/vjan/ParaView-4.0.1-Linux-64bit/bin/pvbatch --use-offscreen-rendering line_avg.py

# %%
def filter_file(sim):
    sim.cp()
    filename = os.path.join(sim.info.local["sim_folder"],"std_out.log_cluster")
    file_obj = open(filename)
    last_job = []
    for line in file_obj:
        last_job.append(line)
        if "Your job looked like" in line:
            last_job = []
            
    for line in last_job:       
        if "---> iteration stops here" in line:
            sim.sim_info["converged"] = True
            return "converged"

    sim.sim_info["converged"] = False
    return None

# %%
try:
    sh.rmtree("logfiles")
except:
   pass
os.mkdir("logfiles")

for sim in sim_list:
    if not filter_file(sim):
        #sim.run_sim(nproc="4",memory="1024",time='480',njobs=1,restart=False) 
        sh.copy(os.path.join(sim.info.local["sim_folder"],"std_out.log_cluster"),os.path.join("logfiles",sim.info.local["jobname"]))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-15-c8f1521342fd> in <module>()
#       6
#       7 for sim in sim_list:
# ----> 8     if not filter_file(sim):
#       9         #sim.run_sim(nproc="4",memory="1024",time='480',njobs=1,restart=False)
#      10         sh.copy(os.path.join(sim.info.local["sim_folder"],"std_out.log_cluster"),os.path.join("logfiles",sim.info.local["jobname"]))
#
# <ipython-input-14-6569f08d4252> in filter_file(sim)
#       1 def filter_file(sim):
# ----> 2     sim.cp()
#       3     filename = os.path.join(sim.info.local["sim_folder"],"std_out.log_cluster")
#       4     file_obj = open(filename)
#       5     last_job = []
#
# /home/vonrickenbach/contrib_git/python/cluster_interface/simulation_brutus.pyc in cp(self, filename)
#     697
#     698    def cp(self,filename='std_out.log'):
# --> 699       self.communicator.cp(filename=filename)
#     700
#     701    def kill(self):
#
# /home/vonrickenbach/contrib_git/python/cluster_interface/simulation_brutus.pyc in cp(self, filename)
#     512
#     513       cp_command = cp_command.split()
# --> 514       self.sim_class.command_runner(cp_command)
#     515
#     516 class status_handler:
#
# /home/vonrickenbach/contrib_git/python/cluster_interface/simulation_brutus.pyc in __call__(self, command, quiet, wait)
#      96       process = sp.Popen(temp_command,cwd=directory,shell=False,stdout=open(os.path.join(directory,"std_out_commands.log"),'a'),stderr=None)
#      97       if wait:
# ---> 98          process.wait()
#      99       else:
#     100          self.sim_class.status_handler.process = process
#
# /usr/lib64/python2.7/subprocess.pyc in wait(self)
#    1289             if self.returncode is None:
#    1290                 try:
# -> 1291                     pid, sts = _eintr_retry_call(os.waitpid, self.pid, 0)
#    1292                 except OSError as e:
#    1293                     if e.errno != errno.ECHILD:
#
# /usr/lib64/python2.7/subprocess.pyc in _eintr_retry_call(func, *args)
#     476     while True:
#     477         try:
# --> 478             return func(*args)
#     479         except (OSError, IOError) as e:
#     480             if e.errno == errno.EINTR:
#
# KeyboardInterrupt:

# %%
def get_conv(sim):
    gas.TPX = [sim.sim_info["temperature"],1.015E5,[0.1,0,0,0.9-sim.sim_info["mf"]*1E-6,sim.sim_info["mf"]*1E-6]]
    mf_in=gas.Y[4]
    eval_factor = sim.sim_info["sh_number"]/2000. 
    eval_factor = 1
    try:
        avg_Y= np.interp(0.004/eval_factor,sim.wc_data["coords"],sim.wc_data["CO"])

        mf   =1-avg_Y/mf_in
    except:
       mf = -1
#    if mf <0.0:
#        mf = np.nan
    return mf

# %%
def get_var(sim,var):
   return max(0,sim.sim_info[var])

# %%
filter_simulations(sim_list,wc_thickness=10,temperature=400,wc_geo_area=500)
# Out:
# [<simulation_brutus.job instance at 0xcdea830>,
#  <simulation_brutus.job instance at 0x8735320>]

# %%
gas = ca.import_phases(os.path.join(ref_folder,"cantera_input.cti"),["gas"])[0]
par_inputs["no_wc"] = par_inputs["wc_geo_area"][:-1]

ext = ".eps"
#ext = ".png"
#colors = ["x",".","*",">","<","^"]
colors = ["r","b","g","y","c","t"] 

par_names = {"wc_thickness":["$t_{wc}$","$\mu m$",1],
             "mf":["$Y_{in}$","ppm",1],
             "wc_geo_area":["$F_{cat/geo}$","",1],
             "velocity":["U","m/s",1],
             "sh_number":["h'","",1],
             "dp":["$d_{wc}$","$nm$",1],
             "a_v":["$A_V$","$m^{-1}$",1],
             "nx":["$n_{wc}$","",1],
             "t_fac":["t fac","$m^{-1}$",1],
             "x_cells":["$n_x$","",1],
             "no_wc":["$F_{cat/geo}$","",1]}

for par,vals in par_inputs.iteritems():
 
   if len(vals) > 1:

     fig = pl.figure(figsize=figsize)
     ax  = fig.add_subplot(1,1,1)
     name = par+ext
     ncells = wc_ncells[:]          
     print(par,vals)
    
     for co in cov_co[:]:
               inputs = default_inputs.copy()
               for val,col in zip(vals,colors): 
                        inputs["cov_CO"] = co
                        mark = "-"
                        co_name = ""
                        if co==1:
                            mark = "--"
                            co_name = ""
                            
                        label = par_names[par][0] + ": "+str(val*par_names[par][2]).ljust(3) + " "+par_names[par][1] +""+ str(co_name)

                            
                        if par=="no_wc":
                            inputs["wc_geo_area"] = val
                            inputs["wc_thickness"] = -1E6
                        else:
                            inputs[par] = val
                            
                        if par == "wc_geo_area" and val == -1:
                            inputs["wc_thickness"] = -1E6
                            inputs["wc_geo_area"]  = 100
                            label = "Inst wc diff"
                                              
                        if co == 1:
                            label  = ""
                                      

                        sim_to_plot = sort_sims(filter_simulations(sim_list_py,**inputs),"temperature")

                       
                        ax.plot(get_array(sim_to_plot,get_var,"temperature"),get_array(sim_to_plot,get_conv),label=label,markersize=3,mfc=col,mec=col,linestyle=mark,color=col)


     diff_coeffs = []
     for temp in temperatures:
        gas.TPX = temp,1.00E5,[0.1,0.0,0.0,0.9-0.003,0.003]
        diff_coeffs.append(gas.mix_diff_coeffs[-1])
     if par!="sh_number":
            sh_n = [par_inputs["sh_number"][0]]
     else:
        sh_n = vals
     if par!="velocity":
        uvel_n = [par_inputs["velocity"][0]]
     else:
        uvel_n = vals   
     for col,sh_l in zip(colors,sh_n):
         for uvel in uvel_n:
            # label= "I Sh="+str(sh_l*0.0023)+", vel ="+str(uvel)
             label = "inf" 
             co = "k"
             ls = "-"
             if len(sh_n) > 1:
                    label = "" 
                    ls = "-."
                    co = col
             ax.plot(temperatures,1-np.exp(-np.array(diff_coeffs)*sh_l/uvel*1000*0.004/0.5)*np.ones(len(temperatures)),label=label,linewidth=1,linestyle=ls,color=co)
#             if par == "dp":
#                min_conv = 1-np.exp(-np.array(diff_coeffs)/(1/(0.35/4/4E-5) + 1./(sh_l))/uvel*1000*0.004/0.5)*np.ones(len(temperatures))    
#                cond = np.where((np.array(temperatures)<470) & (np.array(temperatures)>390))
#                label = "Assuming $\dot''{m}_min$"
#                ax.plot(np.array(temperatures)[cond],np.array(min_conv)[cond],label=label,linewidth=1,linestyle=":",color="k")

#     ax.set_xlim([400,600])
#     ax.set_ylim([0,0.9])

#     ax.plot(temperatures,1-np.exp(-np.array(diff_coeffs[-1])*4000/5*1000*0.005/0.5*(np.array(temperatures)/(temperatures[-1]*1.0))**1.5),label="T^3by2")

     handles, labels = ax.get_legend_handles_labels()
     vals,labels, handles = (list(x) for x in zip(*sorted(zip(vals+[1E20],labels, handles))))  
        
     ncol = 2
     
     if par == "mf":
            ncol = 1

     ax = pl.gca()

     ax.set_ylabel("$\chi$ (-)")
     ax.set_ylim(bottom=-0.005)
     ax.set_ylim([-0.005,0.81])
     loc = 2
     if par == "sh_number":
         ax.set_ylim([-0.005,1.001])
         loc = 4
         ncol = 1
                
     if par == "wc_geo_area":
         ax.set_ylim([-0.005,0.9])

               
     ax.legend(handles,labels,loc=loc,ncol=ncol,frameon=False,columnspacing =0.8)

     ax.set_xlabel("Temperature (K)")
     fig.tight_layout()
     fig.savefig("wc_plots/"+name,dpi=300,bbox_inches='tight',transparent=True)
# Out:
# ('t_fac', [1, 10, 0.1])
# ('mf', [3000, 1000, 10000])
# ('wc_geo_area', [100, 500, 10, 1, -1])
# ('nx', [64, 128, 32])
# ('x_cells', [20, 40])
# ('no_wc', [100, 500, 10, 1])
# ('sh_number', [4000, 8000, 16000])
# ('wc_thickness', [100, 10, 160, -1000000.0])
# ('dp', [10, 50, 5])

# %%
for item in filter_simulations(sim_list):
    if not filter_file(item):
        print(item.info.local["jobname"])
len(filter_simulations(sim_list,converged=False))
# Out:
# 0

# %%
gas.mi

# %%
res_list = filter_simulations(sim_list,temperature=440,cov_CO=1)

for sim in res_list:
    sim.cp("RESULT/Linf_resnorm.dat")

# %%
# Plot residuals

legendlist = []
filename = "RESULT/Linf_resnorm.dat"
varname = ".*Species05.*Linf.*end"
for sim in res_list:
  print(sim.get_log(filename))
  try:
      res_file     = pa.file_reader(sim.get_log(filename,n=0),comment="#")
#  pressure_res = res_file.get_column(".*Species01.*Linf.*end")[:]/np.amax(res_file.get_column(".*Species01.*Linf.*end")[:])
      pressure_res = res_file.get_column(varname)[:]/np.amax(res_file.get_column(varname)[:])

      pl.semilogy(abs(pressure_res))
      legendlist.append(sim.info.local["jobname"])
  except:
        pass
ax = pl.gca()
ax.set_xlim([0,1000])
ax.set_xlabel("Iteration")
ax.set_ylabel("Residual")
ax.legend(legendlist,bbox_to_anchor=(3,1))
# Out:
# /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10/RESULT/Linf_resnorm.dat_cluster
# #  1: Iteration                                                  #
# #  2: Pres-Divmax. residue (begin), global block number          #
#
# #  3: Pres-Divmax. residue (begin), i-index                      #
#
# #  4: Pres-Divmax. residue (begin), j-index                      #
#
# #  5: Pres-Divmax. residue (begin), k-index                      #
#
# #  6: Pres-Divmax. residue (  end), global block number          #
#
# #  7: Pres-Divmax. residue (  end), i-index                      #
#
# #  8: Pres-Divmax. residue (  end), j-index                      #
#
# #  9: Pres-Divmax. residue (  end), k-index                      #
#
# # 10: Pres-DivLinf(   begin)                                     #
#
# # 11: Pres-DivLinf(     end)                                     #
#
# # 12: Pres-DivLinf(relative)                                     #
#
# # 13: U-Velocitymax. residue (begin), global block number        #
#
# # 14: U-Velocitymax. residue (begin), i-index                    #
#
# # 15: U-Velocitymax. residue (begin), j-index                    #
#
# # 16: U-Velocitymax. residue (begin), k-index                    #
#
# # 17: U-Velocitymax. residue (  end), global block number        #
#
# # 18: U-Velocitymax. residue (  end), i-index                    #
#
# # 19: U-Velocitymax. residue (  end), j-index                    #
#
# # 20: U-Velocitymax. residue (  end), k-index                    #
#
# # 21: U-VelocityLinf(   begin)                                   #
#
# # 22: U-VelocityLinf(     end)                                   #
#
# # 23: U-VelocityLinf(relative)                                   #
#
# # 24: Temperaturemax. residue (begin), global block number       #
#
# # 25: Temperaturemax. residue (begin), i-index                   #
#
# # 26: Temperaturemax. residue (begin), j-index                   #
#
# # 27: Temperaturemax. residue (begin), k-index                   #
#
# # 28: Temperaturemax. residue (  end), global block number       #
#
# # 29: Temperaturemax. residue (  end), i-index                   #
#
# # 30: Temperaturemax. residue (  end), j-index                   #
#
# # 31: Temperaturemax. residue (  end), k-index                   #
#
# # 32: TemperatureLinf(   begin)                                  #
#
# # 33: TemperatureLinf(     end)                                  #
#
# # 34: TemperatureLinf(relative)                                  #
#
# # 35: Phase01_Species01max. residue (begin), global block number #
#
# # 36: Phase01_Species01max. residue (begin), i-index             #
#
# # 37: Phase01_Species01max. residue (begin), j-index             #
#
# # 38: Phase01_Species01max. residue (begin), k-index             #
#
# # 39: Phase01_Species01max. residue (  end), global block number #
#
# # 40: Phase01_Species01max. residue (  end), i-index             #
#
# # 41: Phase01_Species01max. residue (  end), j-index             #
#
# # 42: Phase01_Species01max. residue (  end), k-index             #
#
# # 43: Phase01_Species01Linf(   begin)                            #
#
# # 44: Phase01_Species01Linf(     end)                            #
#
# # 45: Phase01_Species01Linf(relative)                            #
#
# # 46: Phase01_Species02max. residue (begin), global block number #
#
# # 47: Phase01_Species02max. residue (begin), i-index             #
#
# # 48: Phase01_Species02max. residue (begin), j-index             #
#
# # 49: Phase01_Species02max. residue (begin), k-index             #
#
# # 50: Phase01_Species02max. residue (  end), global block number #
#
# # 51: Phase01_Species02max. residue (  end), i-index             #
#
# # 52: Phase01_Species02max. residue (  end), j-index             #
#
# # 53: Phase01_Species02max. residue (  end), k-index             #
#
# # 54: Phase01_Species02Linf(   begin)                            #
#
# # 55: Phase01_Species02Linf(     end)                            #
#
# # 56: Phase01_Species02Linf(relative)                            #
#
# # 57: Phase01_Species03max. residue (begin), global block number #
#
# # 58: Phase01_Species03max. residue (begin), i-index             #
#
# # 59: Phase01_Species03max. residue (begin), j-index             #
#
# # 60: Phase01_Species03max. residue (begin), k-index             #
#
# # 61: Phase01_Species03max. residue (  end), global block number #
#
# # 62: Phase01_Species03max. residue (  end), i-index             #
#
# # 63: Phase01_Species03max. residue (  end), j-index             #
#
# # 64: Phase01_Species03max. residue (  end), k-index             #
#
# # 65: Phase01_Species03Linf(   begin)                            #
#
# # 66: Phase01_Species03Linf(     end)                            #
#
# # 67: Phase01_Species03Linf(relative)                            #
#
# # 68: Phase01_Species04max. residue (begin), global block number #
#
# # 69: Phase01_Species04max. residue (begin), i-index             #
#
# # 70: Phase01_Species04max. residue (begin), j-index             #
#
# # 71: Phase01_Species04max. residue (begin), k-index             #
#
# # 72: Phase01_Species04max. residue (  end), global block number #
#
# # 73: Phase01_Species04max. residue (  end), i-index             #
#
# # 74: Phase01_Species04max. residue (  end), j-index             #
#
# # 75: Phase01_Species04max. residue (  end), k-index             #
#
# # 76: Phase01_Species04Linf(   begin)                            #
#
# # 77: Phase01_Species04Linf(     end)                            #
#
# # 78: Phase01_Species04Linf(relative)                            #
#
# # 79: Phase01_Species05max. residue (begin), global block number #
#
# # 80: Phase01_Species05max. residue (begin), i-index             #
#
# # 81: Phase01_Species05max. residue (begin), j-index             #
#
# # 82: Phase01_Species05max. residue (begin), k-index             #
#
# # 83: Phase01_Species05max. residue (  end), global block number #
#
# # 84: Phase01_Species05max. residue (  end), i-index             #
#
# # 85: Phase01_Species05max. residue (  end), j-index             #
#
# # 86: Phase01_Species05max. residue (  end), k-index             #
#
# # 87: Phase01_Species05Linf(   begin)                            #
#
# # 88: Phase01_Species05Linf(     end)                            #
#
# # 89: Phase01_Species05Linf(relative)                            #
#
# /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_10000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10/RESULT/Linf_resnorm.dat_cluster
# #  1: Iteration                                                  #
# #  2: Pres-Divmax. residue (begin), global block number          #
#
# #  3: Pres-Divmax. residue (begin), i-index                      #
#
# #  4: Pres-Divmax. residue (begin), j-index                      #
#
# #  5: Pres-Divmax. residue (begin), k-index                      #
#
# #  6: Pres-Divmax. residue (  end), global block number          #
#
# #  7: Pres-Divmax. residue (  end), i-index                      #
#
# #  8: Pres-Divmax. residue (  end), j-index                      #
#
# #  9: Pres-Divmax. residue (  end), k-index                      #
#
# # 10: Pres-DivLinf(   begin)                                     #
#
# # 11: Pres-DivLinf(     end)                                     #
#
# # 12: Pres-DivLinf(relative)                                     #
#
# # 13: U-Velocitymax. residue (begin), global block number        #
#
# # 14: U-Velocitymax. residue (begin), i-index                    #
#
# # 15: U-Velocitymax. residue (begin), j-index                    #
#
# # 16: U-Velocitymax. residue (begin), k-index                    #
#
# # 17: U-Velocitymax. residue (  end), global block number        #
#
# # 18: U-Velocitymax. residue (  end), i-index                    #
#
# # 19: U-Velocitymax. residue (  end), j-index                    #
#
# # 20: U-Velocitymax. residue (  end), k-index                    #
#
# # 21: U-VelocityLinf(   begin)                                   #
#
# # 22: U-VelocityLinf(     end)                                   #
#
# # 23: U-VelocityLinf(relative)                                   #
#
# # 24: Temperaturemax. residue (begin), global block number       #
#
# # 25: Temperaturemax. residue (begin), i-index                   #
#
# # 26: Temperaturemax. residue (begin), j-index                   #
#
# # 27: Temperaturemax. residue (begin), k-index                   #
#
# # 28: Temperaturemax. residue (  end), global block number       #
#
# # 29: Temperaturemax. residue (  end), i-index                   #
#
# # 30: Temperaturemax. residue (  end), j-index                   #
#
# # 31: Temperaturemax. residue (  end), k-index                   #
#
# # 32: TemperatureLinf(   begin)                                  #
#
# # 33: TemperatureLinf(     end)                                  #
#
# # 34: TemperatureLinf(relative)                                  #
#
# # 35: Phase01_Species01max. residue (begin), global block number #
#
# # 36: Phase01_Species01max. residue (begin), i-index             #
#
# # 37: Phase01_Species01max. residue (begin), j-index             #
#
# # 38: Phase01_Species01max. residue (begin), k-index             #
#
# # 39: Phase01_Species01max. residue (  end), global block number #
#
# # 40: Phase01_Species01max. residue (  end), i-index             #
#
# # 41: Phase01_Species01max. residue (  end), j-index             #
#
# # 42: Phase01_Species01max. residue (  end), k-index             #
#
# # 43: Phase01_Species01Linf(   begin)                            #
#
# # 44: Phase01_Species01Linf(     end)                            #
#
# # 45: Phase01_Species01Linf(relative)                            #
#
# # 46: Phase01_Species02max. residue (begin), global block number #
#
# # 47: Phase01_Species02max. residue (begin), i-index             #
#
# # 48: Phase01_Species02max. residue (begin), j-index             #
#
# # 49: Phase01_Species02max. residue (begin), k-index             #
#
# # 50: Phase01_Species02max. residue (  end), global block number #
#
# # 51: Phase01_Species02max. residue (  end), i-index             #
#
# # 52: Phase01_Species02max. residue (  end), j-index             #
#
# # 53: Phase01_Species02max. residue (  end), k-index             #
#
# # 54: Phase01_Species02Linf(   begin)                            #
#
# # 55: Phase01_Species02Linf(     end)                            #
#
# # 56: Phase01_Species02Linf(relative)                            #
#
# # 57: Phase01_Species03max. residue (begin), global block number #
#
# # 58: Phase01_Species03max. residue (begin), i-index             #
#
# # 59: Phase01_Species03max. residue (begin), j-index             #
#
# # 60: Phase01_Species03max. residue (begin), k-index             #
#
# # 61: Phase01_Species03max. residue (  end), global block number #
#
# # 62: Phase01_Species03max. residue (  end), i-index             #
#
# # 63: Phase01_Species03max. residue (  end), j-index             #
#
# # 64: Phase01_Species03max. residue (  end), k-index             #
#
# # 65: Phase01_Species03Linf(   begin)                            #
#
# # 66: Phase01_Species03Linf(     end)                            #
#
# # 67: Phase01_Species03Linf(relative)                            #
#
# # 68: Phase01_Species04max. residue (begin), global block number #
#
# # 69: Phase01_Species04max. residue (begin), i-index             #
#
# # 70: Phase01_Species04max. residue (begin), j-index             #
#
# # 71: Phase01_Species04max. residue (begin), k-index             #
#
# # 72: Phase01_Species04max. residue (  end), global block number #
#
# # 73: Phase01_Species04max. residue (  end), i-index             #
#
# # 74: Phase01_Species04max. residue (  end), j-index             #
#
# # 75: Phase01_Species04max. residue (  end), k-index             #
#
# # 76: Phase01_Species04Linf(   begin)                            #
#
# # 77: Phase01_Species04Linf(     end)                            #
#
# # 78: Phase01_Species04Linf(relative)                            #
#
# # 79: Phase01_Species05max. residue (begin), global block number #
#
# # 80: Phase01_Species05max. residue (begin), i-index             #
#
# # 81: Phase01_Species05max. residue (begin), j-index             #
#
# # 82: Phase01_Species05max. residue (begin), k-index             #
#
# # 83: Phase01_Species05max. residue (  end), global block number #
#
# # 84: Phase01_Species05max. residue (  end), i-index             #
#
# # 85: Phase01_Species05max. residue (  end), j-index             #
#
# # 86: Phase01_Species05max. residue (  end), k-index             #
#
# # 87: Phase01_Species05Linf(   begin)                            #
#
# # 88: Phase01_Species05Linf(     end)                            #
#
# # 89: Phase01_Species05Linf(relative)                            #
#
# /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_1_wc_nc_32_wc_th_10/RESULT/Linf_resnorm.dat_cluster
# #  1: Iteration                                                  #
# #  2: Pres-Divmax. residue (begin), global block number          #
#
# #  3: Pres-Divmax. residue (begin), i-index                      #
#
# #  4: Pres-Divmax. residue (begin), j-index                      #
#
# #  5: Pres-Divmax. residue (begin), k-index                      #
#
# #  6: Pres-Divmax. residue (  end), global block number          #
#
# #  7: Pres-Divmax. residue (  end), i-index                      #
#
# #  8: Pres-Divmax. residue (  end), j-index                      #
#
# #  9: Pres-Divmax. residue (  end), k-index                      #
#
# # 10: Pres-DivLinf(   begin)                                     #
#
# # 11: Pres-DivLinf(     end)                                     #
#
# # 12: Pres-DivLinf(relative)                                     #
#
# # 13: U-Velocitymax. residue (begin), global block number        #
#
# # 14: U-Velocitymax. residue (begin), i-index                    #
#
# # 15: U-Velocitymax. residue (begin), j-index                    #
#
# # 16: U-Velocitymax. residue (begin), k-index                    #
#
# # 17: U-Velocitymax. residue (  end), global block number        #
#
# # 18: U-Velocitymax. residue (  end), i-index                    #
#
# # 19: U-Velocitymax. residue (  end), j-index                    #
#
# # 20: U-Velocitymax. residue (  end), k-index                    #
#
# # 21: U-VelocityLinf(   begin)                                   #
#
# # 22: U-VelocityLinf(     end)                                   #
#
# # 23: U-VelocityLinf(relative)                                   #
#
# # 24: Temperaturemax. residue (begin), global block number       #
#
# # 25: Temperaturemax. residue (begin), i-index                   #
#
# # 26: Temperaturemax. residue (begin), j-index                   #
#
# # 27: Temperaturemax. residue (begin), k-index                   #
#
# # 28: Temperaturemax. residue (  end), global block number       #
#
# # 29: Temperaturemax. residue (  end), i-index                   #
#
# # 30: Temperaturemax. residue (  end), j-index                   #
#
# # 31: Temperaturemax. residue (  end), k-index                   #
#
# # 32: TemperatureLinf(   begin)                                  #
#
# # 33: TemperatureLinf(     end)                                  #
#
# # 34: TemperatureLinf(relative)                                  #
#
# # 35: Phase01_Species01max. residue (begin), global block number #
#
# # 36: Phase01_Species01max. residue (begin), i-index             #
#
# # 37: Phase01_Species01max. residue (begin), j-index             #
#
# # 38: Phase01_Species01max. residue (begin), k-index             #
#
# # 39: Phase01_Species01max. residue (  end), global block number #
#
# # 40: Phase01_Species01max. residue (  end), i-index             #
#
# # 41: Phase01_Species01max. residue (  end), j-index             #
#
# # 42: Phase01_Species01max. residue (  end), k-index             #
#
# # 43: Phase01_Species01Linf(   begin)                            #
#
# # 44: Phase01_Species01Linf(     end)                            #
#
# # 45: Phase01_Species01Linf(relative)                            #
#
# # 46: Phase01_Species02max. residue (begin), global block number #
#
# # 47: Phase01_Species02max. residue (begin), i-index             #
#
# # 48: Phase01_Species02max. residue (begin), j-index             #
#
# # 49: Phase01_Species02max. residue (begin), k-index             #
#
# # 50: Phase01_Species02max. residue (  end), global block number #
#
# # 51: Phase01_Species02max. residue (  end), i-index             #
#
# # 52: Phase01_Species02max. residue (  end), j-index             #
#
# # 53: Phase01_Species02max. residue (  end), k-index             #
#
# # 54: Phase01_Species02Linf(   begin)                            #
#
# # 55: Phase01_Species02Linf(     end)                            #
#
# # 56: Phase01_Species02Linf(relative)                            #
#
# # 57: Phase01_Species03max. residue (begin), global block number #
#
# # 58: Phase01_Species03max. residue (begin), i-index             #
#
# # 59: Phase01_Species03max. residue (begin), j-index             #
#
# # 60: Phase01_Species03max. residue (begin), k-index             #
#
# # 61: Phase01_Species03max. residue (  end), global block number #
#
# # 62: Phase01_Species03max. residue (  end), i-index             #
#
# # 63: Phase01_Species03max. residue (  end), j-index             #
#
# # 64: Phase01_Species03max. residue (  end), k-index             #
#
# # 65: Phase01_Species03Linf(   begin)                            #
#
# # 66: Phase01_Species03Linf(     end)                            #
#
# # 67: Phase01_Species03Linf(relative)                            #
#
# # 68: Phase01_Species04max. residue (begin), global block number #
#
# # 69: Phase01_Species04max. residue (begin), i-index             #
#
# # 70: Phase01_Species04max. residue (begin), j-index             #
#
# # 71: Phase01_Species04max. residue (begin), k-index             #
#
# # 72: Phase01_Species04max. residue (  end), global block number #
#
# # 73: Phase01_Species04max. residue (  end), i-index             #
#
# # 74: Phase01_Species04max. residue (  end), j-index             #
#
# # 75: Phase01_Species04max. residue (  end), k-index             #
#
# # 76: Phase01_Species04Linf(   begin)                            #
#
# # 77: Phase01_Species04Linf(     end)                            #
#
# # 78: Phase01_Species04Linf(relative)                            #
#
# # 79: Phase01_Species05max. residue (begin), global block number #
#
# # 80: Phase01_Species05max. residue (begin), i-index             #
#
# # 81: Phase01_Species05max. residue (begin), j-index             #
#
# # 82: Phase01_Species05max. residue (begin), k-index             #
#
# # 83: Phase01_Species05max. residue (  end), global block number #
#
# # 84: Phase01_Species05max. residue (  end), i-index             #
#
# # 85: Phase01_Species05max. residue (  end), j-index             #
#
# # 86: Phase01_Species05max. residue (  end), k-index             #
#
# # 87: Phase01_Species05Linf(   begin)                            #
#
# # 88: Phase01_Species05Linf(     end)                            #
#
# # 89: Phase01_Species05Linf(relative)                            #
#
# /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_10_wc_nc_32_wc_th_10/RESULT/Linf_resnorm.dat_cluster
# #  1: Iteration                                                  #
# #  2: Pres-Divmax. residue (begin), global block number          #
#
# #  3: Pres-Divmax. residue (begin), i-index                      #
#
# #  4: Pres-Divmax. residue (begin), j-index                      #
#
# #  5: Pres-Divmax. residue (begin), k-index                      #
#
# #  6: Pres-Divmax. residue (  end), global block number          #
#
# #  7: Pres-Divmax. residue (  end), i-index                      #
#
# #  8: Pres-Divmax. residue (  end), j-index                      #
#
# #  9: Pres-Divmax. residue (  end), k-index                      #
#
# # 10: Pres-DivLinf(   begin)                                     #
#
# # 11: Pres-DivLinf(     end)                                     #
#
# # 12: Pres-DivLinf(relative)                                     #
#
# # 13: U-Velocitymax. residue (begin), global block number        #
#
# # 14: U-Velocitymax. residue (begin), i-index                    #
#
# # 15: U-Velocitymax. residue (begin), j-index                    #
#
# # 16: U-Velocitymax. residue (begin), k-index                    #
#
# # 17: U-Velocitymax. residue (  end), global block number        #
#
# # 18: U-Velocitymax. residue (  end), i-index                    #
#
# # 19: U-Velocitymax. residue (  end), j-index                    #
#
# # 20: U-Velocitymax. residue (  end), k-index                    #
#
# # 21: U-VelocityLinf(   begin)                                   #
#
# # 22: U-VelocityLinf(     end)                                   #
#
# # 23: U-VelocityLinf(relative)                                   #
#
# # 24: Temperaturemax. residue (begin), global block number       #
#
# # 25: Temperaturemax. residue (begin), i-index                   #
#
# # 26: Temperaturemax. residue (begin), j-index                   #
#
# # 27: Temperaturemax. residue (begin), k-index                   #
#
# # 28: Temperaturemax. residue (  end), global block number       #
#
# # 29: Temperaturemax. residue (  end), i-index                   #
#
# # 30: Temperaturemax. residue (  end), j-index                   #
#
# # 31: Temperaturemax. residue (  end), k-index                   #
#
# # 32: TemperatureLinf(   begin)                                  #
#
# # 33: TemperatureLinf(     end)                                  #
#
# # 34: TemperatureLinf(relative)                                  #
#
# # 35: Phase01_Species01max. residue (begin), global block number #
#
# # 36: Phase01_Species01max. residue (begin), i-index             #
#
# # 37: Phase01_Species01max. residue (begin), j-index             #
#
# # 38: Phase01_Species01max. residue (begin), k-index             #
#
# # 39: Phase01_Species01max. residue (  end), global block number #
#
# # 40: Phase01_Species01max. residue (  end), i-index             #
#
# # 41: Phase01_Species01max. residue (  end), j-index             #
#
# # 42: Phase01_Species01max. residue (  end), k-index             #
#
# # 43: Phase01_Species01Linf(   begin)                            #
#
# # 44: Phase01_Species01Linf(     end)                            #
#
# # 45: Phase01_Species01Linf(relative)                            #
#
# # 46: Phase01_Species02max. residue (begin), global block number #
#
# # 47: Phase01_Species02max. residue (begin), i-index             #
#
# # 48: Phase01_Species02max. residue (begin), j-index             #
#
# # 49: Phase01_Species02max. residue (begin), k-index             #
#
# # 50: Phase01_Species02max. residue (  end), global block number #
#
# # 51: Phase01_Species02max. residue (  end), i-index             #
#
# # 52: Phase01_Species02max. residue (  end), j-index             #
#
# # 53: Phase01_Species02max. residue (  end), k-index             #
#
# # 54: Phase01_Species02Linf(   begin)                            #
#
# # 55: Phase01_Species02Linf(     end)                            #
#
# # 56: Phase01_Species02Linf(relative)                            #
#
# # 57: Phase01_Species03max. residue (begin), global block number #
#
# # 58: Phase01_Species03max. residue (begin), i-index             #
#
# # 59: Phase01_Species03max. residue (begin), j-index             #
#
# # 60: Phase01_Species03max. residue (begin), k-index             #
#
# # 61: Phase01_Species03max. residue (  end), global block number #
#
# # 62: Phase01_Species03max. residue (  end), i-index             #
#
# # 63: Phase01_Species03max. residue (  end), j-index             #
#
# # 64: Phase01_Species03max. residue (  end), k-index             #
#
# # 65: Phase01_Species03Linf(   begin)                            #
#
# # 66: Phase01_Species03Linf(     end)                            #
#
# # 67: Phase01_Species03Linf(relative)                            #
#
# # 68: Phase01_Species04max. residue (begin), global block number #
#
# # 69: Phase01_Species04max. residue (begin), i-index             #
#
# # 70: Phase01_Species04max. residue (begin), j-index             #
#
# # 71: Phase01_Species04max. residue (begin), k-index             #
#
# # 72: Phase01_Species04max. residue (  end), global block number #
#
# # 73: Phase01_Species04max. residue (  end), i-index             #
#
# # 74: Phase01_Species04max. residue (  end), j-index             #
#
# # 75: Phase01_Species04max. residue (  end), k-index             #
#
# # 76: Phase01_Species04Linf(   begin)                            #
#
# # 77: Phase01_Species04Linf(     end)                            #
#
# # 78: Phase01_Species04Linf(relative)                            #
#
# # 79: Phase01_Species05max. residue (begin), global block number #
#
# # 80: Phase01_Species05max. residue (begin), i-index             #
#
# # 81: Phase01_Species05max. residue (begin), j-index             #
#
# # 82: Phase01_Species05max. residue (begin), k-index             #
#
# # 83: Phase01_Species05max. residue (  end), global block number #
#
# # 84: Phase01_Species05max. residue (  end), i-index             #
#
# # 85: Phase01_Species05max. residue (  end), j-index             #
#
# # 86: Phase01_Species05max. residue (  end), k-index             #
#
# # 87: Phase01_Species05Linf(   begin)                            #
#
# # 88: Phase01_Species05Linf(     end)                            #
#
# # 89: Phase01_Species05Linf(relative)                            #
#
# /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_500_wc_nc_32_wc_th_10/RESULT/Linf_resnorm.dat_cluster
# #  1: Iteration                                                  #
# #  2: Pres-Divmax. residue (begin), global block number          #
#
# #  3: Pres-Divmax. residue (begin), i-index                      #
#
# #  4: Pres-Divmax. residue (begin), j-index                      #
#
# #  5: Pres-Divmax. residue (begin), k-index                      #
#
# #  6: Pres-Divmax. residue (  end), global block number          #
#
# #  7: Pres-Divmax. residue (  end), i-index                      #
#
# #  8: Pres-Divmax. residue (  end), j-index                      #
#
# #  9: Pres-Divmax. residue (  end), k-index                      #
#
# # 10: Pres-DivLinf(   begin)                                     #
#
# # 11: Pres-DivLinf(     end)                                     #
#
# # 12: Pres-DivLinf(relative)                                     #
#
# # 13: U-Velocitymax. residue (begin), global block number        #
#
# # 14: U-Velocitymax. residue (begin), i-index                    #
#
# # 15: U-Velocitymax. residue (begin), j-index                    #
#
# # 16: U-Velocitymax. residue (begin), k-index                    #
#
# # 17: U-Velocitymax. residue (  end), global block number        #
#
# # 18: U-Velocitymax. residue (  end), i-index                    #
#
# # 19: U-Velocitymax. residue (  end), j-index                    #
#
# # 20: U-Velocitymax. residue (  end), k-index                    #
#
# # 21: U-VelocityLinf(   begin)                                   #
#
# # 22: U-VelocityLinf(     end)                                   #
#
# # 23: U-VelocityLinf(relative)                                   #
#
# # 24: Temperaturemax. residue (begin), global block number       #
#
# # 25: Temperaturemax. residue (begin), i-index                   #
#
# # 26: Temperaturemax. residue (begin), j-index                   #
#
# # 27: Temperaturemax. residue (begin), k-index                   #
#
# # 28: Temperaturemax. residue (  end), global block number       #
#
# # 29: Temperaturemax. residue (  end), i-index                   #
#
# # 30: Temperaturemax. residue (  end), j-index                   #
#
# # 31: Temperaturemax. residue (  end), k-index                   #
#
# # 32: TemperatureLinf(   begin)                                  #
#
# # 33: TemperatureLinf(     end)                                  #
#
# # 34: TemperatureLinf(relative)                                  #
#
# # 35: Phase01_Species01max. residue (begin), global block number #
#
# # 36: Phase01_Species01max. residue (begin), i-index             #
#
# # 37: Phase01_Species01max. residue (begin), j-index             #
#
# # 38: Phase01_Species01max. residue (begin), k-index             #
#
# # 39: Phase01_Species01max. residue (  end), global block number #
#
# # 40: Phase01_Species01max. residue (  end), i-index             #
#
# # 41: Phase01_Species01max. residue (  end), j-index             #
#
# # 42: Phase01_Species01max. residue (  end), k-index             #
#
# # 43: Phase01_Species01Linf(   begin)                            #
#
# # 44: Phase01_Species01Linf(     end)                            #
#
# # 45: Phase01_Species01Linf(relative)                            #
#
# # 46: Phase01_Species02max. residue (begin), global block number #
#
# # 47: Phase01_Species02max. residue (begin), i-index             #
#
# # 48: Phase01_Species02max. residue (begin), j-index             #
#
# # 49: Phase01_Species02max. residue (begin), k-index             #
#
# # 50: Phase01_Species02max. residue (  end), global block number #
#
# # 51: Phase01_Species02max. residue (  end), i-index             #
#
# # 52: Phase01_Species02max. residue (  end), j-index             #
#
# # 53: Phase01_Species02max. residue (  end), k-index             #
#
# # 54: Phase01_Species02Linf(   begin)                            #
#
# # 55: Phase01_Species02Linf(     end)                            #
#
# # 56: Phase01_Species02Linf(relative)                            #
#
# # 57: Phase01_Species03max. residue (begin), global block number #
#
# # 58: Phase01_Species03max. residue (begin), i-index             #
#
# # 59: Phase01_Species03max. residue (begin), j-index             #
#
# # 60: Phase01_Species03max. residue (begin), k-index             #
#
# # 61: Phase01_Species03max. residue (  end), global block number #
#
# # 62: Phase01_Species03max. residue (  end), i-index             #
#
# # 63: Phase01_Species03max. residue (  end), j-index             #
#
# # 64: Phase01_Species03max. residue (  end), k-index             #
#
# # 65: Phase01_Species03Linf(   begin)                            #
#
# # 66: Phase01_Species03Linf(     end)                            #
#
# # 67: Phase01_Species03Linf(relative)                            #
#
# # 68: Phase01_Species04max. residue (begin), global block number #
#
# # 69: Phase01_Species04max. residue (begin), i-index             #
#
# # 70: Phase01_Species04max. residue (begin), j-index             #
#
# # 71: Phase01_Species04max. residue (begin), k-index             #
#
# # 72: Phase01_Species04max. residue (  end), global block number #
#
# # 73: Phase01_Species04max. residue (  end), i-index             #
#
# # 74: Phase01_Species04max. residue (  end), j-index             #
#
# # 75: Phase01_Species04max. residue (  end), k-index             #
#
# # 76: Phase01_Species04Linf(   begin)                            #
#
# # 77: Phase01_Species04Linf(     end)                            #
#
# # 78: Phase01_Species04Linf(relative)                            #
#
# # 79: Phase01_Species05max. residue (begin), global block number #
#
# # 80: Phase01_Species05max. residue (begin), i-index             #
#
# # 81: Phase01_Species05max. residue (begin), j-index             #
#
# # 82: Phase01_Species05max. residue (begin), k-index             #
#
# # 83: Phase01_Species05max. residue (  end), global block number #
#
# # 84: Phase01_Species05max. residue (  end), i-index             #
#
# # 85: Phase01_Species05max. residue (  end), j-index             #
#
# # 86: Phase01_Species05max. residue (  end), k-index             #
#
# # 87: Phase01_Species05Linf(   begin)                            #
#
# # 88: Phase01_Species05Linf(     end)                            #
#
# # 89: Phase01_Species05Linf(relative)                            #
#
# /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_2000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10/RESULT/Linf_resnorm.dat_cluster
# #  1: Iteration                                                  #
# #  2: Pres-Divmax. residue (begin), global block number          #
#
# #  3: Pres-Divmax. residue (begin), i-index                      #
#
# #  4: Pres-Divmax. residue (begin), j-index                      #
#
# #  5: Pres-Divmax. residue (begin), k-index                      #
#
# #  6: Pres-Divmax. residue (  end), global block number          #
#
# #  7: Pres-Divmax. residue (  end), i-index                      #
#
# #  8: Pres-Divmax. residue (  end), j-index                      #
#
# #  9: Pres-Divmax. residue (  end), k-index                      #
#
# # 10: Pres-DivLinf(   begin)                                     #
#
# # 11: Pres-DivLinf(     end)                                     #
#
# # 12: Pres-DivLinf(relative)                                     #
#
# # 13: U-Velocitymax. residue (begin), global block number        #
#
# # 14: U-Velocitymax. residue (begin), i-index                    #
#
# # 15: U-Velocitymax. residue (begin), j-index                    #
#
# # 16: U-Velocitymax. residue (begin), k-index                    #
#
# # 17: U-Velocitymax. residue (  end), global block number        #
#
# # 18: U-Velocitymax. residue (  end), i-index                    #
#
# # 19: U-Velocitymax. residue (  end), j-index                    #
#
# # 20: U-Velocitymax. residue (  end), k-index                    #
#
# # 21: U-VelocityLinf(   begin)                                   #
#
# # 22: U-VelocityLinf(     end)                                   #
#
# # 23: U-VelocityLinf(relative)                                   #
#
# # 24: Temperaturemax. residue (begin), global block number       #
#
# # 25: Temperaturemax. residue (begin), i-index                   #
#
# # 26: Temperaturemax. residue (begin), j-index                   #
#
# # 27: Temperaturemax. residue (begin), k-index                   #
#
# # 28: Temperaturemax. residue (  end), global block number       #
#
# # 29: Temperaturemax. residue (  end), i-index                   #
#
# # 30: Temperaturemax. residue (  end), j-index                   #
#
# # 31: Temperaturemax. residue (  end), k-index                   #
#
# # 32: TemperatureLinf(   begin)                                  #
#
# # 33: TemperatureLinf(     end)                                  #
#
# # 34: TemperatureLinf(relative)                                  #
#
# # 35: Phase01_Species01max. residue (begin), global block number #
#
# # 36: Phase01_Species01max. residue (begin), i-index             #
#
# # 37: Phase01_Species01max. residue (begin), j-index             #
#
# # 38: Phase01_Species01max. residue (begin), k-index             #
#
# # 39: Phase01_Species01max. residue (  end), global block number #
#
# # 40: Phase01_Species01max. residue (  end), i-index             #
#
# # 41: Phase01_Species01max. residue (  end), j-index             #
#
# # 42: Phase01_Species01max. residue (  end), k-index             #
#
# # 43: Phase01_Species01Linf(   begin)                            #
#
# # 44: Phase01_Species01Linf(     end)                            #
#
# # 45: Phase01_Species01Linf(relative)                            #
#
# # 46: Phase01_Species02max. residue (begin), global block number #
#
# # 47: Phase01_Species02max. residue (begin), i-index             #
#
# # 48: Phase01_Species02max. residue (begin), j-index             #
#
# # 49: Phase01_Species02max. residue (begin), k-index             #
#
# # 50: Phase01_Species02max. residue (  end), global block number #
#
# # 51: Phase01_Species02max. residue (  end), i-index             #
#
# # 52: Phase01_Species02max. residue (  end), j-index             #
#
# # 53: Phase01_Species02max. residue (  end), k-index             #
#
# # 54: Phase01_Species02Linf(   begin)                            #
#
# # 55: Phase01_Species02Linf(     end)                            #
#
# # 56: Phase01_Species02Linf(relative)                            #
#
# # 57: Phase01_Species03max. residue (begin), global block number #
#
# # 58: Phase01_Species03max. residue (begin), i-index             #
#
# # 59: Phase01_Species03max. residue (begin), j-index             #
#
# # 60: Phase01_Species03max. residue (begin), k-index             #
#
# # 61: Phase01_Species03max. residue (  end), global block number #
#
# # 62: Phase01_Species03max. residue (  end), i-index             #
#
# # 63: Phase01_Species03max. residue (  end), j-index             #
#
# # 64: Phase01_Species03max. residue (  end), k-index             #
#
# # 65: Phase01_Species03Linf(   begin)                            #
#
# # 66: Phase01_Species03Linf(     end)                            #
#
# # 67: Phase01_Species03Linf(relative)                            #
#
# # 68: Phase01_Species04max. residue (begin), global block number #
#
# # 69: Phase01_Species04max. residue (begin), i-index             #
#
# # 70: Phase01_Species04max. residue (begin), j-index             #
#
# # 71: Phase01_Species04max. residue (begin), k-index             #
#
# # 72: Phase01_Species04max. residue (  end), global block number #
#
# # 73: Phase01_Species04max. residue (  end), i-index             #
#
# # 74: Phase01_Species04max. residue (  end), j-index             #
#
# # 75: Phase01_Species04max. residue (  end), k-index             #
#
# # 76: Phase01_Species04Linf(   begin)                            #
#
# # 77: Phase01_Species04Linf(     end)                            #
#
# # 78: Phase01_Species04Linf(relative)                            #
#
# # 79: Phase01_Species05max. residue (begin), global block number #
#
# # 80: Phase01_Species05max. residue (begin), i-index             #
#
# # 81: Phase01_Species05max. residue (begin), j-index             #
#
# # 82: Phase01_Species05max. residue (begin), k-index             #
#
# # 83: Phase01_Species05max. residue (  end), global block number #
#
# # 84: Phase01_Species05max. residue (  end), i-index             #
#
# # 85: Phase01_Species05max. residue (  end), j-index             #
#
# # 86: Phase01_Species05max. residue (  end), k-index             #
#
# # 87: Phase01_Species05Linf(   begin)                            #
#
# # 88: Phase01_Species05Linf(     end)                            #
#
# # 89: Phase01_Species05Linf(relative)                            #
#
# /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_5_wc_ge_100_wc_nc_32_wc_th_10/RESULT/Linf_resnorm.dat_cluster
# #  1: Iteration                                                  #
# #  2: Pres-Divmax. residue (begin), global block number          #
#
# #  3: Pres-Divmax. residue (begin), i-index                      #
#
# #  4: Pres-Divmax. residue (begin), j-index                      #
#
# #  5: Pres-Divmax. residue (begin), k-index                      #
#
# #  6: Pres-Divmax. residue (  end), global block number          #
#
# #  7: Pres-Divmax. residue (  end), i-index                      #
#
# #  8: Pres-Divmax. residue (  end), j-index                      #
#
# #  9: Pres-Divmax. residue (  end), k-index                      #
#
# # 10: Pres-DivLinf(   begin)                                     #
#
# # 11: Pres-DivLinf(     end)                                     #
#
# # 12: Pres-DivLinf(relative)                                     #
#
# # 13: U-Velocitymax. residue (begin), global block number        #
#
# # 14: U-Velocitymax. residue (begin), i-index                    #
#
# # 15: U-Velocitymax. residue (begin), j-index                    #
#
# # 16: U-Velocitymax. residue (begin), k-index                    #
#
# # 17: U-Velocitymax. residue (  end), global block number        #
#
# # 18: U-Velocitymax. residue (  end), i-index                    #
#
# # 19: U-Velocitymax. residue (  end), j-index                    #
#
# # 20: U-Velocitymax. residue (  end), k-index                    #
#
# # 21: U-VelocityLinf(   begin)                                   #
#
# # 22: U-VelocityLinf(     end)                                   #
#
# # 23: U-VelocityLinf(relative)                                   #
#
# # 24: Temperaturemax. residue (begin), global block number       #
#
# # 25: Temperaturemax. residue (begin), i-index                   #
#
# # 26: Temperaturemax. residue (begin), j-index                   #
#
# # 27: Temperaturemax. residue (begin), k-index                   #
#
# # 28: Temperaturemax. residue (  end), global block number       #
#
# # 29: Temperaturemax. residue (  end), i-index                   #
#
# # 30: Temperaturemax. residue (  end), j-index                   #
#
# # 31: Temperaturemax. residue (  end), k-index                   #
#
# # 32: TemperatureLinf(   begin)                                  #
#
# # 33: TemperatureLinf(     end)                                  #
#
# # 34: TemperatureLinf(relative)                                  #
#
# # 35: Phase01_Species01max. residue (begin), global block number #
#
# # 36: Phase01_Species01max. residue (begin), i-index             #
#
# # 37: Phase01_Species01max. residue (begin), j-index             #
#
# # 38: Phase01_Species01max. residue (begin), k-index             #
#
# # 39: Phase01_Species01max. residue (  end), global block number #
#
# # 40: Phase01_Species01max. residue (  end), i-index             #
#
# # 41: Phase01_Species01max. residue (  end), j-index             #
#
# # 42: Phase01_Species01max. residue (  end), k-index             #
#
# # 43: Phase01_Species01Linf(   begin)                            #
#
# # 44: Phase01_Species01Linf(     end)                            #
#
# # 45: Phase01_Species01Linf(relative)                            #
#
# # 46: Phase01_Species02max. residue (begin), global block number #
#
# # 47: Phase01_Species02max. residue (begin), i-index             #
#
# # 48: Phase01_Species02max. residue (begin), j-index             #
#
# # 49: Phase01_Species02max. residue (begin), k-index             #
#
# # 50: Phase01_Species02max. residue (  end), global block number #
#
# # 51: Phase01_Species02max. residue (  end), i-index             #
#
# # 52: Phase01_Species02max. residue (  end), j-index             #
#
# # 53: Phase01_Species02max. residue (  end), k-index             #
#
# # 54: Phase01_Species02Linf(   begin)                            #
#
# # 55: Phase01_Species02Linf(     end)                            #
#
# # 56: Phase01_Species02Linf(relative)                            #
#
# # 57: Phase01_Species03max. residue (begin), global block number #
#
# # 58: Phase01_Species03max. residue (begin), i-index             #
#
# # 59: Phase01_Species03max. residue (begin), j-index             #
#
# # 60: Phase01_Species03max. residue (begin), k-index             #
#
# # 61: Phase01_Species03max. residue (  end), global block number #
#
# # 62: Phase01_Species03max. residue (  end), i-index             #
#
# # 63: Phase01_Species03max. residue (  end), j-index             #
#
# # 64: Phase01_Species03max. residue (  end), k-index             #
#
# # 65: Phase01_Species03Linf(   begin)                            #
#
# # 66: Phase01_Species03Linf(     end)                            #
#
# # 67: Phase01_Species03Linf(relative)                            #
#
# # 68: Phase01_Species04max. residue (begin), global block number #
#
# # 69: Phase01_Species04max. residue (begin), i-index             #
#
# # 70: Phase01_Species04max. residue (begin), j-index             #
#
# # 71: Phase01_Species04max. residue (begin), k-index             #
#
# # 72: Phase01_Species04max. residue (  end), global block number #
#
# # 73: Phase01_Species04max. residue (  end), i-index             #
#
# # 74: Phase01_Species04max. residue (  end), j-index             #
#
# # 75: Phase01_Species04max. residue (  end), k-index             #
#
# # 76: Phase01_Species04Linf(   begin)                            #
#
# # 77: Phase01_Species04Linf(     end)                            #
#
# # 78: Phase01_Species04Linf(relative)                            #
#
# # 79: Phase01_Species05max. residue (begin), global block number #
#
# # 80: Phase01_Species05max. residue (begin), i-index             #
#
# # 81: Phase01_Species05max. residue (begin), j-index             #
#
# # 82: Phase01_Species05max. residue (begin), k-index             #
#
# # 83: Phase01_Species05max. residue (  end), global block number #
#
# # 84: Phase01_Species05max. residue (  end), i-index             #
#
# # 85: Phase01_Species05max. residue (  end), j-index             #
#
# # 86: Phase01_Species05max. residue (  end), k-index             #
#
# # 87: Phase01_Species05Linf(   begin)                            #
#
# # 88: Phase01_Species05Linf(     end)                            #
#
# # 89: Phase01_Species05Linf(relative)                            #
#
# /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_40/RESULT/Linf_resnorm.dat_cluster
# #  1: Iteration                                                  #
# #  2: Pres-Divmax. residue (begin), global block number          #
#
# #  3: Pres-Divmax. residue (begin), i-index                      #
#
# #  4: Pres-Divmax. residue (begin), j-index                      #
#
# #  5: Pres-Divmax. residue (begin), k-index                      #
#
# #  6: Pres-Divmax. residue (  end), global block number          #
#
# #  7: Pres-Divmax. residue (  end), i-index                      #
#
# #  8: Pres-Divmax. residue (  end), j-index                      #
#
# #  9: Pres-Divmax. residue (  end), k-index                      #
#
# # 10: Pres-DivLinf(   begin)                                     #
#
# # 11: Pres-DivLinf(     end)                                     #
#
# # 12: Pres-DivLinf(relative)                                     #
#
# # 13: U-Velocitymax. residue (begin), global block number        #
#
# # 14: U-Velocitymax. residue (begin), i-index                    #
#
# # 15: U-Velocitymax. residue (begin), j-index                    #
#
# # 16: U-Velocitymax. residue (begin), k-index                    #
#
# # 17: U-Velocitymax. residue (  end), global block number        #
#
# # 18: U-Velocitymax. residue (  end), i-index                    #
#
# # 19: U-Velocitymax. residue (  end), j-index                    #
#
# # 20: U-Velocitymax. residue (  end), k-index                    #
#
# # 21: U-VelocityLinf(   begin)                                   #
#
# # 22: U-VelocityLinf(     end)                                   #
#
# # 23: U-VelocityLinf(relative)                                   #
#
# # 24: Temperaturemax. residue (begin), global block number       #
#
# # 25: Temperaturemax. residue (begin), i-index                   #
#
# # 26: Temperaturemax. residue (begin), j-index                   #
#
# # 27: Temperaturemax. residue (begin), k-index                   #
#
# # 28: Temperaturemax. residue (  end), global block number       #
#
# # 29: Temperaturemax. residue (  end), i-index                   #
#
# # 30: Temperaturemax. residue (  end), j-index                   #
#
# # 31: Temperaturemax. residue (  end), k-index                   #
#
# # 32: TemperatureLinf(   begin)                                  #
#
# # 33: TemperatureLinf(     end)                                  #
#
# # 34: TemperatureLinf(relative)                                  #
#
# # 35: Phase01_Species01max. residue (begin), global block number #
#
# # 36: Phase01_Species01max. residue (begin), i-index             #
#
# # 37: Phase01_Species01max. residue (begin), j-index             #
#
# # 38: Phase01_Species01max. residue (begin), k-index             #
#
# # 39: Phase01_Species01max. residue (  end), global block number #
#
# # 40: Phase01_Species01max. residue (  end), i-index             #
#
# # 41: Phase01_Species01max. residue (  end), j-index             #
#
# # 42: Phase01_Species01max. residue (  end), k-index             #
#
# # 43: Phase01_Species01Linf(   begin)                            #
#
# # 44: Phase01_Species01Linf(     end)                            #
#
# # 45: Phase01_Species01Linf(relative)                            #
#
# # 46: Phase01_Species02max. residue (begin), global block number #
#
# # 47: Phase01_Species02max. residue (begin), i-index             #
#
# # 48: Phase01_Species02max. residue (begin), j-index             #
#
# # 49: Phase01_Species02max. residue (begin), k-index             #
#
# # 50: Phase01_Species02max. residue (  end), global block number #
#
# # 51: Phase01_Species02max. residue (  end), i-index             #
#
# # 52: Phase01_Species02max. residue (  end), j-index             #
#
# # 53: Phase01_Species02max. residue (  end), k-index             #
#
# # 54: Phase01_Species02Linf(   begin)                            #
#
# # 55: Phase01_Species02Linf(     end)                            #
#
# # 56: Phase01_Species02Linf(relative)                            #
#
# # 57: Phase01_Species03max. residue (begin), global block number #
#
# # 58: Phase01_Species03max. residue (begin), i-index             #
#
# # 59: Phase01_Species03max. residue (begin), j-index             #
#
# # 60: Phase01_Species03max. residue (begin), k-index             #
#
# # 61: Phase01_Species03max. residue (  end), global block number #
#
# # 62: Phase01_Species03max. residue (  end), i-index             #
#
# # 63: Phase01_Species03max. residue (  end), j-index             #
#
# # 64: Phase01_Species03max. residue (  end), k-index             #
#
# # 65: Phase01_Species03Linf(   begin)                            #
#
# # 66: Phase01_Species03Linf(     end)                            #
#
# # 67: Phase01_Species03Linf(relative)                            #
#
# # 68: Phase01_Species04max. residue (begin), global block number #
#
# # 69: Phase01_Species04max. residue (begin), i-index             #
#
# # 70: Phase01_Species04max. residue (begin), j-index             #
#
# # 71: Phase01_Species04max. residue (begin), k-index             #
#
# # 72: Phase01_Species04max. residue (  end), global block number #
#
# # 73: Phase01_Species04max. residue (  end), i-index             #
#
# # 74: Phase01_Species04max. residue (  end), j-index             #
#
# # 75: Phase01_Species04max. residue (  end), k-index             #
#
# # 76: Phase01_Species04Linf(   begin)                            #
#
# # 77: Phase01_Species04Linf(     end)                            #
#
# # 78: Phase01_Species04Linf(relative)                            #
#
# # 79: Phase01_Species05max. residue (begin), global block number #
#
# # 80: Phase01_Species05max. residue (begin), i-index             #
#
# # 81: Phase01_Species05max. residue (begin), j-index             #
#
# # 82: Phase01_Species05max. residue (begin), k-index             #
#
# # 83: Phase01_Species05max. residue (  end), global block number #
#
# # 84: Phase01_Species05max. residue (  end), i-index             #
#
# # 85: Phase01_Species05max. residue (  end), j-index             #
#
# # 86: Phase01_Species05max. residue (  end), k-index             #
#
# # 87: Phase01_Species05Linf(   begin)                            #
#
# # 88: Phase01_Species05Linf(     end)                            #
#
# # 89: Phase01_Species05Linf(relative)                            #
#
# /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_10_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_-1000000/RESULT/Linf_resnorm.dat_cluster
# #  1: Iteration                                                  #
# #  2: Pres-Divmax. residue (begin), global block number          #
#
# #  3: Pres-Divmax. residue (begin), i-index                      #
#
# #  4: Pres-Divmax. residue (begin), j-index                      #
#
# #  5: Pres-Divmax. residue (begin), k-index                      #
#
# #  6: Pres-Divmax. residue (  end), global block number          #
#
# #  7: Pres-Divmax. residue (  end), i-index                      #
#
# #  8: Pres-Divmax. residue (  end), j-index                      #
#
# #  9: Pres-Divmax. residue (  end), k-index                      #
#
# # 10: Pres-DivLinf(   begin)                                     #
#
# # 11: Pres-DivLinf(     end)                                     #
#
# # 12: Pres-DivLinf(relative)                                     #
#
# # 13: U-Velocitymax. residue (begin), global block number        #
#
# # 14: U-Velocitymax. residue (begin), i-index                    #
#
# # 15: U-Velocitymax. residue (begin), j-index                    #
#
# # 16: U-Velocitymax. residue (begin), k-index                    #
#
# # 17: U-Velocitymax. residue (  end), global block number        #
#
# # 18: U-Velocitymax. residue (  end), i-index                    #
#
# # 19: U-Velocitymax. residue (  end), j-index                    #
#
# # 20: U-Velocitymax. residue (  end), k-index                    #
#
# # 21: U-VelocityLinf(   begin)                                   #
#
# # 22: U-VelocityLinf(     end)                                   #
#
# # 23: U-VelocityLinf(relative)                                   #
#
# # 24: Temperaturemax. residue (begin), global block number       #
#
# # 25: Temperaturemax. residue (begin), i-index                   #
#
# # 26: Temperaturemax. residue (begin), j-index                   #
#
# # 27: Temperaturemax. residue (begin), k-index                   #
#
# # 28: Temperaturemax. residue (  end), global block number       #
#
# # 29: Temperaturemax. residue (  end), i-index                   #
#
# # 30: Temperaturemax. residue (  end), j-index                   #
#
# # 31: Temperaturemax. residue (  end), k-index                   #
#
# # 32: TemperatureLinf(   begin)                                  #
#
# # 33: TemperatureLinf(     end)                                  #
#
# # 34: TemperatureLinf(relative)                                  #
#
# # 35: Phase01_Species01max. residue (begin), global block number #
#
# # 36: Phase01_Species01max. residue (begin), i-index             #
#
# # 37: Phase01_Species01max. residue (begin), j-index             #
#
# # 38: Phase01_Species01max. residue (begin), k-index             #
#
# # 39: Phase01_Species01max. residue (  end), global block number #
#
# # 40: Phase01_Species01max. residue (  end), i-index             #
#
# # 41: Phase01_Species01max. residue (  end), j-index             #
#
# # 42: Phase01_Species01max. residue (  end), k-index             #
#
# # 43: Phase01_Species01Linf(   begin)                            #
#
# # 44: Phase01_Species01Linf(     end)                            #
#
# # 45: Phase01_Species01Linf(relative)                            #
#
# # 46: Phase01_Species02max. residue (begin), global block number #
#
# # 47: Phase01_Species02max. residue (begin), i-index             #
#
# # 48: Phase01_Species02max. residue (begin), j-index             #
#
# # 49: Phase01_Species02max. residue (begin), k-index             #
#
# # 50: Phase01_Species02max. residue (  end), global block number #
#
# # 51: Phase01_Species02max. residue (  end), i-index             #
#
# # 52: Phase01_Species02max. residue (  end), j-index             #
#
# # 53: Phase01_Species02max. residue (  end), k-index             #
#
# # 54: Phase01_Species02Linf(   begin)                            #
#
# # 55: Phase01_Species02Linf(     end)                            #
#
# # 56: Phase01_Species02Linf(relative)                            #
#
# # 57: Phase01_Species03max. residue (begin), global block number #
#
# # 58: Phase01_Species03max. residue (begin), i-index             #
#
# # 59: Phase01_Species03max. residue (begin), j-index             #
#
# # 60: Phase01_Species03max. residue (begin), k-index             #
#
# # 61: Phase01_Species03max. residue (  end), global block number #
#
# # 62: Phase01_Species03max. residue (  end), i-index             #
#
# # 63: Phase01_Species03max. residue (  end), j-index             #
#
# # 64: Phase01_Species03max. residue (  end), k-index             #
#
# # 65: Phase01_Species03Linf(   begin)                            #
#
# # 66: Phase01_Species03Linf(     end)                            #
#
# # 67: Phase01_Species03Linf(relative)                            #
#
# # 68: Phase01_Species04max. residue (begin), global block number #
#
# # 69: Phase01_Species04max. residue (begin), i-index             #
#
# # 70: Phase01_Species04max. residue (begin), j-index             #
#
# # 71: Phase01_Species04max. residue (begin), k-index             #
#
# # 72: Phase01_Species04max. residue (  end), global block number #
#
# # 73: Phase01_Species04max. residue (  end), i-index             #
#
# # 74: Phase01_Species04max. residue (  end), j-index             #
#
# # 75: Phase01_Species04max. residue (  end), k-index             #
#
# # 76: Phase01_Species04Linf(   begin)                            #
#
# # 77: Phase01_Species04Linf(     end)                            #
#
# # 78: Phase01_Species04Linf(relative)                            #
#
# # 79: Phase01_Species05max. residue (begin), global block number #
#
# # 80: Phase01_Species05max. residue (begin), i-index             #
#
# # 81: Phase01_Species05max. residue (begin), j-index             #
#
# # 82: Phase01_Species05max. residue (begin), k-index             #
#
# # 83: Phase01_Species05max. residue (  end), global block number #
#
# # 84: Phase01_Species05max. residue (  end), i-index             #
#
# # 85: Phase01_Species05max. residue (  end), j-index             #
#
# # 86: Phase01_Species05max. residue (  end), k-index             #
#
# # 87: Phase01_Species05Linf(   begin)                            #
#
# # 88: Phase01_Species05Linf(     end)                            #
#
# # 89: Phase01_Species05Linf(relative)                            #
#
# /home/vonrickenbach/testcases_mb/kelvin_cell_final/wc_1d_tests/a_v_1000_cov_C_1_dp_100_mf_3000_resol_21_sh_nu_4000_tempe_440_veloc_2_wc_ge_100_wc_nc_32_wc_th_10/RESULT/Linf_resnorm.dat_cluster
# #  1: Iteration                                                  #
# #  2: Pres-Divmax. residue (begin), global block number          #
#
# #  3: Pres-Divmax. residue (begin), i-index                      #
#
# #  4: Pres-Divmax. residue (begin), j-index                      #
#
# #  5: Pres-Divmax. residue (begin), k-index                      #
#
# #  6: Pres-Divmax. residue (  end), global block number          #
#
# #  7: Pres-Divmax. residue (  end), i-index                      #
#
# #  8: Pres-Divmax. residue (  end), j-index                      #
#
# #  9: Pres-Divmax. residue (  end), k-index                      #
#
# # 10: Pres-DivLinf(   begin)                                     #
#
# # 11: Pres-DivLinf(     end)                                     #
#
# # 12: Pres-DivLinf(relative)                                     #
#
# # 13: U-Velocitymax. residue (begin), global block number        #
#
# # 14: U-Velocitymax. residue (begin), i-index                    #
#
# # 15: U-Velocitymax. residue (begin), j-index                    #
#
# # 16: U-Velocitymax. residue (begin), k-index                    #
#
# # 17: U-Velocitymax. residue (  end), global block number        #
#
# # 18: U-Velocitymax. residue (  end), i-index                    #
#
# # 19: U-Velocitymax. residue (  end), j-index                    #
#
# # 20: U-Velocitymax. residue (  end), k-index                    #
#
# # 21: U-VelocityLinf(   begin)                                   #
#
# # 22: U-VelocityLinf(     end)                                   #
#
# # 23: U-VelocityLinf(relative)                                   #
#
# # 24: Temperaturemax. residue (begin), global block number       #
#
# # 25: Temperaturemax. residue (begin), i-index                   #
#
# # 26: Temperaturemax. residue (begin), j-index                   #
#
# # 27: Temperaturemax. residue (begin), k-index                   #
#
# # 28: Temperaturemax. residue (  end), global block number       #
#
# # 29: Temperaturemax. residue (  end), i-index                   #
#
# # 30: Temperaturemax. residue (  end), j-index                   #
#
# # 31: Temperaturemax. residue (  end), k-index                   #
#
# # 32: TemperatureLinf(   begin)                                  #
#
# # 33: TemperatureLinf(     end)                                  #
#
# # 34: TemperatureLinf(relative)                                  #
#
# # 35: Phase01_Species01max. residue (begin), global block number #
#
# # 36: Phase01_Species01max. residue (begin), i-index             #
#
# # 37: Phase01_Species01max. residue (begin), j-index             #
#
# # 38: Phase01_Species01max. residue (begin), k-index             #
#
# # 39: Phase01_Species01max. residue (  end), global block number #
#
# # 40: Phase01_Species01max. residue (  end), i-index             #
#
# # 41: Phase01_Species01max. residue (  end), j-index             #
#
# # 42: Phase01_Species01max. residue (  end), k-index             #
#
# # 43: Phase01_Species01Linf(   begin)                            #
#
# # 44: Phase01_Species01Linf(     end)                            #
#
# # 45: Phase01_Species01Linf(relative)                            #
#
# # 46: Phase01_Species02max. residue (begin), global block number #
#
# # 47: Phase01_Species02max. residue (begin), i-index             #
#
# # 48: Phase01_Species02max. residue (begin), j-index             #
#
# # 49: Phase01_Species02max. residue (begin), k-index             #
#
# # 50: Phase01_Species02max. residue (  end), global block number #
#
# # 51: Phase01_Species02max. residue (  end), i-index             #
#
# # 52: Phase01_Species02max. residue (  end), j-index             #
#
# # 53: Phase01_Species02max. residue (  end), k-index             #
#
# # 54: Phase01_Species02Linf(   begin)                            #
#
# # 55: Phase01_Species02Linf(     end)                            #
#
# # 56: Phase01_Species02Linf(relative)                            #
#
# # 57: Phase01_Species03max. residue (begin), global block number #
#
# # 58: Phase01_Species03max. residue (begin), i-index             #
#
# # 59: Phase01_Species03max. residue (begin), j-index             #
#
# # 60: Phase01_Species03max. residue (begin), k-index             #
#
# # 61: Phase01_Species03max. residue (  end), global block number #
#
# # 62: Phase01_Species03max. residue (  end), i-index             #
#
# # 63: Phase01_Species03max. residue (  end), j-index             #
#
# # 64: Phase01_Species03max. residue (  end), k-index             #
#
# # 65: Phase01_Species03Linf(   begin)                            #
#
# # 66: Phase01_Species03Linf(     end)                            #
#
# # 67: Phase01_Species03Linf(relative)                            #
#
# # 68: Phase01_Species04max. residue (begin), global block number #
#
# # 69: Phase01_Species04max. residue (begin), i-index             #
#
# # 70: Phase01_Species04max. residue (begin), j-index             #
#
# # 71: Phase01_Species04max. residue (begin), k-index             #
#
# # 72: Phase01_Species04max. residue (  end), global block number #
#
# # 73: Phase01_Species04max. residue (  end), i-index             #
#
# # 74: Phase01_Species04max. residue (  end), j-index             #
#
# # 75: Phase01_Species04max. residue (  end), k-index             #
#
# # 76: Phase01_Species04Linf(   begin)                            #
#
# # 77: Phase01_Species04Linf(     end)                            #
#
# # 78: Phase01_Species04Linf(relative)                            #
#
# # 79: Phase01_Species05max. residue (begin), global block number #
#
# # 80: Phase01_Species05max. residue (begin), i-index             #
#
# # 81: Phase01_Species05max. residue (begin), j-index             #
#
# # 82: Phase01_Species05max. residue (begin), k-index             #
#
# # 83: Phase01_Species05max. residue (  end), global block number #
#
# # 84: Phase01_Species05max. residue (  end), i-index             #
#
# # 85: Phase01_Species05max. residue (  end), j-index             #
#
# # 86: Phase01_Species05max. residue (  end), k-index             #
#
# # 87: Phase01_Species05Linf(   begin)                            #
#
# # 88: Phase01_Species05Linf(     end)                            #
#
# # 89: Phase01_Species05Linf(relative)                            #

# %%
for sim in sim_list:
#    if sim.sim_info["temperature"] < 420:
      print(sim.info.local["jobname"])
      sim.sync_result("processed")
# Out:
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_500_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_10_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_1_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_40
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_160
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_500_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_10_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_1_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_1000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_10000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_500_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_10_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_1_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_40
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_160
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_500_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_10_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_1_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_50_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_100_mf_3000_sh_n_4000_temp_300_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_500_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_10_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_1_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_40
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_160
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_500_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_10_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_1_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_1000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_10000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_500_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_10_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_1_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_40
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_160
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_500_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_10_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_1_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_50_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_100_mf_3000_sh_n_4000_temp_360_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_500_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_10_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_1_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_40
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_160
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_500_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_10_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_1_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_1000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_10000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_500_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_10_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_1_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_40
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_160
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_500_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_10_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_1_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_50_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_100_mf_3000_sh_n_4000_temp_370_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_500_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_10_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_1_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_40
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_160
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_500_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_10_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_1_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_1000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_10000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_500_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_10_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_1_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_40
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_160
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_500_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_10_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_1_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_50_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_100_mf_3000_sh_n_4000_temp_380_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_390_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_390_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_500_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_10_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_1_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_100_wc_t_40
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_100_wc_t_160
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_100_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_500_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_10_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_1_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_1000_sh_n_4000_temp_390_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_10000_sh_n_4000_temp_390_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_500_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_10_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_1_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_100_wc_t_40
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_100_wc_t_160
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_100_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_500_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_10_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_1_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_50_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_100_mf_3000_sh_n_4000_temp_390_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_500_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_10_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_1_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_40
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_160
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_500_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_10_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_1_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_1000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_10000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_500_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_10_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_1_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_40
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_160
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_500_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_10_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_1_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_50_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_100_mf_3000_sh_n_4000_temp_400_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_500_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_10_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_1_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_40
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_160
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_500_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_10_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_1_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_1000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_10000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_500_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_10_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_1_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_40
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_160
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_500_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_10_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_1_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_50_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_100_mf_3000_sh_n_4000_temp_410_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_420_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_420_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_420_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_420_velo_5_wc_g_500_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_420_velo_5_wc_g_10_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_420_velo_5_wc_g_1_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_420_velo_5_wc_g_100_wc_t_40
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_420_velo_5_wc_g_100_wc_t_160
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_420_velo_5_wc_g_100_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_420_velo_5_wc_g_500_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_420_velo_5_wc_g_10_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_420_velo_5_wc_g_1_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_420_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_420_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_420_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_1000_sh_n_4000_temp_420_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_10000_sh_n_4000_temp_420_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_420_velo_5_wc_g_500_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ...
# a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_800_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_800_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_1000_sh_n_4000_temp_800_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_10000_sh_n_4000_temp_800_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_800_velo_5_wc_g_500_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_800_velo_5_wc_g_10_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_800_velo_5_wc_g_1_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_800_velo_5_wc_g_100_wc_t_40
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_800_velo_5_wc_g_100_wc_t_160
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_800_velo_5_wc_g_100_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_800_velo_5_wc_g_500_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_800_velo_5_wc_g_10_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_800_velo_5_wc_g_1_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_50_mf_3000_sh_n_4000_temp_800_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_100_mf_3000_sh_n_4000_temp_800_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_900_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_900_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_500_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_10_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_1_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_100_wc_t_40
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_100_wc_t_160
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_100_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_500_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_10_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_1_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_1000_sh_n_4000_temp_900_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_10000_sh_n_4000_temp_900_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_500_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_10_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_1_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_100_wc_t_40
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_100_wc_t_160
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_100_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_500_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_10_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_1_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_50_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_100_mf_3000_sh_n_4000_temp_900_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_1000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_10000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_500_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_10_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_1_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_40
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_160
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_500_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_10_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_1_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_50_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__1_dp_100_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_1000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_10000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_500_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_10_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_1_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_40
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_160
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_500_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_10_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_1_wc_t_-1000000
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_50_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================
# a_v_1000_cov__0_dp_100_mf_3000_sh_n_4000_temp_1000_velo_5_wc_g_100_wc_t_10
# ===================================================
#  Syncing processed folder  with Cluster
# ===================================================

# %%
for sim in filter_simulations(sim_list):
  try:
     wc_data_l = pic.load(open(os.path.join(sim.info.local["sim_folder"],"processed/wc_data.dat"))) 
     wc_data = [[float(item[0].split()[2].split("\\")[0]),item[1]] for item in sorted(wc_data_l,key=lambda item:item[0])]
     sim.wc_data = {}
     sim.wc_data["coords"] = np.linspace(0.0,0.04,100)
     sim.wc_data["CO"]     = np.interp(sim.wc_data["coords"],[item[0] for item in wc_data],[np.array(item[1][4][0]) for item in wc_data])
     sim.all_data = wc_data  
     if np.isnan(np.array([item[1] for item in wc_data])).any():
         sim.sim_info["converged"] = False
         print sim.info.local["jobname"]
  except:
     print sim.info.local["jobname"]
# Out:
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_510_velo_5_wc_g_500_wc_t_-1000000
# a_v_1000_cov__0_dp_50_mf_3000_sh_n_4000_temp_510_velo_5_wc_g_100_wc_t_10
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_520_velo_5_wc_g_100_wc_t_10
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_520_velo_5_wc_g_10_wc_t_10
# a_v_1000_cov__0_dp_10_mf_3000_sh_n_4000_temp_520_velo_5_wc_g_100_wc_t_40

# %%
plot_sims = filter_simulations(sim_list,cov_CO=0,dp=10,wc_geo_area=500,sh_number=4000,mf=3000,wc_thickness=0)

fig = pl.figure(figsize=figsize)
ax = fig.add_subplot(1,1,1)

for i in range(1):
    inputs = default_inputs.copy()
    inputs["cov_CO"] =1
    inputs["wc_geo_area"] = 1
    inputs["wc_thickness"] = -1E6

    sim_to_plot = sort_sims(filter_simulations(sim_list_py,**inputs),"temperature")

    grid = []
    for val in range(1,33):
        grid.append((1-1.2**val)/(1-1.2))
    grid = np.array(grid) / grid[-1] * sim.sim_info["wc_thickness"]*1E-6
    grid = np.insert(grid,0,0)
    label = str(sim.sim_info["temperature"])+"_"+str(sim.sim_info["nx"])
    ax.semilogy(get_array(sim_to_plot,get_var,"temperature"),get_array(sim_to_plot,get_cov,5),label="PT(S)")
    ax.semilogy(get_array(sim_to_plot,get_var,"temperature"),get_array(sim_to_plot,get_cov,6),label="O(S)")
    ax.semilogy(get_array(sim_to_plot,get_var,"temperature"),get_array(sim_to_plot,get_cov,7),label="CO(S)")

ax.set_ylim([1E-4,1.01])
ax.set_xlabel("Temperature (K)")
ax.set_ylabel("$\\theta$ (-)")
ax.legend(loc=0,frameon=False)
fig.tight_layout()
fig.savefig("wc_plots/coverages.eps")

# %%
def get_cov(sim,idx):
#    try:
        return sim.all_data[0][1][idx][0]
#    except:
#        print (sim.info.local["jobname"])

# %%
gas = ca.import_phases(os.path.join(ref_folder,"cantera_input.cti"),["gas"])[0]
interface = ca.Interface(os.path.join(ref_folder,"cantera_input.cti"),"pt_surf",[gas])

temp_wc = [410,420,430]
colors = ["r","b","k","g","y","m",'r']
covs = [10,1000]

markers = ["-","--"]

fig = pl.figure(figsize=figsize)
ax = fig.add_subplot(1,1,1)

for cov,mark in zip(covs,markers):

    for temp,col in zip(temp_wc,colors):
      print(temp)
      for sim in  filter_simulations(sim_list_py,cov_CO=0,dp=cov,wc_geo_area=100,sh_number=4000,mf=3000,temperature=temp,wc_thickness=40,velocity=5,a_v=1000,nx=64,t_fac=1,x_cells=20):
        grid = []
        for val in range(1,sim.sim_info["nx"]+1):
            grid.append((1-1.1**val)/(1-1.1))
        grid = np.array(grid) / grid[-1] * sim.sim_info["wc_thickness"]
        grid = np.insert(grid,0,0)
        if sim.sim_info["cov_CO"]== 0:
          marker = "o"
          lab = "heating"
        else:
            marker = "x"
            lab  = "cooling"
            lab  = ""
        label = str(sim.sim_info["temperature"])+"_"+str(sim.sim_info["res"])
        ax.plot(grid,sim.all_data[0][1][4][:]*1E6,label="T "+str(temp)+" K",linestyle=mark,color=col)
#        ax.plot(grid,sim.all_data[0][1][7][:],label="T "+str(temp)+" K",linestyle=mark,color=col)
        
        prod_rates = []

        for conc in sim.all_data[0][1][4][:]:
            gas.TPX = (temp,1.015E5,[0.1,0.064,0.072,0.76,conc])
            interface.TPX = [temp,1E5,[1,0,0,0]]
            interface.advance_coverages_test(1000000)
            prod_rates.append(interface.get_net_production_rates("gas")[1])
        
        
  #      ax.plot(grid,prod_rates,label="T "+str(temp)+" K",linestyle=mark,color=col)

#        ax.plot([item[1][4][0] for item in sim.all_data],label="T= "+str(temp)+" K , $d_{wc}$ ="+str(sim.sim_info["dp"]) + " nm",linestyle=mark,color=col)

        ax.set_xlabel("w ($\mu m)$")
        ax.set_ylabel("$Y_{CO}$ (ppm)")

handles, labels = ax.get_legend_handles_labels()
ax.legend(handles[:3],labels[:3],loc=0,frameon=False)
pl.gcf().tight_layout()        
pl.gcf().savefig("wc_plots/wc_detail_cool.eps")
# Out:
# 410
# 420
# 430
# 410
# 420
# 430

# %%
temp_wc = [480,500,600]
colors = ["r","b","k","g","y","m",'r']
covs = [100,10]

markers = ["-","-"]



for cov,mark in zip(covs,markers):
    fig = pl.figure(figsize=figsize)
    ax = fig.add_subplot(1,1,1)
    for temp,col in zip(temp_wc,colors):
      print(temp)
      for sim in  filter_simulations(sim_list_py,cov_CO=1,dp=cov,wc_geo_area=100,sh_number=4000,mf=3000,temperature=temp,wc_thickness=100,velocity=5,a_v=1000,nx=64,t_fac=1,x_cells=20):
        grid = []
        for val in range(1,sim.sim_info["nx"]+1):
            grid.append((1-1.1**val)/(1-1.1))
        grid = np.array(grid) / grid[-1] * sim.sim_info["wc_thickness"]
        grid = np.insert(grid,0,0)
        if sim.sim_info["cov_CO"]== 0:
          marker = "o"
          lab = "heating"
        else:
            marker = "x"
            lab  = "cooling"
            lab  = ""
        label = str(sim.sim_info["temperature"])+"_"+str(sim.sim_info["res"])
        ax.plot(grid,sim.all_data[0][1][4][:]*1E6,label="T "+str(temp)+" K",linestyle=mark,color=col)
#        ax.plot([item[1][4][0] for item in sim.all_data],label="T= "+str(temp)+" K , $d_{wc}$ ="+str(sim.sim_info["dp"]) + " nm",linestyle=mark,color=col)

        ax.set_xlabel("w ($\mu m)$")
        ax.set_ylabel("$Y_{CO}$ (ppm)")
        ax.set_xlim([0,9])

        prod = []
        for cell_idx in range(len(sim.all_data[0][1][4][:])-1):
            data = np.array(sim.all_data[0][1])
            gas.TPX = (temp,1.015E5,data[:5,cell_idx])
#       gas.setState_TPX(temp,1.015E5,[0.1,0.064,0.072,0.76,0.00003])

            interface.TPX = (temp,1E5,data[5:-1,cell_idx])
            prod.append(interface.net_rates_of_progress[4])
        
        prod = np.array(prod)
        prod = prod/max(prod)

        grid_prod = grid[1:]
#        ax.plot(grid_prod,prod*3000,"--",color=col)
        ax.set_ylim(0,3000)
        ltp1 = grid_prod[np.where(prod>0.1)]

        ax.add_patch(pl.Rectangle([min(ltp1),0],max(ltp1)-min(ltp1),3000,fill=True,alpha=0.5,color=col))




    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles[:],labels[:],loc=0,frameon=False)
    pl.gcf().tight_layout()        
    pl.gcf().savefig("wc_plots/wc_detail_heat_dp_"+str(cov)+".pdf")
# Out:
# 480
# 500
# 600
# 480
# 500
# 600

# %%
temp_wc = [1000]
colors = ["r","b","k","g","y","m",'r']
covs = [100,10]

markers = ["-","-"]



for cov,mark in zip(covs,markers):
    fig = pl.figure(figsize=figsize)
    ax = fig.add_subplot(1,1,1)
    for temp,col in zip(temp_wc,colors):
      print(temp)
      for sim in  filter_simulations(sim_list_py,cov_CO=1,dp=cov,wc_geo_area=100,sh_number=4000,mf=3000,temperature=temp,wc_thickness=40,velocity=5,a_v=1000,nx=64,t_fac=1,x_cells=20):
        grid = []
        for val in range(1,sim.sim_info["nx"]+1):
            grid.append((1-1.1**val)/(1-1.1))
        grid = np.array(grid) / grid[-1] * sim.sim_info["wc_thickness"]
        grid = np.insert(grid,0,0)
        if sim.sim_info["cov_CO"]== 0:
          marker = "o"
          lab = "heating"
        else:
            marker = "x"
            lab  = "cooling"
            lab  = ""
        label = str(sim.sim_info["temperature"])+"_"+str(sim.sim_info["res"])
        ax.plot(grid[1:],sim.all_data[0][1][4][1:]*1E6,label="T "+str(temp)+" K",linestyle=mark,color="k")
#        ax.plot([item[1][4][0] for item in sim.all_data],label="T= "+str(temp)+" K , $d_{wc}$ ="+str(sim.sim_info["dp"]) + " nm",linestyle=mark,color=col)

        ax.set_xlabel("w ($\mu m)$")
        ax.set_ylabel("$Y_{CO}$ (ppm)")
        ax.set_xlim([0.00,1])
        ax.set_ylim([0,3000])

        prod = []
        for cell_idx in range(len(sim.all_data[0][1][4][:])-1):
            data = np.array(sim.all_data[0][1])
            gas.TPX = (temp,1.015E5,data[:5,cell_idx])
#       gas.setState_TPX(temp,1.015E5,[0.1,0.064,0.072,0.76,0.00003])

            interface.TPX = (temp,1E5,data[5:-1,cell_idx])
            prod.append(interface.net_rates_of_progress[4])
        
        prod = np.array(prod)
        prod = prod/max(prod)

        grid_prod = grid[1:]
#        ax.plot(grid_prod,prod*3000,"--",color=col)
        
        ltp1 = grid_prod[np.where(prod>0.1)]

        ax.add_patch(pl.Rectangle([min(ltp1),0],max(ltp1)-min(ltp1),3000,fill=True,alpha=0.5,color=col))




    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles[:],labels[:],loc=0,frameon=False)
    pl.gcf().tight_layout()        
    pl.gcf().savefig("wc_plots/wc_detail_heat_pres_"+str(cov)+".png",dpi=300,)
# Out:
# 1000
# 1000

# %%
prod/max(prod)
# Out:
# array([  1.00000000e+00,   8.43104333e-01,   7.03609957e-01,
#          5.81260716e-01,   4.75372505e-01,   3.84914544e-01,
#          3.08613515e-01,   2.45044210e-01,   1.92713672e-01,
#          1.50128749e-01,   1.15864092e-01,   8.85973466e-02,
#          6.71457033e-02,   5.04820686e-02,   3.77265382e-02,
#          2.81176114e-02,   2.09820422e-02,   1.57292133e-02,
#          1.18620987e-02,   8.98969121e-03,   6.82376891e-03,
#          5.16313826e-03,   3.87243534e-03,   2.86218535e-03,
#          2.07286316e-03,   1.46295915e-03,   1.00113015e-03,
#          6.61178781e-04,   4.19600570e-04,   2.54837322e-04,
#          1.47525876e-04,   8.10851882e-05,   4.21481601e-05,
#          2.06399225e-05,   9.48763781e-06,   4.08101872e-06,
#          1.63869964e-06,   6.13455868e-07,   2.14098397e-07,
#          6.97429879e-08,   2.12415287e-08,   6.05417559e-09,
#          1.61211005e-09,   3.98873759e-10,   9.08489595e-11,
#          1.88206384e-11,   3.50087143e-12,   5.77542462e-13,
#          8.35801575e-14,   1.05118803e-14,   1.14002945e-15,
#          1.05916726e-16,   8.38365794e-18,   5.62716879e-19,
#          3.19041606e-20,   1.52335210e-21,   6.52793880e-23,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#          0.00000000e+00])

# %%
gas = ca.importPhase(os.path.join(ref_folder,"cantera_input.cti"),"gas")
interface = ca.importInterface(os.path.join(ref_folder,"cantera_input.cti"),"pt_surf",[gas])
temp = 500
gas.setState_TPY(temp,1.015E5,[0.1,0.064,0.072,0.76,0.003])
diff = []
dps = np.logspace(-4,-9)
for dp in dps:
    diff.append(1./(1/gas.mixDiffCoeffs()[-1]+1./(dp/8*np.sqrt(8*8*temp/(np.pi*0.028)))))

ax = pl.gca()
ax.set_xlabel("pore diameter")
ax.set_ylabel("D ($m^2/s$)")

ax.loglog(dps,diff)
pl.gcf().tight_layout()
pl.gcf().savefig("knudsen.eps")

# %%
gas = ca.import_phases(os.path.join(ref_folder,"cantera_input.cti"),["gas"])[0]
interface = ca.Interface(os.path.join(ref_folder,"cantera_input.cti"),"pt_surf",[gas])
temp = 800
prod = []
#conc_arr = np.logspace(-5,-1,100)
temp_arr =temperatures
#temp_arr.extend(temperatures[::-1])
prod = np.zeros([len(temp_arr),interface.n_reactions+1])
ref_prod = np.zeros([len(temp_arr),interface.n_reactions+1])

colors = ["r","r","b","b","k","k","m","m"]
linestyles = ["-","--","-","--","-","--","-","--"]
for reaction in range(interface.n_reactions+1):
    for idx,temp in enumerate(temp_arr[:]):
        sim =  filter_simulations(sim_list_py,temperature=temp,cov_CO=1,wc_geo_area=1,velocity=5,wc_thickness=-1E6)[0]
        conc = sim.all_data[0][1][4][1]
        gas.TPX = (temp,1.015E5,[0.1,0.064,0.072,0.76,conc])
#        gas.setState_TPX(temp,1.015E5,[0.1,0.064,0.072,0.76,0.00003])

        interface.TPX = (temp,1E5,[1,0,0,0])
        for reac in range(interface.n_reactions):
            interface.set_multiplier(1,reac)
        interface.advance_coverages_test(1000000)
        prod_ref = interface.net_rates_of_progress[4]
        if reaction == interface.n_reactions:
            interface.TPX = (temp+0.01*temp,1.0E5,[1,0,0,0])
        else:   
            interface.set_multiplier(1.01,reaction)
        interface.advance_coverages_test(1000000)
        if reaction == interface.n_reactions:
            print prod_ref, interface.net_rates_of_progress[4]
        prod[idx,reaction] = (interface.net_rates_of_progress[4]-prod_ref)/prod_ref/0.01
# Out:
# 3.19044895818e-23 7.21422865728e-23
# 3.50352508468e-17 6.9091848768e-17
# 2.29831251786e-16 4.44939883244e-16
# 1.36606754324e-15 2.59870869428e-15
# 7.41285773189e-15
#  1.38692879236e-14
# 3.69752819802e-14 6.80963030382e-14
# 1.70577698726e-13 3.09465031827e-13
# 7.31877035782e-13 1.30892287264e-12
# 2.9352436125e-12
#  5.17837393946e-12
# 1.10543315777e-11 1.9249548649e-11
# 3.92564832923e-11 6.75123682146e-11
# 1.31956639414e-10 2.24239399266e-10
# 4.21301002932e-10
#  7.07759678843e-10
# 1.28166246834e-09 2.12941804218e-09
# 3.72611261435e-09 6.12481183772e-09
# 1.03821737535e-08 1.68888341647e-08
# 2.78104203906e-08
#  4.47797199543e-08
# 7.19049386252e-08 1.14613740664e-07
# 1.80636026806e-07 2.85017690932e-07
# 4.47014723543e-07 6.98072324798e-07
# 1.13211378691e-06
#  1.74929305347e-06
# 3.92052648507e-06 6.00422056089e-06
# 1.37653893016e-05 1.38148230278e-05
# 1.41766334797e-05 1.42144716761e-05
# 1.3240207244e-05 1.40880302067e-05
# 1.36134867484e-05
#  1.4631570902e-05
# 1.57210586754e-05 1.6492973505e-05
# 1.75014553877e-05 1.80549180289e-05

# %%
fig = pl.figure(figsize=figsize)
ax = fig.add_subplot(1,1,1)
colors = ["r","b","r","b","k","g","k","k"]
linestyles = ["-","-",":",":","-","-","-","-"]
pl.plot(temp_arr,np.array(prod[:,interface.n_reactions]),color=co,linestyle=ls)
#    reaction_str = [interface.reactionString(ind) for ind in range(interface.nReactions())]
legend_list = []
#for reac in reaction_str:
#    legend_list.append("$"+"\\rightarrow".join(reac.split("=>"))+"$")

pl.legend(legend_list,loc=0,frameon=False,ncol=2,columnspacing =0.8)
ax.set_ylim([0,90]) 
ax.set_xlim([400,1000])
ax.set_xlabel("Temperature (K)")
ax.set_ylabel("$S_T$ (-)")
ax.add_patch(pl.Rectangle([520,0],60,90,fill=True,alpha=0.5,color="r"))
fig.tight_layout()
fig.savefig("wc_plots/sensitivities_T.pdf")

# %%
fig = pl.figure(figsize=figsize)
ax = fig.add_subplot(1,1,1)
colors = ["r","b","r","b","k","g","k","k"]
linestyles = ["-","-",":",":","-","-","-","-"]
for column_idx,ls,co in zip(range(len(prod[0,:]-1)),linestyles,colors):
    if column_idx == 4 or column_idx == interface.n_reactions or column_idx == 6:
        continue
    pl.plot(temp_arr,np.array(prod[:,column_idx]),color=co,linestyle=ls)
#    reaction_str = [interface.reactionString(ind) for ind in range(interface.nReactions())]
legend_list = []
#for reac in reaction_str:
#    legend_list.append("$"+"\\rightarrow".join(reac.split("=>"))+"$")


legend_list = ["$O_2$ ad","$CO$ ad","$O(S)$ de","$CO$ de","SR"]
pl.legend(legend_list,loc=0,frameon=False,ncol=2,columnspacing =0.8)
ax.set_ylim([-2.2,5]) 
#ax.set_xlim([400,1000])
ax.set_xlabel("Temperature (K)")
ax.set_ylabel("S (-)")
fig.tight_layout()
fig.savefig("wc_plots/sensitivities_r.eps")

# %%
import matplotlib
fig = pl.figure(figsize=figsize_print)
colors = ["r","b","r","b","k","g","g"]

ax = fig.add_subplot(1,1,1)
for column_idx,ls,co in zip(range(len(prod[0,:])),linestyles,colors):
    if column_idx == 5:
        continue
    ax.semilogy(temp_arr,np.array(ref_prod[:,column_idx]),color=co,linestyle=ls)
    
legend_list = ["$O_2$ ad","$CO$ ad","$O(S)$ de","$CO$ de","SR","CO2des"]
#ax.locator_params(nbins=10)
   
pl.legend(legend_list,loc=0,frameon=False)
ax.set_xlabel("Temperature (K)")
ax.set_ylabel(r"Reaction rate $( kmol / (m^2 s)$)")
ax.set_ylim([1E-14,1E-3])

ticks = np.logspace(-13,-3,6)
ax.set_yticks(ticks)
ax.set_yticklabels(["$10^{"+str(int(np.log10(item)))+"}$" for item in ticks])

pl.minorticks_off()
#ax.get_xaxis().set_major_formatter(matplotlib.ticker.ScalarFormatter())
#ax.yaxis.set_ticks(np.logspace(-14, -3,10))
fig.tight_layout()
fig.savefig("wc_plots/reaction_rates.eps")

# %%
def create_simulation_python(input_dict,folder,root_folder=".",ref_folder=None):
     

    config_sim = jc.configuration_mb_local
    config_sim["transat_version"] = "wc_python"

    config_sim["jobname"] = inputs["folder"]
    config_sim["root_folder"] = root_folder
    simulation = sim_brutus.job(**config_sim)

    simulation.sim_info = input_dict.copy()
    simulation.sim_info["converged"] = False


    return simulation

# %%
temperatures = [300,360,370,380,390,400,410,420,430,440,450,460,470,480,490,500,510,520,530,540,550,560,570,600,700,800,900,1000]

# %%
folders = ["washcoat_model_co_test","sandbox_test"]

par_inputs_py = {}
par_inputs_py["wc_thickness"] = [10,80,160]
par_inputs_py["no_wc"] = [1,10,100,500]
par_inputs_py["wc_geo_area"] = [1,10,500]
par_inputs_py["dp"] = [50,100,5,1000]
par_inputs_py["mf"] = [1000,10000]
par_inputs_py["default"] = [0]
par_inputs_py["x_cells"] = [40]

par_inputs_py["nx"] = [32,128]
par_inputs_py["t_fac"] = [10]
par_inputs_py["sh_number"] = [8000,16000]




inputs = {}

sim_list_py  = []
trate = 0.1
mintemp = 380
maxtemp = 1000
temperatures = np.linspace(mintemp,maxtemp,(maxtemp-mintemp)/10+1)
temperatures = np.linspace(300,1000,71)
temperatures = [300,360,370,380,390,400,410,420,430,440,450,460,470,480,490,500,510,520,530,540,550,560,570,600,700,800,900,1000]
nx=32

ref_folder= "/home/vonrickenbach/ref_sims/ref_folder_python/"
#root_folder= "/home/vonrickenbach/testcases_python_no_H2O"
#root_folder= "/home/vonrickenbach/testcases_python"
root_folder= "/home/vonrickenbach/testcases_python_wc_100/"



for par_key,par_value in par_inputs_py.iteritems():
    for val in par_value:
        folder = par_key+"_"+str(int(val))
  #      folder = "ref_sims/ref_folder_python"


        try:
            sh.copytree(ref_folder,os.path.join(root_folder,folder))
        except:
            pass
        input_file = open(os.path.join(root_folder,folder,"input.pic"),"w")
        file_dict = {}

        if par_key == "wc_thickness":
            if val < 0:
               file_dict["nx"] =1
            file_dict["wc_thickness"] =val
        if par_key == "wc_geo_area":
            file_dict["wc_geo_area"] =val  
        if par_key == "no_wc":
            file_dict["wc_geo_area"] =val
            file_dict["nx"] =1

        if par_key == "dp":
            if val == 1000:
               file_dict["tortuosity"] = 1.0 
            file_dict["d_p"] =val 
        if par_key == "mf":
            file_dict["mf"] =val  
        if par_key == "nx":
            file_dict["nx"] =val  
        if par_key == "t_fac":
            file_dict["t_fac"] =val  
        if par_key == "x_cells":
            file_dict["x_cells"] =val  
        if par_key == "sh_number":
            file_dict["h"] =val        

  
        pic.dump(file_dict,input_file)
        input_file.close()
        for cov in [1,0]:

            for temperature in temperatures:
                inputs = default_inputs.copy()
                inputs["wc_thickness"] = 100
                inputs["temperature"] = temperature
                inputs["cov_CO"] = cov
                inputs["folder"] = folder
                inputs["res"] = 20
                inputs["nx"]  = 64
                inputs["t_fac"]  = 1
                inputs["x_cells"]  = 20


                inputs["mf"] = 3000
                if par_key == "no_wc":
                    inputs["wc_geo_area"] = val
                    inputs["wc_thickness"] = -1E6


                else:
                    inputs[par_key] = val
                sim_list_py.append(create_simulation_python(inputs,folder,root_folder=root_folder))
                
sim_list_run = filter_simulations(sim_list_py,temperature=mintemp,cov_CO=1)
# Out:
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# ...
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported
# Warning Initial conditions with single block code not supported

# %%
for sim in sim_list_py:
 try:
    load_wc(sim)

 except:
       print(sim.sim_info)
       pass
# Out:
# {'a_v': 1000, 'cov_CO': 1, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 570, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 1, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 600, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 1, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 700, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 1, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 800, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 1, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 900, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 1, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 1000, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 300, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 360, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 370, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 380, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 390, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 400, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 410, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 420, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 430, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 440, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 450, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 460, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 470, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 480, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 490, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 500, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 510, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 520, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 530, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 540, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 550, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 560, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 570, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 600, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 700, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 800, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 900, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 100, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 10, 'mf': 3000, 'temperature': 1000, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 't_fac_10', 'sh_number': 4000}
# {'a_v': 1000, 'cov_CO': 0, 'wc_porosity': 0.35, 'wc_tortuosity': 8.0, 'wc_geo_area': 500, 'x_cells': 20, 'wc_thickness': 100, 'dp': 10, 't_fac': 1, 'mf': 3000, 'temperature': 300, 'res': 20, 'nx': 64, 'converged': False, 'velocity': 5, 'folder': 'wc_geo_area_500', 'sh_number': 4000}

# %%
def load_wc(sim):
    wc_data = []
    if sim.sim_info["cov_CO"] == 1:
        time_idx = (int(sim.sim_info["temperature"])-380)*10
    else:
        time_idx = int(np.size(temperatures)*10 + (max(temperatures) - sim.sim_info["temperature"]))*10
        
    time_idx = int(sim.sim_info["temperature"])
#    print sim.info.local["sim_folder"]

    nx = sim.sim_info["x_cells"]
    dx = 0.005/ sim.sim_info["x_cells"]
    for point in range(sim.sim_info["x_cells"]):
      wc_data.append([point*dx+dx/2,np.genfromtxt(os.path.join(sim.info.local["sim_folder"],"result","grid_"+str(point)+"_"+str(time_idx)+"_"+str(sim.sim_info["cov_CO"])+".dat"))])
    
    sim.wc_data = {}
    sim.wc_data["coords"] = np.linspace(0.0,0.005,100)
    sim.wc_data["CO"]     = np.interp(sim.wc_data["coords"],[item[0] for item in wc_data],[np.array(item[1][4][0]) for item in wc_data])
    sim.all_data = wc_data

# %%
Re = 100
Dp = 0.002
epsilon = 0.9
Re**0.47*Dp**(-0.42)/(0.001)**0.58*epsilon**0.44
# Out:
# 6214.8994404175155

# %%
Dp = [item / 1000 for item in [2.768,1.610,1.190,0.867,3.132,1.582,1.191,0.893,1.529,0.802]]
epsilon = [0.772,0.751,0.766,0.761,0.812,0.814,0.807,0.801,0.719,0.946]

# %%
for dp,ep in zip(Dp,epsilon):
    Re = 0.5*dp/2.2E-5
    print(Re**0.47*dp**(-0.42)/(0.001)**0.58*ep**0.44)
# Out:
# 4076.027998
# 3919.2242004
# 3894.17306691
# 3821.97151458
# 4193.46461356
# 4057.06816106
# 3984.71427277
# 3914.87700355
# 3834.93783267
# 4189.65305438

# %%
10*0.001/(1.8E-5)
# Out:
# 555.5555555555555

# %%
gas.TPX = (400,1E5,(0.1,0,0,0.9,0))

# %%
gas.viscosity
# Out:
# 2.267917998751395e-05
